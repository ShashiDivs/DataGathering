# %%
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd

# %%
with open('smartprix.html','r',encoding='utf-8') as f:
    html = f.read()

# %%
#html

# %%
soup = BeautifulSoup(html,'lxml')

# %%
container = soup.find_all('div',{'class':'sm-product has-tag has-features has-actions'})

# %%
name = []
prices = []
ratings = []
sim = []
processor = []
ram = []
battery = []
display = []
camera = []
card = []
os = []

for i in container:
    try:
        name.append(i.find('h2').text)
    except:
        name.append(np.nan)
    try:
        prices.append(i.find('span',{'class':'price'}).text)
    except:
        prices.append(np.nan)
    try:
        ratings.append(i.find('div',{'class':'score rank-2-bg'}).find('b').text)
    except:
        ratings.append(np.nan)

    x = i.find('ul',{'class':'sm-feat specs'}).find_all('li')
    try:
        sim.append(x[0].text)
    except:
        sim.append(x[1].text)
    try:
        processor.append(x[1].text)
    except:
        processor.append(np.nan)
    try:    
        ram.append(x[2].text)
    except:
        ram.append(np.nan)
    try:
        battery.append(x[3].text)
    except:
        battery.append(np.nan)
    try:
        display.append(x[4].text)
    except:
        display.append(np.nan)
    try:
        camera.append(x[5].text)
    except:
        camera.append(np.nan)
    try:
        card.append(x[6].text)
    except:
        card.append(np.nan)
    try:
        os.append(x[7].text)
    except:
        os.append(np.nan)

# %%
len(name)
# Out:
# 1020

# %%
len(ram)
# Out:
# 1020

# %%
df = pd.DataFrame({
    'model':name,
    'price':prices,
    'rating':ratings,
    'sim':sim,
    'processor':processor,
    'ram':ram,
    'battery':battery,
    'display':display,
    'camera':camera,
    'card':card,
    'os':os
})

# %%
df
# Out:
#                           model    price rating  \
# 0     OnePlus Nord CE 2 Lite 5G  ₹18,999     81
# 1         Samsung Galaxy A14 5G  ₹16,499     75
# 2          Motorola Moto G62 5G  ₹14,999     81
# 3            Realme 10 Pro Plus  ₹24,999     82
# 4               Apple iPhone 14  ₹72,990     81
# ...                         ...      ...    ...
# 1015            Eunity U1 Pulse     ₹699    NaN
# 1016           Karbonn KX51 Pro   ₹1,349    NaN
# 1017            Snexian Rock 4G   ₹2,499    NaN
# 1018             Eunity U1 Wave     ₹849    NaN
# 1019             iKall K460 New   ₹6,199    NaN
#
#                                           sim  \
# 0          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...                                       ...
# 1015                                 Dual Sim
# 1016                                 Dual Sim
# 1017                  Dual Sim, 3G, 4G, VoLTE
# 1018                                 Dual Sim
# 1019           Dual Sim, 3G, 4G, VoLTE, Wi-Fi
#
#                                           processor                       ram  \
# 0      Snapdragon 695, Octa Core, 2.2 GHz Processor  6 GB RAM, 128 GB inbuilt
# 1         Exynos 1330, Octa Core, 2.4 GHz Processor   4 GB RAM, 64 GB inbuilt
# 2     Snapdragon  695, Octa Core, 2.2 GHz Processor  6 GB RAM, 128 GB inbuilt
# 3      Dimensity 1080, Octa Core, 2.6 GHz Processor  6 GB RAM, 128 GB inbuilt
# 4         Bionic A15, Hexa Core, 3.22 GHz Processor  6 GB RAM, 128 GB inbuilt
# ...                                             ...                       ...
# 1015                             1.77 MHz Processor  16 MB RAM, 16 MB inbuilt
# 1016                              1.1 MHz Processor  32 MB RAM, 32 MB inbuilt
# 1017                                        No Wifi           1 MHz Processor
# 1018                             1.77 MHz Processor  16 MB RAM, 16 MB inbuilt
# 1019                   Quad Core, 1.3 GHz Processor   4 GB RAM, 32 GB inbuilt
#
#                                       battery  \
# 0     5000 mAh Battery with 33W Fast Charging
# 1     5000 mAh Battery with 15W Fast Charging
# 2         5000 mAh Battery with Fast Charging
# 3     5000 mAh Battery with 67W Fast Charging
# 4         3279 mAh Battery with Fast Charging
# ...                                       ...
# 1015                         3000 mAh Battery
# 1016                         1800 mAh Battery
# 1017                 32 MB RAM, 32 MB inbuilt
# 1018                         3000 mAh Battery
# 1019                         4000 mAh Battery
#
#                                                 display  \
# 0     6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 1     6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 2     6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 3     6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# 4     6.1 inches, 1170 x 2532 px Display with Small ...
# ...                                                 ...
# 1015                   1.8 inches, 176 x 220 px Display
# 1016                   2.4 inches, 240 x 320 px Display
# 1017                                   2500 mAh Battery
# 1018                   2.4 inches, 320 x 480 px Display
# 1019                 6.26 inches, 720 x 1520 px Display
#
#                                                  camera  \
# 0     64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 1     50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 2     50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 3     108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
# 4          12 MP + 12 MP Dual Rear & 12 MP Front Camera
# ...                                                 ...
# 1015                                 0.3 MP Rear Camera
# 1016                                 0.3 MP Rear Camera
# 1017                   2.8 inches, 240 x 320 px Display
# 1018                                 0.3 MP Rear Camera
# 1019                     13 MP Rear & 8 MP Front Camera
#
#                                     card                                 os
# 0        Memory Card (Hybrid), upto 1 TB                        Android v12
# 1       Memory Card Supported, upto 1 TB                        Android v13
# 2        Memory Card (Hybrid), upto 1 TB                        Android v12
# 3              Memory Card Not Supported                        Android v13
# 4              Memory Card Not Supported                            iOS v16
# ...                                  ...                                ...
# 1015                                 NaN                                NaN
# 1016   Memory Card Supported, upto 32 GB                                NaN
# 1017                  0.3 MP Rear Camera  Memory Card Supported, upto 32 GB
# 1018                                 NaN                                NaN
# 1019  Memory Card Supported, upto 128 GB                        Android v10
#
# [1020 rows x 11 columns]
