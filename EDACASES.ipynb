# %% [markdown]
# Importing all libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
#importing the Dataset

# %%
df = pd.read_csv('DataSets/smartphone_cleaned_v2.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df = pd.read_csv('DataSets/smartphone_cleaned_v2.csv')
#
# File ~/.local/lib/python3.8/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
df.head()
# Out:
#    level_0 brand_name                      model  price  rating  \
# 0        0    oneplus              OnePlus 11 5G  54999    89.0
# 1        1    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2        2    samsung      Samsung Galaxy A14 5G  16499    75.0
# 3        3   motorola       Motorola Moto G62 5G  14999    81.0
# 4        4     realme         Realme 10 Pro Plus  24999    82.0
#
#    has_ir_blaster  has_5g  has_nfc     processor_name processor_brand  ...  \
# 0           False    True     True  Snapdragon 8 Gen2      snapdragon  ...
# 1           False    True    False     Snapdragon 695      snapdragon  ...
# 2           False    True    False        Exynos 1330          exynos  ...
# 3           False    True    False    Snapdragon  695      snapdragon  ...
# 4           False    True    False     Dimensity 1080       dimensity  ...
#
#      resolution  refresh_rate  num_rear_cameras  num_front_cameras       os  \
# ...

# %%
df.shape
# Out:
# (975, 27)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 975 entries, 0 to 974
# Data columns (total 27 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   level_0               975 non-null    int64
#  1   brand_name            975 non-null    object
#  2   model                 975 non-null    object
#  3   price                 975 non-null    int64
#  4   rating                875 non-null    float64
#  5   has_ir_blaster        975 non-null    bool
#  6   has_5g                975 non-null    bool
#  7   has_nfc               975 non-null    bool
#  8   processor_name        955 non-null    object
#  9   processor_brand       955 non-null    object
#  10  num_corse             968 non-null    object
#  11  processor_speeds      932 non-null    float64
#  12  battery_capacity      964 non-null    float64
#  13  fast_charging         975 non-null    float64
#  14  ram_capasity          975 non-null    float64
# ...

# %%
df.columns
# Out:
# Index(['level_0', 'brand_name', 'model', 'price', 'rating', 'has_ir_blaster',
#        'has_5g', 'has_nfc', 'processor_name', 'processor_brand', 'num_corse',
#        'processor_speeds', 'battery_capacity', 'fast_charging', 'ram_capasity',
#        'internal_memoryy', 'screen_size', 'resolution', 'refresh_rate',
#        'num_rear_cameras', 'num_front_cameras', 'os', 'ram_capacity',
#        'internal_memory', 'primary_camera_rear', 'primary_camera_front',
#        'extended_memory'],
#       dtype='object')

# %%
df.sample(4)
# Out:
#      level_0 brand_name                            model  price  rating  \
# 789      820      tecno               Tecno Camon 19 Neo  14999    77.0
# 883      922     xiaomi          Xiaomi Redmi Note 8 Pro  16999    78.0
# 210      212     realme    Realme 9 5G (6GB RAM + 128GB)  15499    79.0
# 787      818      nokia  Nokia C21 Plus (4GB RAM + 64GB)   8999    64.0
#
#      has_ir_blaster  has_5g  has_nfc     processor_name processor_brand  ...  \
# 789           False   False     True         Helio  G85           helio  ...
# 883            True   False    False        Helio  G90T           helio  ...
# 210           False    True    False  Dimensity  810 5G       dimensity  ...
# 787           False   False    False    Unisoc  SC9863A          unisoc  ...
#
#        resolution  refresh_rate  num_rear_cameras  num_front_cameras       os  \
# 789  1080 x 2400             90                 3                  1  android
# ...
