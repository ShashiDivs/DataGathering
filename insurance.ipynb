# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df = pd.read_csv('DataSets/insurance_data - insurance_data.csv')
df.head()
# Out:
#    index  PatientID   age gender   bmi  bloodpressure diabetic  children  \
# 0      0          1  39.0   male  23.2             91      Yes         0
# 1      1          2  24.0   male  30.1             87       No         0
# 2      2          3   NaN   male  33.3             82      Yes         0
# 3      3          4   NaN   male  33.7             80       No         0
# 4      4          5   NaN   male  34.1            100       No         0
#
#   smoker     region    claim
# 0     No  southeast  1121.87
# 1     No  southeast  1131.51
# 2     No  southeast  1135.94
# 3     No  northwest  1136.40
# 4     No  northwest  1137.01

# %% [markdown]
# 1) Show records of 'male' patient from 'southwest' region.

# %%
df[(df['gender']=='male') & (df['region']=='southeast')]
# Out:
#       index  PatientID   age gender   bmi  bloodpressure diabetic  children  \
# 0         0          1  39.0   male  23.2             91      Yes         0
# 1         1          2  24.0   male  30.1             87       No         0
# 2         2          3   NaN   male  33.3             82      Yes         0
# 19       19         20  48.0   male  33.3             91      Yes         0
# 20       20         21  45.0   male  23.2             85      Yes         0
# ...     ...        ...   ...    ...   ...            ...      ...       ...
# 1327   1327       1328  49.0   male  40.9            107       No         0
# 1328   1328       1329  45.0   male  42.1            117       No         1
# 1331   1331       1332  18.0   male  41.1            104       No         1
# 1332   1332       1333  26.0   male  37.0            120       No         2
# 1338   1338       1339  37.0   male  30.4            106       No         0
#
#      smoker     region     claim
# ...

# %% [markdown]
# 2) Show all records having bmi in range 30 to 45 both inclusive.

# %%
df[df['bmi'].between(30,45)]
# Out:
#       index  PatientID   age  gender   bmi  bloodpressure diabetic  children  \
# 1         1          2  24.0    male  30.1             87       No         0
# 2         2          3   NaN    male  33.3             82      Yes         0
# 3         3          4   NaN    male  33.7             80       No         0
# 4         4          5   NaN    male  34.1            100       No         0
# 5         5          6   NaN    male  34.4             96      Yes         0
# ...     ...        ...   ...     ...   ...            ...      ...       ...
# 1334   1334       1335  43.0    male  32.8            125       No         0
# 1335   1335       1336  44.0  female  35.5             88      Yes         0
# 1336   1336       1337  59.0  female  38.1            120       No         1
# 1337   1337       1338  30.0    male  34.5             91      Yes         3
# 1338   1338       1339  37.0    male  30.4            106       No         0
#
#      smoker     region     claim
# ...

# %% [markdown]
# 3) Show minimum and maximum bloodpressure of diabetic patient who smokes. Make column names as MinBP and MaxBP respectively.

# %%
df.head()
# Out:
#    index  PatientID   age gender   bmi  bloodpressure diabetic  children  \
# 0      0          1  39.0   male  23.2             91      Yes         0
# 1      1          2  24.0   male  30.1             87       No         0
# 2      2          3   NaN   male  33.3             82      Yes         0
# 3      3          4   NaN   male  33.7             80       No         0
# 4      4          5   NaN   male  34.1            100       No         0
#
#   smoker     region    claim
# 0     No  southeast  1121.87
# 1     No  southeast  1131.51
# 2     No  southeast  1135.94
# 3     No  northwest  1136.40
# 4     No  northwest  1137.01

# %%
df.pivot_table(index='gender',columns='smoker',values='claim',aggfunc='sum',margins=True)
# Out:
# smoker          No         Yes          All
# gender
# female  4792976.66  3528084.57   8321061.23
# male    4183938.94  5253678.99   9437617.93
# All     8976915.60  8781763.56  17758679.16
