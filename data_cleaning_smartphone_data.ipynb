# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('DataSets/smartphones.csv')

# %%
df.head()
# Out:
#                        model    price  rating  \
# 0              OnePlus 11 5G  ₹54,999    89.0
# 1  OnePlus Nord CE 2 Lite 5G  ₹19,989    81.0
# 2      Samsung Galaxy A14 5G  ₹16,499    75.0
# 3       Motorola Moto G62 5G  ₹14,999    81.0
# 4         Realme 10 Pro Plus  ₹24,999    82.0
#
#                                        sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 4     Dimensity 1080, Octa Core, 2.6 GHz Processor   6 GB RAM, 128 GB inbuilt
#
#                                     battery  \
# 0  5000 mAh Battery with 100W Fast Charging
# 1   5000 mAh Battery with 33W Fast Charging
# 2   5000 mAh Battery with 15W Fast Charging
# 3       5000 mAh Battery with Fast Charging
# 4   5000 mAh Battery with 67W Fast Charging
#
#                                              display  \
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 2  6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 3  6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 4  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
#
#                                               camera  \
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 2  50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 3  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4  108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
#
#                                card           os
# 0         Memory Card Not Supported  Android v13
# 1   Memory Card (Hybrid), upto 1 TB  Android v12
# 2  Memory Card Supported, upto 1 TB  Android v13
# 3   Memory Card (Hybrid), upto 1 TB  Android v12
# 4         Memory Card Not Supported  Android v13

# %% [markdown]
# ## Data Assessing
#
# ### Quality Issues
#
# 1. **model** - some brands are written diiferently like OPPO in model column
# 2. **price** - has unneccesary '₹'
# 3. **price** - has ',' between numbers
# 4. **price** - phone Namotel has a price of 99
# 5. **ratings** - missing values
# 6. **processor** - has some incorrect values for some samsung phones(row # -642,647,649,659,667,701,750,759,819,859,883,884,919,927,929,932,1002)
# 7. There is ipod on row 756
# 8. **memory** - incorrect values in rows (441,485,534,553,584,610,613,642,647,649,659,667,701,750,759,819,859,884,919,927,929,932,990,1002)
# 9. **battery** - incorrect values in rows(113,151,309,365,378,441,450,553,584,610,613,630,642,647,649,659,667,701,750,756,759,764,819,855,859,884,915,916,927,929,932,990,1002)
# 10. **display** - sometimes frequency is not available
# 11. **display** - incorrect values in rows(378,441,450,553,584,610,613,630,642,647,649,659,667,701,750,759,764,819,859,884,915,916,927,929,932,990,1002)
# 12. certain phones are foldable and the info is scattered
# 13. **camera** - words like Dual, Triple and Quad are used to represent number of cameras and front and rear cameras are separated by '&'
# 14. **camera** - problem with rows (100,113,151,157,161,238,273,308,309,323,324,365,367,378,394,441,450,484,506,534,553,571,572,575,584,610,613,615,630,642,647,649,659,667,684,687,705,711,723,728,750,756,759,764,792,819,846,854,855,858,883,884,896,915,916,927,929,932,945,956,990,995,1002,1016
# )
# 15. **card** - sometimes contains info about os and camera
# 16. **os** - sometimes contains info about bluetooth and fm radio
# 17. **os** - issue with rows (324,378)
# 18. **os** - sometimes contains os version name like lollipop
# 19. missing values in camera card too
# 20. datatype and pricing incorrect
#
#
#
# ### Tidiness Issues
#
# 1. **sim** - can be split into 3 cols has_5g, has_NFC, has_IR_Blaster
# 2. **ram** - can be split into 2 cols RAM and ROM
# 3. **processor** - can be split into processor name, cores and cpu speed.
# 4. **battery** - can be split into battery capacity, fast_charging_available
# 5. **display** - can be split into size, resolution_width, resolution_height and frequency
# 6. **camera** - can be split into front and rear camera
# 7. **card** - can be split into supported, extended_upto

# %%
df.sample(2)
# Out:
#                                 model    price  rating  \
# 393  Samsung Galaxy M32 Prime Edition  ₹12,120    75.0
# 640                    Nokia 105 Plus   ₹1,299     NaN
#
#                                 sim                              processor  \
# 393  Dual Sim, 3G, 4G, VoLTE, Wi-Fi  Helio G80, Octa Core, 2 GHz Processor
# 640                        Dual Sim                 4 MB RAM, 4 MB inbuilt
#
#                          ram                                  battery  \
# 393  4 GB RAM, 64 GB inbuilt  6000 mAh Battery with 15W Fast Charging
# 640          800 mAh Battery        1.77 inches, 128 x 160 px Display
#
#                                                display  \
# 393  6.4 inches, 1080 x 2400 px, 90 Hz Display with...
# 640                                     No Rear Camera
#
#                                    camera                              card  \
# 393  64 MP Quad Rear & 20 MP Front Camera  Memory Card Supported, upto 1 TB
# 640     Memory Card Supported, upto 32 GB                         Bluetooth
#
#               os
# 393  Android v11
# 640          NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   model      1020 non-null   object
#  1   price      1020 non-null   object
#  2   rating     879 non-null    float64
#  3   sim        1020 non-null   object
#  4   processor  1020 non-null   object
#  5   ram        1020 non-null   object
#  6   battery    1020 non-null   object
#  7   display    1020 non-null   object
#  8   camera     1019 non-null   object
#  9   card       1013 non-null   object
#  10  os         1003 non-null   object
# dtypes: float64(1), object(10)
# memory usage: 87.8+ KB

# %%
df.columns
# Out:
# Index(['model', 'price', 'rating', 'sim', 'processor', 'ram', 'battery',
#        'display', 'camera', 'card', 'os'],
#       dtype='object')

# %%
df.describe()
# Out:
#            rating
# count  879.000000
# mean    78.258248
# std      7.402854
# min     60.000000
# 25%     74.000000
# 50%     80.000000
# 75%     84.000000
# max     89.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   model      1020 non-null   object
#  1   price      1020 non-null   object
#  2   rating     879 non-null    float64
#  3   sim        1020 non-null   object
#  4   processor  1020 non-null   object
#  5   ram        1020 non-null   object
#  6   battery    1020 non-null   object
#  7   display    1020 non-null   object
#  8   camera     1019 non-null   object
#  9   card       1013 non-null   object
#  10  os         1003 non-null   object
# dtypes: float64(1), object(10)
# memory usage: 87.8+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['model', 'price', 'rating', 'sim', 'processor', 'ram', 'battery',
#        'display', 'camera', 'card', 'os'],
#       dtype='object')

# %%
df
# Out:
#                                 model    price  rating  \
# 0                       OnePlus 11 5G  ₹54,999    89.0
# 1           OnePlus Nord CE 2 Lite 5G  ₹19,989    81.0
# 2               Samsung Galaxy A14 5G  ₹16,499    75.0
# 3                Motorola Moto G62 5G  ₹14,999    81.0
# 4                  Realme 10 Pro Plus  ₹24,999    82.0
# ...                               ...      ...     ...
# 1015       Motorola Moto Edge S30 Pro  ₹34,990    83.0
# 1016                      Honor X8 5G  ₹14,990    75.0
# 1017  POCO X4 GT 5G (8GB RAM + 256GB)  ₹28,990    85.0
# 1018             Motorola Moto G91 5G  ₹19,990    80.0
# 1019           Samsung Galaxy M52s 5G  ₹24,990    74.0
#
#                                                     sim  \
# 0               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...                                                 ...
# 1015                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1016                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1017  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 1018            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1019                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                             processor  \
# 0     Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor
# 1        Snapdragon 695, Octa Core, 2.2 GHz Processor
# 2           Exynos 1330, Octa Core, 2.4 GHz Processor
# 3       Snapdragon  695, Octa Core, 2.2 GHz Processor
# 4        Dimensity 1080, Octa Core, 2.6 GHz Processor
# ...                                               ...
# 1015    Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 1016   Snapdragon  480+, Octa Core, 2.2 GHz Processor
# 1017    Dimensity 8100, Octa Core, 2.85 GHz Processor
# 1018     Snapdragon 695, Octa Core, 2.2 GHz Processor
# 1019                              Octa Core Processor
#
#                             ram                                    battery  \
# 0     12 GB RAM, 256 GB inbuilt   5000 mAh Battery with 100W Fast Charging
# 1      6 GB RAM, 128 GB inbuilt    5000 mAh Battery with 33W Fast Charging
# 2       4 GB RAM, 64 GB inbuilt    5000 mAh Battery with 15W Fast Charging
# 3      6 GB RAM, 128 GB inbuilt        5000 mAh Battery with Fast Charging
# 4      6 GB RAM, 128 GB inbuilt    5000 mAh Battery with 67W Fast Charging
# ...                         ...                                        ...
# 1015   8 GB RAM, 128 GB inbuilt  5000 mAh Battery with 68.2W Fast Charging
# 1016   6 GB RAM, 128 GB inbuilt  5000 mAh Battery with 22.5W Fast Charging
# 1017   8 GB RAM, 256 GB inbuilt    5080 mAh Battery with 67W Fast Charging
# 1018   6 GB RAM, 128 GB inbuilt        5000 mAh Battery with Fast Charging
# 1019   8 GB RAM, 128 GB inbuilt        5000 mAh Battery with Fast Charging
#
#                                                 display  \
# 0     6.7 inches, 1440 x 3216 px, 120 Hz Display wit...
# 1     6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 2     6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 3     6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 4     6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# ...                                                 ...
# 1015  6.67 inches, 1080 x 2460 px, 120 Hz Display wi...
# 1016  6.5 inches, 720 x 1600 px Display with Water D...
# 1017  6.6 inches, 1080 x 2460 px, 144 Hz Display wit...
# 1018  6.8 inches, 1080 x 2400 px Display with Punch ...
# 1019  6.5 inches, 1080 x 2400 px Display with Water ...
#
#                                                  camera  \
# 0     50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# 1     64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 2     50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 3     50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4     108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
# ...                                                 ...
# 1015  64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 1016  48 MP + 2 MP + Depth Sensor Triple Rear & 8 MP...
# 1017  64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 1018  108 MP + 8 MP + 2 MP Triple Rear & 32 MP Front...
# 1019  64 MP + 8 MP + 5 MP Triple Rear & 32 MP Front ...
#
#                                   card           os
# 0            Memory Card Not Supported  Android v13
# 1      Memory Card (Hybrid), upto 1 TB  Android v12
# 2     Memory Card Supported, upto 1 TB  Android v13
# 3      Memory Card (Hybrid), upto 1 TB  Android v12
# 4            Memory Card Not Supported  Android v13
# ...                                ...          ...
# 1015                       Android v12  No FM Radio
# 1016  Memory Card Supported, upto 1 TB  Android v11
# 1017         Memory Card Not Supported  Android v12
# 1018  Memory Card Supported, upto 1 TB  Android v12
# 1019  Memory Card Supported, upto 1 TB  Android v12
#
# [1020 rows x 11 columns]

# %%
#make a copy
df1 = df.copy()

# %%
df1.head(2)
# Out:
#    index brand_name                      model  price  rating  \
# 0      2    oneplus              OnePlus 11 5G  54999    89.0
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
#
#                                        sim  has_ir_blaster  has_5g  has_nfc  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False    True     True
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
#
#                                     battery  \
# 0  5000 mAh Battery with 100W Fast Charging
# 1   5000 mAh Battery with 33W Fast Charging
#
#                                              display  \
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
#
#                                               camera  \
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
#
#                               card           os
# 0        Memory Card Not Supported  Android v13
# 1  Memory Card (Hybrid), upto 1 TB  Android v12

# %%
df1['price'] = df1['price'].str.replace("₹","").str.replace(',',"").astype('int')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 df1['price'] = df1['price'].str.replace("₹","").str.replace(',',"").astype('int')
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/accessor.py:182, in CachedAccessor.__get__(self, obj, cls)
#     179 if obj is None:
#     180     # we're accessing the attribute of the class, i.e., Dataset.geo
#     181     return self._accessor
# --> 182 accessor_obj = self._accessor(obj)
#     183 # Replace the property with the accessor object. Inspired by:
#     184 # https://www.pydanny.com/cached-property.html
#     185 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     186 # NDFrame
#     187 object.__setattr__(obj, self._name, accessor_obj)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/strings/accessor.py:181, in StringMethods.__init__(self, data)
#     178 def __init__(self, data) -> None:
#     179     from pandas.core.arrays.string_ import StringDtype
# --> 181     self._inferred_dtype = self._validate(data)
#     182     self._is_categorical = is_categorical_dtype(data.dtype)
#     183     self._is_string = isinstance(data.dtype, StringDtype)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/strings/accessor.py:235, in StringMethods._validate(data)
#     232 inferred_dtype = lib.infer_dtype(values, skipna=True)
#     234 if inferred_dtype not in allowed_types:
# --> 235     raise AttributeError("Can only use .str accessor with string values!")
#     236 return inferred_dtype
#
# AttributeError: Can only use .str accessor with string values!

# %%
df['sim']
# Out:
# 0                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1                      Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2                      Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3                      Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4                      Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 5                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 6                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 7          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 8                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 9                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 10                     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 11                Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 12         Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 13                     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 14          Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC
# 15                Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 16                         Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 17                Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 18                Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 19                         Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 20                Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 21                     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 22         Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 23         Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 24                Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 25                Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 26                     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 27                Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 28                     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 29                Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 30                     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 31      Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 32                     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 33                    Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC
# 34                     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 35                Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 36                Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 37                Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 38         Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 39                Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 40                Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 41         Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 42                Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 43                     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 44                         Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 45                Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 46             Dual Sim, 3G, 4G, VoLTE, Wi-Fi, IR Blaster
# 47                         Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 48                         Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 49                Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 50                     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 51      Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 52                     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 53                Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 54                         Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 55                     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 56                Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 57             Dual Sim, 3G, 4G, VoLTE, Wi-Fi, IR Blaster
# 58          Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC
# 59                         Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 60      Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 61                Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 62                         Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 63                         Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 64         Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 65                Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 66                Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 67         Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 68                Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 69                Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 70                         Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 71                     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 72                     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 73                Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 74         Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 75                         Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 76                Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 77                     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 78                Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 79                         Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 80                    Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC
# 81                     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 82                     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 83                     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 84                     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 85                Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 86                     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 87                     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 88             Dual Sim, 3G, 4G, VoLTE, Wi-Fi, IR Blaster
# 89                Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 90                         Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 91                Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 92                     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 93      Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 94                         Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 95                         Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 96                         Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 97                Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 98                Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 99                     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 100               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 101        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 102                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 103                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 104                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 105     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 106                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 107               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 108                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 109               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 110               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 111               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 112        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 113               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 114                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 115               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 116                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 117                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 118               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 119         Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC
# 120               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 121               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 122               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 123                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 124               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 125                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 126                   Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC
# 127                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 128               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 129               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 130        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 131            Dual Sim, 3G, 4G, VoLTE, Wi-Fi, IR Blaster
# 132                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 133               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 134        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 135        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 136                   Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC
# 137                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 138                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 139        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 140                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 141               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 142        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 143                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 144                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 145                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 146               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 147               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 148                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 149               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 150        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 151                   Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC
# 152               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 153               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 154                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 155                               Dual Sim, 3G, 4G, Wi-Fi
# 156                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 157                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 158                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 159               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 160                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 161                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 162               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 163               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 164     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 165                   Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC
# 166            Dual Sim, 3G, 4G, VoLTE, Wi-Fi, IR Blaster
# 167                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 168               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 169                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 170                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 171        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 172                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 173                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 174                 Single Sim, 3G, 4G, VoLTE, Wi-Fi, NFC
# 175                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 176            Dual Sim, 3G, 4G, VoLTE, Wi-Fi, IR Blaster
# 177                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 178                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 179                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 180            Dual Sim, 3G, 4G, VoLTE, Wi-Fi, IR Blaster
# 181                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 182                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 183               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 184               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 185                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 186               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 187               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 188                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 189                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 190                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 191                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 192                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 193                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 194               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 195                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 196               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 197                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 198        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 199                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 200                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 201                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 202               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 203     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 204                   Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC
# 205        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 206               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 207               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 208                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 209        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 210               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 211                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 212                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 213                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 214                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 215     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 216               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 217                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 218                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 219                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 220     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 221                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 222                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 223               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 224            Dual Sim, 3G, 4G, VoLTE, Wi-Fi, IR Blaster
# 225                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 226                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 227                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 228                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 229               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 230               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 231     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 232                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 233            Dual Sim, 3G, 4G, VoLTE, Wi-Fi, IR Blaster
# 234                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 235                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 236     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 237                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 238               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 239                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 240     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 241                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 242               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 243                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 244               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 245        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 246                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 247               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 248               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 249               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 250                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 251               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 252                   Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC
# 253                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 254        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 255               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 256               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 257               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 258                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 259                   Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC
# 260        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 261                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 262                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 263                   Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC
# 264               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 265                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 266               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 267               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 268            Dual Sim, 3G, 4G, VoLTE, Wi-Fi, IR Blaster
# 269               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 270                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 271                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 272               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 273                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 274        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 275        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 276     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 277               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 278                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 279                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 280               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 281                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 282                   Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC
# 283        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 284               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 285                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 286        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 287     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 288                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 289                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 290               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 291                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 292        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 293            Dual Sim, 3G, 4G, VoLTE, Wi-Fi, IR Blaster
# 294                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 295                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 296               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 297                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 298     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 299                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 300                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 301        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 302                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 303               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 304                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 305     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 306             Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 307               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 308               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 309                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 310               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 311               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 312               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 313               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 314               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 919               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 920               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 921                   Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC
# 922            Dual Sim, 3G, 4G, VoLTE, Wi-Fi, IR Blaster
# 923                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 924                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 925                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 926                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 927                                            Single Sim
# 928         Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC
# 929               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 930                               Dual Sim, 3G, 4G, VoLTE
# 931                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 932                                              Dual Sim
# 933               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 934               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 935                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 936                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 937                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 938                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 939               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 940                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 941     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 942                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 943               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 944               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 945               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 946               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 947               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 948                   Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC
# 949                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 950                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 951     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 952                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 953                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 954               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 955                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 956                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 957                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 958                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 959        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 960                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 961               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 962               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 963                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 964                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 965                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 966                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 967        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 968               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 969                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 970                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 971               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 972                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 973                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 974               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 975             Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 976                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 977                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 978                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 979                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 980                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 981                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 982                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 983                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 984                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 985     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 986                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 987                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 988                                              Dual Sim
# 989                   Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC
# 990     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 991                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 992                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 993     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 994                   Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC
# 995                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 996                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 997                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 998               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 999                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 1000                                             Dual Sim
# 1001                   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1002                  Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC
# 1003                       Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 1004              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1005                       Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 1006                         Dual Sim, 3G, 4G, Wi-Fi, NFC
# 1007    Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC,...
# 1008        Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC
# 1009    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 1010                       Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 1011              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1012                              Dual Sim, 3G, 4G, Wi-Fi
# 1013              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1014              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1015                   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1016                   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1017    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 1018              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1019                   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# Name: sim, dtype: object

# %%
df1 = df1.reset_index()

# %%
df1['index'] = df1['index'] + 2

# %%
df1.head(2)
# Out:
#    level_0  index brand_name                      model  price  rating  \
# 0        0      4    oneplus              OnePlus 11 5G  54999    89.0
# 1        1      5    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
#
#                                        sim  has_ir_blaster  has_5g  has_nfc  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False    True     True
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
#
#                                     battery  \
# 0  5000 mAh Battery with 100W Fast Charging
# 1   5000 mAh Battery with 33W Fast Charging
#
#                                              display  \
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
#
#                                               camera  \
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
#
#                               card           os
# 0        Memory Card Not Supported  Android v13
# 1  Memory Card (Hybrid), upto 1 TB  Android v12

# %%
processor_rows = set((642,647,649,659,667,701,750,759,819,859,883,884,919,927,929,932,1002))
ram_rows = set((441,485,534,553,584,610,613,642,647,649,659,667,701,750,759,819,859,884,919,927,929,932,990,1002))
battery_rows = set((113,151,309,365,378,441,450,553,584,610,613,630,642,647,649,659,667,701,750,756,759,764,819,855,859,884,915,916,927,929,932,990,1002))
display_rows = set((378,441,450,553,584,610,613,630,642,647,649,659,667,701,750,759,764,819,859,884,915,916,927,929,932,990,1002))
camera_rows = set((100,113,151,157,161,238,273,308,309,323,324,365,367,378,394,441,450,484,506,534,553,571,572,575,584,610,613,615,630,642,647,649,659,667,684,687,705,711,723,728,750,756,759,764,792,819,846,854,855,858,883,884,896,915,916,927,929,932,945,956,990,995,1002,1016 ))

# %%
df1[df1['index'].isin(processor_rows | ram_rows | battery_rows | display_rows | camera_rows)]
# Out:
#      level_0  index brand_name  \
# 96        96    100       oppo
# 109      109    113    oneplus
# 147      147    151    samsung
# 153      153    157       oppo
# 156      157    161       oppo
# 233      234    238       oppo
# 268      269    273    nothing
# 302      304    308     xiaomi
# 303      305    309     xiaomi
# 317      319    323      honor
# 318      320    324       iqoo
# 359      361    365     xiaomi
# 646                               Infinix Hot 12 Pro   10850    74.0
# 662                                     LG Velvet 5G   54999    85.0
# 665                      Samsung Galaxy Note 10 Lite   39999    83.0
# 678                             Infinix Smart 6 Plus    8299    63.0
# 681                                        Nokia G21   11999    71.0
# 687                          Samsung Galaxy M21 2021   11725    76.0
# 699                                      Vivo T3 Pro   31990    86.0
# 704                            Huawei Mate 50 Pro 5G   99990    85.0
# 726                             Xiaomi Mi 10T Pro 5G   29999    86.0
# 731                                        Realme XT   13279    75.0
# 733                 Xiaomi Poco F1 (6GB RAM + 128GB)   12999    78.0
# 737                                     Vivo S17 Pro   49990    77.0
# 765                       OPPO A54 (4GB RAM + 128GB)   11990    71.0
# 792                         Xiaomi Redmi 13 Prime 5G   17990    79.0
# 817                Realme GT Explorer Master Edition   32990    85.0
# 824                               Samsung Galaxy M62   23999    83.0
# 825                                       Realme Q2i    9999    69.0
# 827                Xiaomi Redmi 9i (4GB RAM + 128GB)    9299    67.0
# 828                        Realme 6 (6GB RAM + 64GB)   12989    77.0
# 850                                        Nokia X30   41990    85.0
# 851                                 Tecno Pova Neo 2   13990    67.0
# 861                         Xiaomi Redmi Note 12T 5G   15999    78.0
# 880                               Samsung Galaxy M12   10999    72.0
# 881                                OnePlus Nord N100   16990    68.0
# 884                                         OPPO A15    9999    66.0
# 891                                        Realme A1    8999     NaN
# 894                             Apple iPhone 15 Plus   84990    75.0
# 905                                    Xiaomi Civi 2   29999    85.0
# 916                                       iQOO Z8 5G   14999    78.0
# 950                                  Vivo Y21 (2020)    9990    65.0
# 954                               Samsung Galaxy A11    9990    63.0
# 961                             Blackview BV5200 Pro    8990    67.0
# 974                                        itel A23s    4787     NaN
#
#                                                    sim  has_ir_blaster  \
# 96                      Dual Sim, 3G, 4G, VoLTE, Wi-Fi           False
# 109            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False
# 147            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False
# 153            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False
# 156                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False
# 233                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False
# 268            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False
# 302                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi           False
# 303  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...            True
# 317            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False
# 318            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False
# 359  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...            True
# 361            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False
# 372                Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC           False
# 387                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False
# 433                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi           False
# 442     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster            True
# 475                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi           False
# 476                            Dual Sim, 3G, 4G, Wi-Fi           False
# 497                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi           False
# 525                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi           False
# 542                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False
# 559            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False
# 560            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False
# 563         Dual Sim, 3G, 4G, VoLTE, Wi-Fi, IR Blaster            True
# 570            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False
# 595                Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC           False
# 597                Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC           False
# 613                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False
# 625                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi           False
# 629  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...            True
# 639                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi           False
# 646                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi           False
# 662            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False
# 665                Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC           False
# 678                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi           False
# 681                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi           False
# 687                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi           False
# 699           Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi           False
# 704            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False
# 726  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...            True
# 731                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi           False
# 733                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi           False
# 737            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False
# 765                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi           False
# 792     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster            True
# 817            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False
# 824                Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC           False
# 825                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False
# 827                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi           False
# 828                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi           False
# 850            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False
# 851                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi           False
# 861     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster            True
# 880                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi           False
# 881                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi           False
# 884                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi           False
# 891                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi           False
# 894      Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC           False
# 905  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...            True
# 916                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False
# 950                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi           False
# 954                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi           False
# 961            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False
# 974                            Dual Sim, 3G, 4G, Wi-Fi           False
#
#      has_5g  has_nfc                                          processor  \
# 96    False    False            Helio G35, Octa Core, 2.3 GHz Processor
# 109    True     True  Dimensity 8100 Max, Octa Core, 2.85 GHz Processor
# 147    True     True          Exynos 1200, Octa Core, 2.4 GHz Processor
# 153    True     True      Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 156    True    False       Snapdragon 695, Octa Core, 2.2 GHz Processor
# 233    True    False     Dimensity 700 5G, Octa Core, 2.2 GHz Processor
# 268    True     True   Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor
# 302   False    False       Snapdragon 680, Octa Core, 2.4 GHz Processor
# 303    True     True    Snapdragon  778G , Octa Core, 2.4 GHz Processor
# 317    True     True       Snapdragon 695, Octa Core, 2.2 GHz Processor
# 318    True     True    Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor
# 359    True     True  Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 361    True     True           Bionic A14, Hexa Core, 3.1 GHz Processor
# 372   False     True       Snapdragon 855, Octa Core, 2.8 GHz Processor
# 387    True    False     Dimensity 700 5G, Octa Core, 2.2 GHz Processor
# 433   False    False            Helio G37, Octa Core, 2.3 GHz Processor
# 442    True    False       Dimensity 1080, Octa Core, 2.6 GHz Processor
# 475   False    False              Helio A22, Quad Core, 2 GHz Processor
# 476   False    False      Unisoc  SC9832E, Quad Core, 1.4 GHz Processor
# 497   False    False          Tiger T612, Octa Core, 1.82 GHz Processor
# 525   False    False    Snapdragon  720G , Octa Core, 2.3 GHz Processor
# 542    True    False    Dimensity  810 5G, Octa Core, 2.4 GHz Processor
# 559    True     True          Dimensity 720, Octa Core, 2 GHz Processor
# 560    True     True    Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor
# 563   False    False      Snapdragon 720G, Octa Core, 2.3 GHz Processor
# 570    True     True      Snapdragon  695, Octa Core, 2.2 GHz Processor
# 595   False     True          A13 Bionic, Hexa Core, 2.65 GHz Processor
# 597   False     True     Snapdragon 4 Gen 1, Octa Core, 2 GHz Processor
# 613    True    False       Dimensity 800U, Octa Core, 2.4 GHz Processor
# 625   False    False          Helio  G96, Octa Core, 2.05 GHz Processor
# 629    True     True    Snapdragon  888 , Octa Core, 2.84 GHz Processor
# 639   False    False            Helio G35, Octa Core, 2.3 GHz Processor
# 646   False    False             Tiger T616, Octa Core, 2 GHz Processor
# 662    True     True     Snapdragon  765G, Octa Core, 2.4 GHz Processor
# 665   False     True          Exynos 9810, Octa Core, 2.7 GHz Processor
# 678   False    False              Helio G25, Octa Core, 2 GHz Processor
# 681   False    False         Unisoc  T606, Octa Core, 1.6 GHz Processor
# 687   False    False          Exynos 9611, Octa Core, 2.3 GHz Processor
# 699    True    False     Snapdragon  782G, Octa Core, 2.7 GHz Processor
# 704    True     True         Kirin 9000E, Octa Core, 3.13 GHz Processor
# 726    True     True     Snapdragon 865 , Octa Core, 2.84 GHz Processor
# 731   False    False       Snapdragon 712, Octa Core, 2.3 GHz Processor
# 733   False    False       Snapdragon 845, Octa Core, 2.8 GHz Processor
# 737    True     True                Dimensity 9200, Octa Core Processor
# 765   False    False            Helio P35, Octa Core, 2.3 GHz Processor
# 792    True    False     Snapdragon 4 Gen 1, Octa Core, 2 GHz Processor
# 817    True     True      Snapdragon  870, Octa Core, 3.2 GHz Processor
# 824   False     True         Exynos 9825, Octa Core, 2.73 GHz Processor
# 825    True    False          Dimensity 720, Octa Core, 2 GHz Processor
# 827   False    False              Helio G25, Octa Core, 2 GHz Processor
# 828   False    False       Helio   G90T , Octa Core, 2.05 GHz Processor
# 850    True     True      Snapdragon  695, Octa Core, 2.2 GHz Processor
# 851   False    False              Helio G85, Octa Core, 2 GHz Processor
# 861    True    False          Dimensity 720, Octa Core, 2 GHz Processor
# 880   False    False            Exynos  850, Octa Core, 2 GHz Processor
# 881   False    False       Snapdragon 460, Octa Core, 1.8 GHz Processor
# 884   False    False            Helio P35, Octa Core, 2.3 GHz Processor
# 891   False    False            Helio P70, Octa Core, 2.1 GHz Processor
# 894    True     True                    Bionic A16, Hexa Core Processor
# 905    True     True    Snapdragon 7 Gen1, Octa Core, 2.4 GHz Processor
# 916    True    False     Snapdragon  695 , Octa Core, 2.2 GHz Processor
# 950   False    False       Snapdragon 450, Octa Core, 1.8 GHz Processor
# 954   False    False                       Octa Core, 1.8 GHz Processor
# 961    True     True            Helio G35, Octa Core, 2.3 GHz Processor
# 974   False    False  Spreadtrum  SC9832E, Quad Core, 1.4 GHz Processor
#
#                            ram                                   battery  \
# 96     4 GB RAM, 64 GB inbuilt       5000 mAh Battery with Fast Charging
# 109  12 GB RAM, 256 GB inbuilt   5000 mAh Battery with 80W Fast Charging
# 147   6 GB RAM, 128 GB inbuilt   6000 mAh Battery with 25W Fast Charging
# 153   8 GB RAM, 128 GB inbuilt   5000 mAh Battery with 67W Fast Charging
# 156   8 GB RAM, 128 GB inbuilt   4500 mAh Battery with 33W Fast Charging
# 233   6 GB RAM, 128 GB inbuilt   5000 mAh Battery with 33W Fast Charging
# 268   8 GB RAM, 128 GB inbuilt   4700 mAh Battery with 66W Fast Charging
# 302   6 GB RAM, 128 GB inbuilt   6000 mAh Battery with 18W Fast Charging
# 303   6 GB RAM, 128 GB inbuilt   4250 mAh Battery with 33W Fast Charging
# 317   8 GB RAM, 128 GB inbuilt   4800 mAh Battery with 66W Fast Charging
# 318  16 GB RAM, 256 GB inbuilt  5000 mAh Battery with 120W Fast Charging
# 359   8 GB RAM, 128 GB inbuilt  5000 mAh Battery with 120W Fast Charging
# 361   4 GB RAM, 128 GB inbuilt                                      None
# 372    6 GB RAM, 64 GB inbuilt       2800 mAh Battery with Fast Charging
# 387   8 GB RAM, 128 GB inbuilt   5000 mAh Battery with 18W Fast Charging
# 433    4 GB RAM, 64 GB inbuilt   5000 mAh Battery with 10W Fast Charging
# 442   6 GB RAM, 128 GB inbuilt  4980 mAh Battery with 120W Fast Charging
# 475    2 GB RAM, 32 GB inbuilt                          5000 mAh Battery
# 476    2 GB RAM, 32 GB inbuilt                          3020 mAh Battery
# 497    3 GB RAM, 32 GB inbuilt                          5000 mAh Battery
# 525   8 GB RAM, 128 GB inbuilt   4000 mAh Battery with 33W Fast Charging
# 542   6 GB RAM, 128 GB inbuilt   5000 mAh Battery with 33W Fast Charging
# 559   6 GB RAM, 128 GB inbuilt   5000 mAh Battery with 15W Fast Charging
# 560  12 GB RAM, 256 GB inbuilt  5000 mAh Battery with 165W Fast Charging
# 563    6 GB RAM, 64 GB inbuilt   5020 mAh Battery with 33W Fast Charging
# 570   6 GB RAM, 128 GB inbuilt   4500 mAh Battery with 20W Fast Charging
# 595    4 GB RAM, 64 GB inbuilt   3500 mAh Battery with 18W Fast Charging
# 597   8 GB RAM, 128 GB inbuilt   5000 mAh Battery with 33W Fast Charging
# 613   8 GB RAM, 128 GB inbuilt   4000 mAh Battery with 33W Fast Charging
6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# 156  6.43 inches, 1080 x 2400 px Display with Punch...
# 233  6.56 inches, 720 x 1612 px, 90 Hz Display with...
# 268  6.67 inches, 1080 x 2400 px, 120 Hz Display wi...
# 302  6.7 inches, 720 x 1600 px Display with Water D...
# 303  6.55 inches, 1080 x 2400 px, 90 Hz Display wit...
# 317                6.81 inches, 1080 x 2388 px Display
# 318  6.78 inches, 1440 x 3200 px, 144 Hz Display wi...
# 359  6.67 inches, 1220 x 2712 px, 120 Hz Display wi...
# 361                 5.4 inches, 1080 x 2340 px Display
# 372                 5.7 inches, 1080 x 2280 px Display
# 387  6.5 inches, 1080 x 2400 px, 90 Hz Display with...
# 433  6.5 inches, 720 x 1600 px, 90 Hz Display with ...
# 442  6.67 inches, 1080 x 2400 px, 120 Hz Display wi...
# 475  6.56 inches, 720 x 1600 px Display with Water ...
# 476                     5 inches, 854 x 480 px Display
# 497  6.52 inches, 720 x 1600 px Display with Water ...
# 525  6.44 inches, 1080 x 2400 px Display with Water...
# 542  6.5 inches, 1080 x 2400 px, 90 Hz Display with...
# 559  6.5 inches, 720 x 1600 px, 90 Hz Display with ...
# 560         6.8 inches, 1116 x 2480 px, 120 Hz Display
# 563  6.67 inches, 1080 x 2400 px Display with Punch...
# 570  6.58 inches, 1080 x 2400 px, 120 Hz Display wi...
# 595  6.5 inches, 1242 x 2688 px Display with Large ...
# 597         6.5 inches, 1080 x 2400 px, 120 Hz Display
# 613  6.44 inches, 1080 x 2400 px, 90 Hz Display wit...
# 625  6.8 inches, 1080 x 2460 px, 120 Hz Display wit...
# 629  6.67 inches, 1080 x 2400 px, 120 Hz Display wi...
# 639  6.53 inches, 720 x 1600 px Display with Water ...
# 646  6.6 inches, 720 x 1612 px, 90 Hz Display with ...
# 662  6.8 inches, 1080 x 2460 px Display with Water ...
# 665  6.7 inches, 1080 x 2400 px Display with Punch ...
# 678  6.82 inches, 720 x 1600 px Display with Water ...
# 681  6.5 inches, 720 x 1600 px, 90 Hz Display with ...
# 687  6.4 inches, 1080 x 2340 px Display with Water ...
# 699  6.67 inches, 1080 x 2408 px, 120 Hz Display wi...
# 704  6.76 inches, 1440 x 3200 px, 120 Hz Display wi...
# 726  6.67 inches, 1080 x 2400 px, 144 Hz Display wi...
# 731  6.4 inches, 1080 x 2340 px Display with Water ...
# 733  6.18 inches, 1080 x 2246 px Display with Large...
# 737  6.67 inches, 1080 x 2400 px, 120 Hz Display wi...
# 765  6.51 inches, 1600 x 720 px Display with Punch ...
# 792  6.73 inches, 1080 x 2408 px, 120 Hz Display wi...
# 817  6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 824  6.71 inches, 1080 x 2400 px Display with Punch...
# 825  6.5 inches, 720 x 1600 px Display with Water D...
# 827  6.53 inches, 720 x 1600 px Display with Water ...
# 828  6.5 inches, 1080 x 2400 px, 90 Hz Display with...
# 850  6.43 inches, 1080 x 2400 px, 90 Hz Display wit...
# 851  6.82 inches, 720 x 1600 px, 90 Hz Display with...
# 861  6.52 inches, 1080 x 2400 px, 90 Hz Display wit...
# 880  6.5 inches, 720 x 1600 px, 90 Hz Display with ...
# 881  6.52 inches, 720 x 1600 px, 90 Hz Display with...
# 884  6.52 inches, 720 x 1600 px Display with Water ...
# 891  6.2 inches, 720 x 1520 px Display with Water D...
# 894  6.71 inches, 1284 x 2778 px, 120 Hz Display wi...
# 905  6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
#
MP + 2 MP + 2 MP Triple Rear & 8 MP Front C...
# 827                     13 MP Rear & 5 MP Front Camera
# 828               64 MP Quad Rear & 16 MP Front Camera
# 850       50 MP + 13 MP Dual Rear & 16 MP Front Camera
# 851         16 MP + 2 MP Dual Rear & 8 MP Front Camera
# 861  64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 880                48 MP Quad Rear & 8 MP Front Camera
# 881  13 MP + 2 MP + 2 MP Triple Rear & 8 MP Front C...
# 884  13 MP + 2 MP + 2 MP Triple Rear & 5 MP Front C...
# 891         13 MP + 2 MP Dual Rear & 8 MP Front Camera
# 894       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 905  50 MP + 20 MP + 2 MP Triple Rear & 32 MP + 32 ...
# 916  50 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 950        13 MP + 2 MP Dual Rear & 13 MP Front Camera
# 954  13 MP + 5 MP + 2 MP Triple Rear & 8 MP Front C...
# 961                13 MP Dual Rear & 8 MP Front Camera
# 974                                   2 MP Rear Camera
#
#                                    card                   os
# 96     Memory Card Supported, upto 1 TB          Android v12
# 109                         Android v12          Android v12
# 147                Memory Card (Hybrid)          Android v12
# 153    Memory Card Supported, upto 1 TB          Android v12
# 156    Memory Card Supported, upto 1 TB          Android v12
# 233    Memory Card Supported, upto 1 TB          Android v12
# 268                         Android v13          Android v13
# 302  Memory Card Supported, upto 512 GB          Android v11
# 303                Memory Card (Hybrid)          Android v11
# 317                         Android v11          Android v11
# 318                         Android v13          Android v13
# 359                         Android v12          Android v12
# 361           Memory Card Not Supported              iOS v14
# 372           Memory Card Not Supported          Android v10
# 387    Memory Card Supported, upto 1 TB          Android v11
# 433    Memory Card Supported, upto 1 TB          Android v12
# 442           Memory Card Not Supported          Android v12
# 475    Memory Card Supported, upto 1 TB          Android v12
# 476               Memory Card Supported          Android v12
# 497    Memory Card Supported, upto 1 TB          Android v11
# 525    Memory Card Supported, upto 1 TB          Android v11
# 542    Memory Card Supported, upto 1 TB          Android v11
# 559     Memory Card (Hybrid), upto 1 TB          Android v11
# 560                         Android v13          Android v13
# 563  Memory Card Supported, upto 512 GB        Android v10.0
# 570                Memory Card (Hybrid)          Android v12
# 595           Memory Card Not Supported              iOS v13
# 597     Memory Card (Hybrid), upto 1 TB          Android v13
# 613                Memory Card (Hybrid)          Android v11
# 625                         Android v12          Android v12
# 629                         Android v11          Android v11
# 639  Memory Card Supported, upto 512 GB          Android v10
# 646  Memory Card Supported, upto 256 GB          Android v12
# 662                Memory Card (Hybrid)          Android v10
# 665     Memory Card (Hybrid), upto 1 TB        Android v10.0
# 678  Memory Card Supported, upto 512 GB          Android v12
# 681  Memory Card Supported, upto 512 GB          Android v11
# 687  Memory Card Supported, upto 512 GB          Android v11
# 699     Memory Card (Hybrid), upto 1 TB          Android v13
# 704           Memory Card Not Supported     Hongmeng OS v4.0
# 726                         Android v10          Android v10
# 731  Memory Card Supported, upto 256 GB   Android v9.0 (Pie)
# 733   Memory Card (Hybrid), upto 256 GB  Android v8.1 (Oreo)
# 737                         Android v13          Android v13
# 765  Memory Card Supported, upto 256 GB          Android v10
# 792    Memory Card Supported, upto 1 TB          Android v13
# 817                         Android v11          Android v11
# 824    Memory Card Supported, upto 1 TB          Android v11
# 825                         Android v10          Android v10
# 827  Memory Card Supported, upto 512 GB          Android v10
# 828  Memory Card Supported, upto 256 GB          Android v10
# 850    Memory Card Supported, upto 1 TB          Android v12
# 851  Memory Card Supported, upto 512 GB          Android v12
# 861  Memory Card Supported, upto 512 GB          Android v12
# 880    Memory Card Supported, upto 1 TB          Android v11
# 881  Memory Card Supported, upto 256 GB          Android v10
# 884  Memory Card Supported, upto 256 GB        Android v10.0
# 891  Memory Card Supported, upto 256 GB  Android v8.1 (Oreo)
# 894           Memory Card Not Supported              iOS v16
# 905                         Android v12          Android v12
# 916     Memory Card (Hybrid), upto 1 TB          Android v12
# 950  Memory Card Supported, upto 256 GB          Android v10
# 954  Memory Card Supported, upto 512 GB          Android v10
# 961               Memory Card Supported          Android v12
# 974                         Android v11          Android v11

# %%
df1[df1['index'].isin(processor_rows & ram_rows & battery_rows & display_rows & camera_rows)]
# Out:
#       index                   model  price  rating  \
# 640     642          Nokia 105 Plus   1299     NaN
# 645     647         Nokia 2760 Flip   5490     NaN
# 647     649       Motorola Moto A10   1339     NaN
# 657     659           Zanco Tiny T1   2799     NaN
# 665     667            itel it2163S    958     NaN
# 748     750            Nokia 400 4G   3290     NaN
# 757     759            Karbonn KU3i    995     NaN
# 817     819            itel Magic X   2239     NaN
# 882     884  Nokia 5710 XpressAudio   4799     NaN
# 925     927           Nokia 3310 4G   3999     NaN
# 927     929      Samsung Guru E1200   1685     NaN
# 930     932        iKall K88 Pro 4G   2099     NaN
# 1000   1002         XTouch F40 Flip   1999     NaN
#
#                                  sim                   processor  \
# 640                         Dual Sim      4 MB RAM, 4 MB inbuilt
# 645          Dual Sim, 3G, 4G, Wi-Fi            1450 mAh Battery
# 647                         Dual Sim      4 MB RAM, 4 MB inbuilt
# 657                       Single Sim    32 MB RAM, 32 MB inbuilt
# 665                         Dual Sim      4 MB RAM, 4 MB inbuilt
# 748       Dual Sim, 4G, VoLTE, Wi-Fi            2000 mAh Battery
# 757                         Dual Sim    52 MB RAM, 32 MB inbuilt
# 817   Dual Sim, 3G, 4G, VoLTE, Wi-Fi                       No 3G
# 882                 Dual Sim, 3G, 4G                     No Wifi
# 925   Dual Sim, 3G, 4G, VoLTE, Wi-Fi  256 MB RAM, 512 MB inbuilt
# 927                       Single Sim                     No Wifi
# 930          Dual Sim, 3G, 4G, VoLTE   48 MB RAM, 128 MB inbuilt
# 1000                        Dual Sim                       No 3G
#
#                                    ram                            battery  \
# 640                    800 mAh Battery  1.77 inches, 128 x 160 px Display
# 645   3.6 inches, 240 x 320 px Display      5 MP Rear & 5 MP Front Camera
# 647                   1750 mAh Battery   1.8 inches, 160 x 128 px Display
# 657                    200 mAh Battery    0.49 inches, 64 x 32 px Display
# 665                   1200 mAh Battery   1.8 inches, 160 x 128 px Display
# 748   2.4 inches, 240 x 320 px Display  0.3 MP Rear & 0.3 MP Front Camera
# 757                   1000 mAh Battery   1.8 inches, 128 x 160 px Display
# 817                               T117          48 MB RAM, 128 MB inbuilt
# 882                        Unisoc T107          48 MB RAM, 128 MB inbuilt
# 925                   1200 mAh Battery   2.4 inches, 240 x 320 px Display
# 927                    800 mAh Battery   1.5 inches, 128 x 128 px Display
# 930                   1800 mAh Battery   2.4 inches, 240 x 360 px Display
# 1000                           No Wifi           32 MB RAM, 32 MB inbuilt
#
#                                 display                              camera  \
# 640                      No Rear Camera   Memory Card Supported, upto 32 GB
# 645   Memory Card Supported, upto 32 GB                          Kaios v3.0
# 647                      No Rear Camera   Memory Card Supported, upto 32 GB
# 657                      No Rear Camera                         No FM Radio
# 665                      No Rear Camera   Memory Card Supported, upto 32 GB
# 748   Memory Card Supported, upto 64 GB                           Bluetooth
# 757                      No Rear Camera   Memory Card Supported, upto 16 GB
# 817                    1200 mAh Battery    2.4 inches, 240 x 320 px Display
# 882                    1450 mAh Battery    2.4 inches, 240 x 320 px Display
# 925                    2 MP Rear Camera   Memory Card Supported, upto 32 GB
# 927                      No Rear Camera                         No FM Radio
# 930                  0.3 MP Rear Camera  Memory Card Supported, upto 128 GB
# 1000                    800 mAh Battery   1.77 inches, 240 x 320 px Display
#
#                     card                                 os
# 640            Bluetooth                                NaN
# 645            Bluetooth                                NaN
# 647                  NaN                                NaN
# 657            Bluetooth                                NaN
# 665            Bluetooth                                NaN
# 748              Browser                                NaN
# 757            Bluetooth                                NaN
# 817   1.3 MP Rear Camera  Memory Card Supported, upto 64 GB
# 882   0.3 MP Rear Camera  Memory Card Supported, upto 32 GB
# 925            Bluetooth                            Browser
# 927                  NaN                                NaN
# 930            Bluetooth                            Browser
# 1000        Dual Display                 1.3 MP Rear Camera

# %%
df1[df1['index'].isin(processor_rows & ram_rows & battery_rows & display_rows & camera_rows)]['price'].mean()
# Out:
# 2537.6923076923076

# %%
df1 = df1[df1['price'] >= 3400]

# %%
df1
# Out:
#       index                            model  price  rating  \
# 0         2                    OnePlus 11 5G  54999    89.0
# 1         3        OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2         4            Samsung Galaxy A14 5G  16499    75.0
# 3         5             Motorola Moto G62 5G  14999    81.0
# 4         6               Realme 10 Pro Plus  24999    82.0
# ...     ...                              ...    ...     ...
# 1015   1017       Motorola Moto Edge S30 Pro  34990    83.0
# 1016   1018                      Honor X8 5G  14990    75.0
# 1017   1019  POCO X4 GT 5G (8GB RAM + 256GB)  28990    85.0
# 1018   1020             Motorola Moto G91 5G  19990    80.0
# 1019   1021           Samsung Galaxy M52s 5G  24990    74.0
#
#                                                     sim  \
# 0               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...                                                 ...
# 1015                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1016                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1017  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 1018            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1019                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                             processor  \
# 0     Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor
# 1        Snapdragon 695, Octa Core, 2.2 GHz Processor
# 2           Exynos 1330, Octa Core, 2.4 GHz Processor
# 3       Snapdragon  695, Octa Core, 2.2 GHz Processor
# 4        Dimensity 1080, Octa Core, 2.6 GHz Processor
# ...                                               ...
# 1015    Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 1016   Snapdragon  480+, Octa Core, 2.2 GHz Processor
# 1017    Dimensity 8100, Octa Core, 2.85 GHz Processor
# 1018     Snapdragon 695, Octa Core, 2.2 GHz Processor
# 1019                              Octa Core Processor
#
#                             ram                                    battery  \
# 0     12 GB RAM, 256 GB inbuilt   5000 mAh Battery with 100W Fast Charging
# 1      6 GB RAM, 128 GB inbuilt    5000 mAh Battery with 33W Fast Charging
# 2       4 GB RAM, 64 GB inbuilt    5000 mAh Battery with 15W Fast Charging
# 3      6 GB RAM, 128 GB inbuilt        5000 mAh Battery with Fast Charging
# 4      6 GB RAM, 128 GB inbuilt    5000 mAh Battery with 67W Fast Charging
# ...                         ...                                        ...
# 1015   8 GB RAM, 128 GB inbuilt  5000 mAh Battery with 68.2W Fast Charging
# 1016   6 GB RAM, 128 GB inbuilt  5000 mAh Battery with 22.5W Fast Charging
# 1017   8 GB RAM, 256 GB inbuilt    5080 mAh Battery with 67W Fast Charging
# 1018   6 GB RAM, 128 GB inbuilt        5000 mAh Battery with Fast Charging
# 1019   8 GB RAM, 128 GB inbuilt        5000 mAh Battery with Fast Charging
#
#                                                 display  \
# 0     6.7 inches, 1440 x 3216 px, 120 Hz Display wit...
# 1     6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 2     6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 3     6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 4     6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# ...                                                 ...
# 1015  6.67 inches, 1080 x 2460 px, 120 Hz Display wi...
# 1016  6.5 inches, 720 x 1600 px Display with Water D...
# 1017  6.6 inches, 1080 x 2460 px, 144 Hz Display wit...
# 1018  6.8 inches, 1080 x 2400 px Display with Punch ...
# 1019  6.5 inches, 1080 x 2400 px Display with Water ...
#
#                                                  camera  \
# 0     50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# 1     64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 2     50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 3     50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4     108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
# ...                                                 ...
# 1015  64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 1016  48 MP + 2 MP + Depth Sensor Triple Rear & 8 MP...
# 1017  64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 1018  108 MP + 8 MP + 2 MP Triple Rear & 32 MP Front...
# 1019  64 MP + 8 MP + 5 MP Triple Rear & 32 MP Front ...
#
#                                   card           os
# 0            Memory Card Not Supported  Android v13
# 1      Memory Card (Hybrid), upto 1 TB  Android v12
# 2     Memory Card Supported, upto 1 TB  Android v13
# 3      Memory Card (Hybrid), upto 1 TB  Android v12
# 4            Memory Card Not Supported  Android v13
# ...                                ...          ...
# 1015                       Android v12  No FM Radio
# 1016  Memory Card Supported, upto 1 TB  Android v11
# 1017         Memory Card Not Supported  Android v12
# 1018  Memory Card Supported, upto 1 TB  Android v12
# 1019  Memory Card Supported, upto 1 TB  Android v12
#
# [991 rows x 12 columns]

# %%
df1[df1['index'].isin(processor_rows & ram_rows & battery_rows & display_rows & camera_rows)]
# Out:
#      index                   model  price  rating  \
# 645    647         Nokia 2760 Flip   5490     NaN
# 882    884  Nokia 5710 XpressAudio   4799     NaN
# 925    927           Nokia 3310 4G   3999     NaN
#
#                                 sim                   processor  \
# 645         Dual Sim, 3G, 4G, Wi-Fi            1450 mAh Battery
# 882                Dual Sim, 3G, 4G                     No Wifi
# 925  Dual Sim, 3G, 4G, VoLTE, Wi-Fi  256 MB RAM, 512 MB inbuilt
#
#                                   ram                           battery  \
# 645  3.6 inches, 240 x 320 px Display     5 MP Rear & 5 MP Front Camera
# 882                       Unisoc T107         48 MB RAM, 128 MB inbuilt
# 925                  1200 mAh Battery  2.4 inches, 240 x 320 px Display
#
#                                display                             camera  \
# 645  Memory Card Supported, upto 32 GB                         Kaios v3.0
# 882                   1450 mAh Battery   2.4 inches, 240 x 320 px Display
# 925                   2 MP Rear Camera  Memory Card Supported, upto 32 GB
#
#                    card                                 os
# 645           Bluetooth                                NaN
# 882  0.3 MP Rear Camera  Memory Card Supported, upto 32 GB
# 925           Bluetooth                            Browser

# %%
#cleaing of the processor column

# %%
df1[df1['index'].isin(processor_rows)]
# Out:
#      index                   model  price  rating  \
# 645    647         Nokia 2760 Flip   5490     NaN
# 857    859             LG Folder 2  11999     NaN
# 882    884  Nokia 5710 XpressAudio   4799     NaN
# 925    927           Nokia 3310 4G   3999     NaN
#
#                                 sim                   processor  \
# 645         Dual Sim, 3G, 4G, Wi-Fi            1450 mAh Battery
# 857       Single Sim, 3G, 4G, Wi-Fi      1 GB RAM, 8 GB inbuilt
# 882                Dual Sim, 3G, 4G                     No Wifi
# 925  Dual Sim, 3G, 4G, VoLTE, Wi-Fi  256 MB RAM, 512 MB inbuilt
#
#                                   ram                           battery  \
# 645  3.6 inches, 240 x 320 px Display     5 MP Rear & 5 MP Front Camera
# 857                  1470 mAh Battery  2.8 inches, 240 x 320 px Display
# 882                       Unisoc T107         48 MB RAM, 128 MB inbuilt
# 925                  1200 mAh Battery  2.4 inches, 240 x 320 px Display
#
#                                display                             camera  \
# 645  Memory Card Supported, upto 32 GB                         Kaios v3.0
# 857                   2 MP Rear Camera              Memory Card Supported
# 882                   1450 mAh Battery   2.4 inches, 240 x 320 px Display
# 925                   2 MP Rear Camera  Memory Card Supported, upto 32 GB
#
#                    card                                 os
# 645           Bluetooth                                NaN
# 857           Bluetooth                                NaN
# 882  0.3 MP Rear Camera  Memory Card Supported, upto 32 GB
# 925           Bluetooth                            Browser

# %%
df1.drop([645,857,882,925],inplace=True)
# Out:
# /tmp/ipykernel_426/1676279141.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop([645,857,882,925],inplace=True)

# %%
df1[df1['index'].isin(ram_rows)]
# Out:
#      index                             model   price  rating  \
# 439    441            Apple iPhone SE 3 2022   43900     NaN
# 483    485  Huawei Mate 50 RS Porsche Design  239999    81.0
# 582    584                     Nokia 8210 4G    3749     NaN
#
#                                                  sim  \
# 439          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 483  Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster
# 582                                 Dual Sim, 3G, 4G
#
#                                             processor             ram  \
# 439        Bionic  A15, Hexa Core, 3.22 GHz Processor   64 GB inbuilt
# 483  Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor  512 GB inbuilt
# 582                                           No Wifi     Unisoc T107
#
#                                      battery  \
# 439        4.7 inches, 750 x 1334 px Display
# 483  4700 mAh Battery with 66W Fast Charging
# 582                48 MB RAM, 128 MB inbuilt
#
#                                          display  \
# 439               12 MP Rear & 7 MP Front Camera
# 483  6.74 inches, 1212 x 2616 px, 120 Hz Display
# 582                             1450 mAh Battery
#
#                                                 camera  \
# 439                          Memory Card Not Supported
# 483  50 MP + 48 MP + 13 MP Triple Rear & 13 MP Fron...
# 582                   2.8 inches, 240 x 320 px Display
#
#                                   card                                 os
# 439                            iOS v15                        No FM Radio
# 483  Memory Card (Hybrid), upto 256 GB                   Hongmeng OS v3.0
# 582                 0.3 MP Rear Camera  Memory Card Supported, upto 32 GB

# %%
df1.drop([582],inplace=True)

# %%
df1[df1['index'].isin(battery_rows)]
# Out:
#      level_0  index brand_name  \
# 109      109    113    oneplus
# 147      147    151    samsung
# 303      305    309     xiaomi
# 359      361    365     xiaomi
# 372      374    378     google
# 433      437    441   motorola
# 442      446    450     xiaomi
# 542      549    553     realme
# 570      580    584      nokia
# 595      606    610      apple
# 597      609    613       sony
# 613      626    630       vivo
# 625      638    642      tecno
# 629      643    647     xiaomi
# 639      655    659     xiaomi
# 646      663    667    infinix
# 678      697    701    infinix
# 726      746    750     xiaomi
# 731      752    756     realme
# 733      755    759     xiaomi
# 737      760    764       vivo
# 792      815    819     xiaomi
# 825      851    855     realme
# 828      855    859     realme
# 851      880    884      tecno
# 880      911    915    samsung
# 881      912    916    oneplus
# 891      923    927     realme
# 894      928    932      apple
# 950      986    990       vivo
# 961      998   1002  blackview
#
#                                                model   price  rating  \
# 109                OnePlus 10R 5G (12GB RAM + 256GB)   36999    87.0
# 147                            Samsung Galaxy M34 5G   16999    84.0
# 303                          Xiaomi Mi 11 Lite NE 5G   21890    83.0
# 359                                Xiaomi 12T Pro 5G   59990    89.0
# 372                                   Google Pixel 4   20120    78.0
# 433                                Motorola Moto E32    8999    71.0
# 442  Xiaomi Redmi Note 12 Pro Plus (6GB RAM + 128GB)   26999    84.0
# 542                                     Realme 8s 5G   17999    80.0
# 570                                        Nokia G60   28498    81.0
# 595                          Apple iPhone 11 Pro Max  109900    77.0
# 597                               Sony Xperia Ace IV   19990    80.0
# 613                                      Vivo V21 5G   23994    85.0
# 625                               Tecno Camon 19 Pro   17990    81.0
# 629             Xiaomi 11T Pro 5G (12GB RAM + 256GB)   38999    88.0
# 639                                   Xiaomi Redmi 9    8999    68.0
# 646                               Infinix Hot 12 Pro   10850    74.0
# 678                             Infinix Smart 6 Plus    8299    63.0
# 726                             Xiaomi Mi 10T Pro 5G   29999    86.0
# 731                                        Realme XT   13279    75.0
# 733                 Xiaomi Poco F1 (6GB RAM + 128GB)   12999    78.0
# 737                                     Vivo S17 Pro   49990    77.0
# 792                         Xiaomi Redmi 13 Prime 5G   17990    79.0
# 825                                       Realme Q2i    9999    69.0
# 828                        Realme 6 (6GB RAM + 64GB)   12989    77.0
# 851                                 Tecno Pova Neo 2   13990    67.0
# 880                               Samsung Galaxy M12   10999    72.0
# 881                                OnePlus Nord N100   16990    68.0
# 891                                        Realme A1    8999     NaN
# 894                             Apple iPhone 15 Plus   84990    75.0
# 950                                  Vivo Y21 (2020)    9990    65.0
# 961                             Blackview BV5200 Pro    8990    67.0
#
#                                                    sim  has_ir_blaster  \
# 109            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False
# 147            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False
# 303  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...            True
# 359  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...            True
# 372                Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC           False
# 433                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi           False
# 442     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster            True
# 542                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False
# 570            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False
# 595                Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC           False
# 597                Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC           False
# 613                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False
# 625                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi           False
# 629  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...            True
# 639                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi           False
# 646                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi           False
# 678                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi           False
# 726  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...            True
# 731                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi           False
# 733                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi           False
# 737            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False
# 792     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster            True
# 825                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False
# 828                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi           False
# 851                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi           False
# 880                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi           False
# 881                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi           False
# 891                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi           False
# 894      Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC           False
# 950                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi           False
# 961            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False
#
#      has_5g  has_nfc                                          processor  \
# 109    True     True  Dimensity 8100 Max, Octa Core, 2.85 GHz Processor
# 147    True     True          Exynos 1200, Octa Core, 2.4 GHz Processor
# 303    True     True    Snapdragon  778G , Octa Core, 2.4 GHz Processor
# 359    True     True  Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 372   False     True       Snapdragon 855, Octa Core, 2.8 GHz Processor
# 433   False    False            Helio G37, Octa Core, 2.3 GHz Processor
# 442    True    False       Dimensity 1080, Octa Core, 2.6 GHz Processor
# 542    True    False    Dimensity  810 5G, Octa Core, 2.4 GHz Processor
# 570    True     True      Snapdragon  695, Octa Core, 2.2 GHz Processor
# 595   False     True          A13 Bionic, Hexa Core, 2.65 GHz Processor
# 597   False     True     Snapdragon 4 Gen 1, Octa Core, 2 GHz Processor
# 613    True    False       Dimensity 800U, Octa Core, 2.4 GHz Processor
# 625   False    False          Helio  G96, Octa Core, 2.05 GHz Processor
# 629    True     True    Snapdragon  888 , Octa Core, 2.84 GHz Processor
# 639   False    False            Helio G35, Octa Core, 2.3 GHz Processor
# 646   False    False             Tiger T616, Octa Core, 2 GHz Processor
# 678   False    False              Helio G25, Octa Core, 2 GHz Processor
# 726    True     True     Snapdragon 865 , Octa Core, 2.84 GHz Processor
# 731   False    False       Snapdragon 712, Octa Core, 2.3 GHz Processor
# 733   False    False       Snapdragon 845, Octa Core, 2.8 GHz Processor
# 737    True     True                Dimensity 9200, Octa Core Processor
# 792    True    False     Snapdragon 4 Gen 1, Octa Core, 2 GHz Processor
# 825    True    False          Dimensity 720, Octa Core, 2 GHz Processor
# 828   False    False       Helio   G90T , Octa Core, 2.05 GHz Processor
# 851   False    False              Helio G85, Octa Core, 2 GHz Processor
# 880   False    False            Exynos  850, Octa Core, 2 GHz Processor
# 881   False    False       Snapdragon 460, Octa Core, 1.8 GHz Processor
# 891   False    False            Helio P70, Octa Core, 2.1 GHz Processor
# 894    True     True                    Bionic A16, Hexa Core Processor
# 950   False    False       Snapdragon 450, Octa Core, 1.8 GHz Processor
# 961    True     True            Helio G35, Octa Core, 2.3 GHz Processor
#
#                            ram                                   battery  \
# 109  12 GB RAM, 256 GB inbuilt   5000 mAh Battery with 80W Fast Charging
# 147   6 GB RAM, 128 GB inbuilt   6000 mAh Battery with 25W Fast Charging
# 303   6 GB RAM, 128 GB inbuilt   4250 mAh Battery with 33W Fast Charging
# 359   8 GB RAM, 128 GB inbuilt  5000 mAh Battery with 120W Fast Charging
# 372    6 GB RAM, 64 GB inbuilt       2800 mAh Battery with Fast Charging
# 433    4 GB RAM, 64 GB inbuilt   5000 mAh Battery with 10W Fast Charging
# 442   6 GB RAM, 128 GB inbuilt  4980 mAh Battery with 120W Fast Charging
# 542   6 GB RAM, 128 GB inbuilt   5000 mAh Battery with 33W Fast Charging
# 570   6 GB RAM, 128 GB inbuilt   4500 mAh Battery with 20W Fast Charging
# 595    4 GB RAM, 64 GB inbuilt   3500 mAh Battery with 18W Fast Charging
# 597   8 GB RAM, 128 GB inbuilt   5000 mAh Battery with 33W Fast Charging
# 613   8 GB RAM, 128 GB inbuilt   4000 mAh Battery with 33W Fast Charging
# 625   8 GB RAM, 128 GB inbuilt   5000 mAh Battery with 33W Fast Charging
# 629  12 GB RAM, 256 GB inbuilt  5000 mAh Battery with 120W Fast Charging
# 639    4 GB RAM, 64 GB inbuilt                          5000 mAh Battery
# 646    6 GB RAM, 64 GB inbuilt   5000 mAh Battery with 18W Fast Charging
# 678    3 GB RAM, 64 GB inbuilt                          5000 mAh Battery
# 726   8 GB RAM, 128 GB inbuilt   5000 mAh Battery with 33W Fast Charging
# 731    4 GB RAM, 64 GB inbuilt   4000 mAh Battery with 20W Fast Charging
# 733   6 GB RAM, 128 GB inbuilt       4000 mAh Battery with Fast Charging
# 737  12 GB RAM, 256 GB inbuilt  5000 mAh Battery with 120W Fast Charging
# 792   6 GB RAM, 128 GB inbuilt   5100 mAh Battery with 18W Fast Charging
# 825   4 GB RAM, 128 GB inbuilt   5000 mAh Battery with 18W Fast Charging
# 828    6 GB RAM, 64 GB inbuilt   4300 mAh Battery with 30W Fast Charging
# 851   6 GB RAM, 128 GB inbuilt                          7000 mAh Battery
# 880    4 GB RAM, 64 GB inbuilt   6000 mAh Battery with 15W Fast Charging
# 881    4 GB RAM, 64 GB inbuilt   5000 mAh Battery with 18W Fast Charging
# 891    2 GB RAM, 16 GB inbuilt                          4000 mAh Battery
# 894   8 GB RAM, 128 GB inbuilt       4532 mAh Battery with Fast Charging
# 950    4 GB RAM, 64 GB inbuilt                          5000 mAh Battery
# 961    4 GB RAM, 64 GB inbuilt   5180 mAh Battery with 10W Fast Charging
#
#                                                display  \
# 109  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# 147  6.5 inches, 1080 x 2400 px, 120 Hz Display wit...
# 303  6.55 inches, 1080 x 2400 px, 90 Hz Display wit...
# 359  6.67 inches, 1220 x 2712 px, 120 Hz Display wi...
# 372                 5.7 inches, 1080 x 2280 px Display
# 433  6.5 inches, 720 x 1600 px, 90 Hz Display with ...
# 442  6.67 inches, 1080 x 2400 px, 120 Hz Display wi...
# 542  6.5 inches, 1080 x 2400 px, 90 Hz Display with...
# 570  6.58 inches, 1080 x 2400 px, 120 Hz Display wi...
# 595  6.5 inches, 1242 x 2688 px Display with Large ...
# 597         6.5 inches, 1080 x 2400 px, 120 Hz Display
# 613  6.44 inches, 1080 x 2400 px, 90 Hz Display wit...
# 625  6.8 inches, 1080 x 2460 px, 120 Hz Display wit...
# 629  6.67 inches, 1080 x 2400 px, 120 Hz Display wi...
# 639  6.53 inches, 720 x 1600 px Display with Water ...
# 646  6.6 inches, 720 x 1612 px, 90 Hz Display with ...
# 678  6.82 inches, 720 x 1600 px Display with Water ...
# 726  6.67 inches, 1080 x 2400 px, 144 Hz Display wi...
# 731  6.4 inches, 1080 x 2340 px Display with Water ...
# 733  6.18 inches, 1080 x 2246 px Display with Large...
# 737  6.67 inches, 1080 x 2400 px, 120 Hz Display wi...
# 792  6.73 inches, 1080 x 2408 px, 120 Hz Display wi...
# 825  6.5 inches, 720 x 1600 px Display with Water D...
# 828  6.5 inches, 1080 x 2400 px, 90 Hz Display with...
# 851  6.82 inches, 720 x 1600 px, 90 Hz Display with...
# 880  6.5 inches, 720 x 1600 px, 90 Hz Display with ...
# 881  6.52 inches, 720 x 1600 px, 90 Hz Display with...
# 891  6.2 inches, 720 x 1520 px Display with Water D...
# 894  6.71 inches, 1284 x 2778 px, 120 Hz Display wi...
# 950  6.5 inches, 720 x 1544 px Display with Water D...
# 961  6.1 inches, 720 x 1560 px Display with Punch Hole
#
#                                                 camera  \
# 109  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 147               64 MP Quad Rear & 32 MP Front Camera
# 303  64 MP + 8 MP + 5 MP Triple Rear & 20 MP Front ...
# 359  200 MP + 8 MP + 2 MP Triple Rear & 20 MP Front...
# 372  16 MP + 12.2 MP Dual Rear & 8 MP + TOF 3D Dual...
# 433         50 MP + 2 MP Dual Rear & 8 MP Front Camera
# 442  200 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
# 542  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 570  50 MP + 5 MP + 2 MP Triple Rear & 8 MP Front C...
# 595  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 597        50 MP + 2 MP Dual Rear & 16 MP Front Camera
# 613  64 MP + 8 MP + 2 MP Triple Rear & 44 MP Front ...
# 625  64 MP + 50 MP + 2 MP Triple Rear & 32 MP Front...
# 629  108 MP + 8 MP + 5 MP Triple Rear & 16 MP Front...
# 639         13 MP + 2 MP Dual Rear & 5 MP Front Camera
# 646  50 MP + Depth Sensor Dual Rear & 8 MP Front Ca...
# 678  8 MP + Depth Sensor Dual Rear & 5 MP Front Camera
# 726  108 MP + 13 MP + 5 MP Triple Rear & 20 MP Fron...
# 731               64 MP Quad Rear & 16 MP Front Camera
# 733        12 MP + 5 MP Dual Rear & 20 MP Front Camera
# 737  50 MP + 13 MP + 2 MP Triple Rear & 32 MP Front...
# 792        64 MP + 2 MP Dual Rear & 16 MP Front Camera
# 825  13 MP + 2 MP + 2 MP Triple Rear & 8 MP Front C...
# 828               64 MP Quad Rear & 16 MP Front Camera
# 851         16 MP + 2 MP Dual Rear & 8 MP Front Camera
# 880                48 MP Quad Rear & 8 MP Front Camera
# 881  13 MP + 2 MP + 2 MP Triple Rear & 8 MP Front C...
# 891         13 MP + 2 MP Dual Rear & 8 MP Front Camera
# 894       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 950        13 MP + 2 MP Dual Rear & 13 MP Front Camera
# 961                13 MP Dual Rear & 8 MP Front Camera
#
#                                    card                   os
# 109                         Android v12          Android v12
# 147                Memory Card (Hybrid)          Android v12
# 303                Memory Card (Hybrid)          Android v11
# 359                         Android v12          Android v12
# 372           Memory Card Not Supported          Android v10
# 433    Memory Card Supported, upto 1 TB          Android v12
# 442           Memory Card Not Supported          Android v12
# 542    Memory Card Supported, upto 1 TB          Android v11
# 570                Memory Card (Hybrid)          Android v12
# 595           Memory Card Not Supported              iOS v13
# 597     Memory Card (Hybrid), upto 1 TB          Android v13
# 613                Memory Card (Hybrid)          Android v11
# 625                         Android v12          Android v12
# 629                         Android v11          Android v11
# 639  Memory Card Supported, upto 512 GB          Android v10
# 646  Memory Card Supported, upto 256 GB          Android v12
# 678  Memory Card Supported, upto 512 GB          Android v12
# 726                         Android v10          Android v10
# 731  Memory Card Supported, upto 256 GB   Android v9.0 (Pie)
# 733   Memory Card (Hybrid), upto 256 GB  Android v8.1 (Oreo)
# 737                         Android v13          Android v13
# 792    Memory Card Supported, upto 1 TB          Android v13
# 825                         Android v10          Android v10
# 828  Memory Card Supported, upto 256 GB          Android v10
# 851  Memory Card Supported, upto 512 GB          Android v12
# 880    Memory Card Supported, upto 1 TB          Android v11
# 881  Memory Card Supported, upto 256 GB          Android v10
# 891  Memory Card Supported, upto 256 GB  Android v8.1 (Oreo)
# 894           Memory Card Not Supported              iOS v16
# 950  Memory Card Supported, upto 256 GB          Android v10
# 961               Memory Card Supported          Android v12

# %%
df1.drop([376,754],inplace=True)

# %%
temp_df = df1[df1['index'].isin(battery_rows)]

# %%
x = temp_df.iloc[:,7:].shift(1,axis=1).values

# %%
df1.loc[temp_df.index,temp_df.columns] .shape
# Out:
# (31, 17)

# %%
df1.loc[temp_df.index,temp_df.columns[7:]]
# Out:
#      has_ir_blaster  has_5g  has_nfc  \
# 109           False    True     True
# 147           False    True     True
# 303            True    True     True
# 359            True    True     True
# 372           False   False     True
# 433           False   False    False
# 442            True    True    False
# 542           False    True    False
# 570           False    True     True
# 595           False   False     True
# 597           False   False     True
# 613           False    True    False
# 625           False   False    False
# 629            True    True     True
# 639           False   False    False
# 646           False   False    False
# 678           False   False    False
# 726            True    True     True
# 731           False   False    False
# 733           False   False    False
# 737           False    True     True
# 792            True    True    False
# 825           False    True    False
# 828           False   False    False
# 851           False   False    False
# 880           False   False    False
# 881           False   False    False
# 891           False   False    False
# 894           False    True     True
# 950           False   False    False
# 961           False    True     True
#
#                                              processor  \
# 109  Dimensity 8100 Max, Octa Core, 2.85 GHz Processor
# 147          Exynos 1200, Octa Core, 2.4 GHz Processor
# 303    Snapdragon  778G , Octa Core, 2.4 GHz Processor
# 359  Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 372       Snapdragon 855, Octa Core, 2.8 GHz Processor
# 433            Helio G37, Octa Core, 2.3 GHz Processor
# 442       Dimensity 1080, Octa Core, 2.6 GHz Processor
# 542    Dimensity  810 5G, Octa Core, 2.4 GHz Processor
# 570      Snapdragon  695, Octa Core, 2.2 GHz Processor
# 595          A13 Bionic, Hexa Core, 2.65 GHz Processor
# 597     Snapdragon 4 Gen 1, Octa Core, 2 GHz Processor
# 613       Dimensity 800U, Octa Core, 2.4 GHz Processor
# 625          Helio  G96, Octa Core, 2.05 GHz Processor
# 629    Snapdragon  888 , Octa Core, 2.84 GHz Processor
# 639            Helio G35, Octa Core, 2.3 GHz Processor
# 646             Tiger T616, Octa Core, 2 GHz Processor
# 678              Helio G25, Octa Core, 2 GHz Processor
# 726     Snapdragon 865 , Octa Core, 2.84 GHz Processor
# 731       Snapdragon 712, Octa Core, 2.3 GHz Processor
# 733       Snapdragon 845, Octa Core, 2.8 GHz Processor
# 737                Dimensity 9200, Octa Core Processor
# 792     Snapdragon 4 Gen 1, Octa Core, 2 GHz Processor
# 825          Dimensity 720, Octa Core, 2 GHz Processor
# 828       Helio   G90T , Octa Core, 2.05 GHz Processor
# 851              Helio G85, Octa Core, 2 GHz Processor
# 880            Exynos  850, Octa Core, 2 GHz Processor
# 881       Snapdragon 460, Octa Core, 1.8 GHz Processor
# 891            Helio P70, Octa Core, 2.1 GHz Processor
# 894                    Bionic A16, Hexa Core Processor
# 950       Snapdragon 450, Octa Core, 1.8 GHz Processor
# 961            Helio G35, Octa Core, 2.3 GHz Processor
#
#                            ram                                   battery  \
# 109  12 GB RAM, 256 GB inbuilt   5000 mAh Battery with 80W Fast Charging
# 147   6 GB RAM, 128 GB inbuilt   6000 mAh Battery with 25W Fast Charging
# 303   6 GB RAM, 128 GB inbuilt   4250 mAh Battery with 33W Fast Charging
# 359   8 GB RAM, 128 GB inbuilt  5000 mAh Battery with 120W Fast Charging
# 372    6 GB RAM, 64 GB inbuilt       2800 mAh Battery with Fast Charging
# 433    4 GB RAM, 64 GB inbuilt   5000 mAh Battery with 10W Fast Charging
# 442   6 GB RAM, 128 GB inbuilt  4980 mAh Battery with 120W Fast Charging
# 542   6 GB RAM, 128 GB inbuilt   5000 mAh Battery with 33W Fast Charging
# 570   6 GB RAM, 128 GB inbuilt   4500 mAh Battery with 20W Fast Charging
# 595    4 GB RAM, 64 GB inbuilt   3500 mAh Battery with 18W Fast Charging
# 597   8 GB RAM, 128 GB inbuilt   5000 mAh Battery with 33W Fast Charging
# 613   8 GB RAM, 128 GB inbuilt   4000 mAh Battery with 33W Fast Charging
# 625   8 GB RAM, 128 GB inbuilt   5000 mAh Battery with 33W Fast Charging
# 629  12 GB RAM, 256 GB inbuilt  5000 mAh Battery with 120W Fast Charging
# 639    4 GB RAM, 64 GB inbuilt                          5000 mAh Battery
# 646    6 GB RAM, 64 GB inbuilt   5000 mAh Battery with 18W Fast Charging
# 678    3 GB RAM, 64 GB inbuilt                          5000 mAh Battery
# 726   8 GB RAM, 128 GB inbuilt   5000 mAh Battery with 33W Fast Charging
# 731    4 GB RAM, 64 GB inbuilt   4000 mAh Battery with 20W Fast Charging
# 733   6 GB RAM, 128 GB inbuilt       4000 mAh Battery with Fast Charging
# 737  12 GB RAM, 256 GB inbuilt  5000 mAh Battery with 120W Fast Charging
# 792   6 GB RAM, 128 GB inbuilt   5100 mAh Battery with 18W Fast Charging
# 825   4 GB RAM, 128 GB inbuilt   5000 mAh Battery with 18W Fast Charging
# 828    6 GB RAM, 64 GB inbuilt   4300 mAh Battery with 30W Fast Charging
# 851   6 GB RAM, 128 GB inbuilt                          7000 mAh Battery
# 880    4 GB RAM, 64 GB inbuilt   6000 mAh Battery with 15W Fast Charging
# 881    4 GB RAM, 64 GB inbuilt   5000 mAh Battery with 18W Fast Charging
# 891    2 GB RAM, 16 GB inbuilt                          4000 mAh Battery
# 894   8 GB RAM, 128 GB inbuilt       4532 mAh Battery with Fast Charging
# 950    4 GB RAM, 64 GB inbuilt                          5000 mAh Battery
# 961    4 GB RAM, 64 GB inbuilt   5180 mAh Battery with 10W Fast Charging
#
#                                                display  \
# 109  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# 147  6.5 inches, 1080 x 2400 px, 120 Hz Display wit...
# 303  6.55 inches, 1080 x 2400 px, 90 Hz Display wit...
# 359  6.67 inches, 1220 x 2712 px, 120 Hz Display wi...
# 372                 5.7 inches, 1080 x 2280 px Display
# 433  6.5 inches, 720 x 1600 px, 90 Hz Display with ...
# 442  6.67 inches, 1080 x 2400 px, 120 Hz Display wi...
# 542  6.5 inches, 1080 x 2400 px, 90 Hz Display with...
# 570  6.58 inches, 1080 x 2400 px, 120 Hz Display wi...
# 595  6.5 inches, 1242 x 2688 px Display with Large ...
# 597         6.5 inches, 1080 x 2400 px, 120 Hz Display
# 613  6.44 inches, 1080 x 2400 px, 90 Hz Display wit...
# 625  6.8 inches, 1080 x 2460 px, 120 Hz Display wit...
# 629  6.67 inches, 1080 x 2400 px, 120 Hz Display wi...
# 639  6.53 inches, 720 x 1600 px Display with Water ...
# 646  6.6 inches, 720 x 1612 px, 90 Hz Display with ...
# 678  6.82 inches, 720 x 1600 px Display with Water ...
# 726  6.67 inches, 1080 x 2400 px, 144 Hz Display wi...
# 731  6.4 inches, 1080 x 2340 px Display with Water ...
# 733  6.18 inches, 1080 x 2246 px Display with Large...
# 737  6.67 inches, 1080 x 2400 px, 120 Hz Display wi...
# 792  6.73 inches, 1080 x 2408 px, 120 Hz Display wi...
# 825  6.5 inches, 720 x 1600 px Display with Water D...
# 828  6.5 inches, 1080 x 2400 px, 90 Hz Display with...
# 851  6.82 inches, 720 x 1600 px, 90 Hz Display with...
# 880  6.5 inches, 720 x 1600 px, 90 Hz Display with ...
# 881  6.52 inches, 720 x 1600 px, 90 Hz Display with...
# 891  6.2 inches, 720 x 1520 px Display with Water D...
# 894  6.71 inches, 1284 x 2778 px, 120 Hz Display wi...
# 950  6.5 inches, 720 x 1544 px Display with Water D...
# 961  6.1 inches, 720 x 1560 px Display with Punch Hole
#
#                                                 camera  \
# 109  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 147               64 MP Quad Rear & 32 MP Front Camera
# 303  64 MP + 8 MP + 5 MP Triple Rear & 20 MP Front ...
# 359  200 MP + 8 MP + 2 MP Triple Rear & 20 MP Front...
# 372  16 MP + 12.2 MP Dual Rear & 8 MP + TOF 3D Dual...
# 433         50 MP + 2 MP Dual Rear & 8 MP Front Camera
# 442  200 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
# 542  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 570  50 MP + 5 MP + 2 MP Triple Rear & 8 MP Front C...
# 595  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 597        50 MP + 2 MP Dual Rear & 16 MP Front Camera
# 613  64 MP + 8 MP + 2 MP Triple Rear & 44 MP Front ...
# 625  64 MP + 50 MP + 2 MP Triple Rear & 32 MP Front...
# 629  108 MP + 8 MP + 5 MP Triple Rear & 16 MP Front...
# 639         13 MP + 2 MP Dual Rear & 5 MP Front Camera
# 646  50 MP + Depth Sensor Dual Rear & 8 MP Front Ca...
# 678  8 MP + Depth Sensor Dual Rear & 5 MP Front Camera
# 726  108 MP + 13 MP + 5 MP Triple Rear & 20 MP Fron...
# 731               64 MP Quad Rear & 16 MP Front Camera
# 733        12 MP + 5 MP Dual Rear & 20 MP Front Camera
# 737  50 MP + 13 MP + 2 MP Triple Rear & 32 MP Front...
# 792        64 MP + 2 MP Dual Rear & 16 MP Front Camera
# 825  13 MP + 2 MP + 2 MP Triple Rear & 8 MP Front C...
# 828               64 MP Quad Rear & 16 MP Front Camera
# 851         16 MP + 2 MP Dual Rear & 8 MP Front Camera
# 880                48 MP Quad Rear & 8 MP Front Camera
# 881  13 MP + 2 MP + 2 MP Triple Rear & 8 MP Front C...
# 891         13 MP + 2 MP Dual Rear & 8 MP Front Camera
# 894       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 950        13 MP + 2 MP Dual Rear & 13 MP Front Camera
# 961                13 MP Dual Rear & 8 MP Front Camera
#
#                                    card                   os
# 109                         Android v12          Android v12
# 147                Memory Card (Hybrid)          Android v12
# 303                Memory Card (Hybrid)          Android v11
# 359                         Android v12          Android v12
# 372           Memory Card Not Supported          Android v10
# 433    Memory Card Supported, upto 1 TB          Android v12
# 442           Memory Card Not Supported          Android v12
# 542    Memory Card Supported, upto 1 TB          Android v11
# 570                Memory Card (Hybrid)          Android v12
# 595           Memory Card Not Supported              iOS v13
# 597     Memory Card (Hybrid), upto 1 TB          Android v13
# 613                Memory Card (Hybrid)          Android v11
# 625                         Android v12          Android v12
# 629                         Android v11          Android v11
# 639  Memory Card Supported, upto 512 GB          Android v10
# 646  Memory Card Supported, upto 256 GB          Android v12
# 678  Memory Card Supported, upto 512 GB          Android v12
# 726                         Android v10          Android v10
# 731  Memory Card Supported, upto 256 GB   Android v9.0 (Pie)
# 733   Memory Card (Hybrid), upto 256 GB  Android v8.1 (Oreo)
# 737                         Android v13          Android v13
# 792    Memory Card Supported, upto 1 TB          Android v13
# 825                         Android v10          Android v10
# 828  Memory Card Supported, upto 256 GB          Android v10
# 851  Memory Card Supported, upto 512 GB          Android v12
# 880    Memory Card Supported, upto 1 TB          Android v11
# 881  Memory Card Supported, upto 256 GB          Android v10
# 891  Memory Card Supported, upto 256 GB  Android v8.1 (Oreo)
# 894           Memory Card Not Supported              iOS v16
# 950  Memory Card Supported, upto 256 GB          Android v10
# 961               Memory Card Supported          Android v12

# %%
df1.loc[temp_df.index,temp_df.columns[7:]] = x

# %%
df1[df1['index'].isin(display_rows)]
# Out:
#      index                         model   price  rating  \
# 439    441        Apple iPhone SE 3 2022   43900     NaN
# 448    450           Apple iPhone 15 Pro  130990    75.0
# 628    630   Apple iPhone 12 Pro (512GB)  139900    80.0
# 762    764             Apple iPhone SE 4   49990    60.0
# 913    915  Apple iPhone 12 Mini (256GB)   55999    75.0
# 914    916       Apple iPhone 12 (256GB)   67999    76.0
#
#                                          sim  \
# 439  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 448  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 628  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 762  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 913  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 914  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                       processor                       ram  \
# 439  Bionic  A15, Hexa Core, 3.22 GHz Processor             64 GB inbuilt
# 448                                 Bionic  A16  8 GB RAM, 128 GB inbuilt
# 628    Bionic A14, Hexa Core, 3.1 GHz Processor  6 GB RAM, 512 GB inbuilt
# 762  Bionic  A15, Hexa Core, 3.22 GHz Processor             64 GB inbuilt
# 913    Bionic A14, Hexa Core, 3.1 GHz Processor  4 GB RAM, 256 GB inbuilt
# 914    Bionic A14, Hexa Core, 3.1 GHz Processor  4 GB RAM, 256 GB inbuilt
#
#     battery                                            display  \
# 439    None                  4.7 inches, 750 x 1334 px Display
# 448    None  6.06 inches, 1170 x 2532 px, 120 Hz Display wi...
# 628    None  6.1 inches, 1170 x 2532 px Display with Large ...
# 762    None                  6.1 inches, 750 x 1580 px Display
# 913    None                 5.4 inches, 1080 x 2340 px Display
# 914    None  6.1 inches, 1170 x 2532 px Display with Large ...
#
#                                                 camera  \
# 439                     12 MP Rear & 7 MP Front Camera
# 448  50 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 628  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 762                  12 MP Rear & 10.8 MP Front Camera
# 913       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 914       12 MP + 12 MP Dual Rear & 12 MP Front Camera
#
#                           card         os
# 439  Memory Card Not Supported    iOS v15
# 448  Memory Card Not Supported    iOS v15
# 628  Memory Card Not Supported  iOS v14.0
# 762  Memory Card Not Supported    iOS v16
# 913  Memory Card Not Supported    iOS v14
# 914  Memory Card Not Supported    iOS v14

# %%
df1[df1['index'].isin(camera_rows)]
# Out:
#      level_0  index brand_name  \
# 96        96    100       oppo
# 109      109    113    oneplus
# 147      147    151    samsung
# 153      153    157       oppo
# 156      157    161       oppo
# 233      234    238       oppo
# 268      269    273    nothing
# 302      304    308     xiaomi
# 303      305    309     xiaomi
# 317      319    323      honor
# 318      320    324       iqoo
# 359      361    365     xiaomi
# 361      363    367      apple
# 372      374    378     google
# 387      390    394     realme
# 433      437    441   motorola
# 442      446    450     xiaomi
# 475      480    484      tecno
# 497      502    506     realme
# 525      530    534       vivo
# 542      549    553     realme
# 559      567    571    samsung
# 560      568    572      nubia
# 563      571    575     xiaomi
# 570      580    584      nokia
# 595      606    610      apple
# 597      609    613       sony
# 613      626    630       vivo
# 625      638    642      tecno
# 629      643    647     xiaomi
# 639      655    659     xiaomi
# 646      663    667    infinix
# 662      680    684         lg
# 665      683    687    samsung
# 681      701    705      nokia
# 687      707    711    samsung
# 699      719    723       vivo
# 704      724    728     huawei
# 726      746    750     xiaomi
# 731      752    756     realme
# 733      755    759     xiaomi
# 827                Xiaomi Redmi 9i (4GB RAM + 128GB)    9299    67.0
# 850                                        Nokia X30   41990    85.0
# 851                                 Tecno Pova Neo 2   13990    67.0
# 861                         Xiaomi Redmi Note 12T 5G   15999    78.0
# 880                               Samsung Galaxy M12   10999    72.0
# 881                                OnePlus Nord N100   16990    68.0
# 891                                        Realme A1    8999     NaN
# 894                             Apple iPhone 15 Plus   84990    75.0
# 905                                    Xiaomi Civi 2   29999    85.0
# 916                                       iQOO Z8 5G   14999    78.0
# 950                                  Vivo Y21 (2020)    9990    65.0
# 954                               Samsung Galaxy A11    9990    63.0
# 961                             Blackview BV5200 Pro    8990    67.0
# 974                                        itel A23s    4787     NaN
#
#                                                    sim  has_ir_blaster  \
# 96                      Dual Sim, 3G, 4G, VoLTE, Wi-Fi           False
# 109            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False
# 147            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False
# 153            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False
# 156                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False
# 233                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False
# 268            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False
# 302                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi           False
# 303  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...            True
# 317            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False
# 318            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False
# 359  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...            True
# 361            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False
# 372                Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC           False
# 387                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False
# 433                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi           False
# 442     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster            True
# 475                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi           False
# 497                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi           False
# 525                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi           False
# 542                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False
# 559            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False
# 560            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False
# 563         Dual Sim, 3G, 4G, VoLTE, Wi-Fi, IR Blaster            True
# 570            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False
# 595                Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC           False
# 597                Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC           False
# 613                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False
# 625                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi           False
# 629  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...            True
# 639                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi           False
# 646                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi           False
# 662            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False
# 665                Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC           False
# 681                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi           False
# 687                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi           False
# 699           Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi           False
# 704            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False
# 726  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...            True
# 731                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi           False
# 733                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi           False
# 737            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False
# 765                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi           False
# 792     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster            True
# 817            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False
# 824                Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC           False
# 825                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False
# 827                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi           False
# 850            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False
# 851                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi           False
# 861     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster            True
# 880                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi           False
# 881                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi           False
# 891                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi           False
# 894      Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC           False
# 905  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...            True
# 916                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False
# 950                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi           False
# 954                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi           False
# 961            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False
# 974                            Dual Sim, 3G, 4G, Wi-Fi           False
#
#      has_5g  has_nfc                                          processor  \
# 96    False    False            Helio G35, Octa Core, 2.3 GHz Processor
# 109    True     True  Dimensity 8100 Max, Octa Core, 2.85 GHz Processor
# 147    True     True          Exynos 1200, Octa Core, 2.4 GHz Processor
# 153    True     True      Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 156    True    False       Snapdragon 695, Octa Core, 2.2 GHz Processor
# 233    True    False     Dimensity 700 5G, Octa Core, 2.2 GHz Processor
# 268    True     True   Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor
# 302   False    False       Snapdragon 680, Octa Core, 2.4 GHz Processor
# 303    True     True    Snapdragon  778G , Octa Core, 2.4 GHz Processor
# 317    True     True       Snapdragon 695, Octa Core, 2.2 GHz Processor
# 318    True     True    Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor
# 359    True     True  Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 361    True     True           Bionic A14, Hexa Core, 3.1 GHz Processor
# 372   False     True       Snapdragon 855, Octa Core, 2.8 GHz Processor
# 387    True    False     Dimensity 700 5G, Octa Core, 2.2 GHz Processor
# 433   False    False            Helio G37, Octa Core, 2.3 GHz Processor
# 442    True    False       Dimensity 1080, Octa Core, 2.6 GHz Processor
# 475   False    False              Helio A22, Quad Core, 2 GHz Processor
# 497   False    False          Tiger T612, Octa Core, 1.82 GHz Processor
# 525   False    False    Snapdragon  720G , Octa Core, 2.3 GHz Processor
# 542    True    False    Dimensity  810 5G, Octa Core, 2.4 GHz Processor
# 559    True     True          Dimensity 720, Octa Core, 2 GHz Processor
# 560    True     True    Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor
# 563   False    False      Snapdragon 720G, Octa Core, 2.3 GHz Processor
# 570    True     True      Snapdragon  695, Octa Core, 2.2 GHz Processor
# 595   False     True          A13 Bionic, Hexa Core, 2.65 GHz Processor
# 597   False     True     Snapdragon 4 Gen 1, Octa Core, 2 GHz Processor
# 613    True    False       Dimensity 800U, Octa Core, 2.4 GHz Processor
# 625   False    False          Helio  G96, Octa Core, 2.05 GHz Processor
# 629    True     True    Snapdragon  888 , Octa Core, 2.84 GHz Processor
# 639   False    False            Helio G35, Octa Core, 2.3 GHz Processor
# 646   False    False             Tiger T616, Octa Core, 2 GHz Processor
# 662    True     True     Snapdragon  765G, Octa Core, 2.4 GHz Processor
# 665   False     True          Exynos 9810, Octa Core, 2.7 GHz Processor
# 681   False    False         Unisoc  T606, Octa Core, 1.6 GHz Processor
# 687   False    False          Exynos 9611, Octa Core, 2.3 GHz Processor
# 699    True    False     Snapdragon  782G, Octa Core, 2.7 GHz Processor
# 704    True     True         Kirin 9000E, Octa Core, 3.13 GHz Processor
# 726    True     True     Snapdragon 865 , Octa Core, 2.84 GHz Processor
# 731   False    False       Snapdragon 712, Octa Core, 2.3 GHz Processor
# 733   False    False       Snapdragon 845, Octa Core, 2.8 GHz Processor
# 737    True     True                Dimensity 9200, Octa Core Processor
# 765   False    False            Helio P35, Octa Core, 2.3 GHz Processor
# 792    True    False     Snapdragon 4 Gen 1, Octa Core, 2 GHz Processor
# 817    True     True      Snapdragon  870, Octa Core, 3.2 GHz Processor
# 824   False     True         Exynos 9825, Octa Core, 2.73 GHz Processor
# 825    True    False          Dimensity 720, Octa Core, 2 GHz Processor
# 827   False    False              Helio G25, Octa Core, 2 GHz Processor
# 850    True     True      Snapdragon  695, Octa Core, 2.2 GHz Processor
# 851   False    False              Helio G85, Octa Core, 2 GHz Processor
# 861    True    False          Dimensity 720, Octa Core, 2 GHz Processor
# 880   False    False            Exynos  850, Octa Core, 2 GHz Processor
# 881   False    False       Snapdragon 460, Octa Core, 1.8 GHz Processor
# 891   False    False            Helio P70, Octa Core, 2.1 GHz Processor
# 894    True     True                    Bionic A16, Hexa Core Processor
# 905    True     True    Snapdragon 7 Gen1, Octa Core, 2.4 GHz Processor
# 916    True    False     Snapdragon  695 , Octa Core, 2.2 GHz Processor
# 950   False    False       Snapdragon 450, Octa Core, 1.8 GHz Processor
# 954   False    False                       Octa Core, 1.8 GHz Processor
# 961    True     True            Helio G35, Octa Core, 2.3 GHz Processor
# 974   False    False  Spreadtrum  SC9832E, Quad Core, 1.4 GHz Processor
#
#                            ram                                   battery  \
# 96     4 GB RAM, 64 GB inbuilt       5000 mAh Battery with Fast Charging
# 109  12 GB RAM, 256 GB inbuilt   5000 mAh Battery with 80W Fast Charging
# 147   6 GB RAM, 128 GB inbuilt   6000 mAh Battery with 25W Fast Charging
# 153   8 GB RAM, 128 GB inbuilt   5000 mAh Battery with 67W Fast Charging
# 156   8 GB RAM, 128 GB inbuilt   4500 mAh Battery with 33W Fast Charging
# 233   6 GB RAM, 128 GB inbuilt   5000 mAh Battery with 33W Fast Charging
# 268   8 GB RAM, 128 GB inbuilt   4700 mAh Battery with 66W Fast Charging
# 302   6 GB RAM, 128 GB inbuilt   6000 mAh Battery with 18W Fast Charging
# 303   6 GB RAM, 128 GB inbuilt   4250 mAh Battery with 33W Fast Charging
# 317   8 GB RAM, 128 GB inbuilt   4800 mAh Battery with 66W Fast Charging
# 318  16 GB RAM, 256 GB inbuilt  5000 mAh Battery with 120W Fast Charging
# 359   8 GB RAM, 128 GB inbuilt  5000 mAh Battery with
# 824   6 GB RAM, 128 GB inbuilt       7000 mAh Battery with Fast Charging
# 825   4 GB RAM, 128 GB inbuilt   5000 mAh Battery with 18W Fast Charging
# 827   4 GB RAM, 128 GB inbuilt   5000 mAh Battery with 10W Fast Charging
# 850   6 GB RAM, 128 GB inbuilt   4200 mAh Battery with 33W Fast Charging
# 851   6 GB RAM, 128 GB inbuilt                          7000 mAh Battery
# 861    6 GB RAM, 64 GB inbuilt   5000 mAh Battery with 33W Fast Charging
# 880    4 GB RAM, 64 GB inbuilt   6000 mAh Battery with 15W Fast Charging
# 881    4 GB RAM, 64 GB inbuilt   5000 mAh Battery with 18W Fast Charging
# 891    2 GB RAM, 16 GB inbuilt                          4000 mAh Battery
# 894   8 GB RAM, 128 GB inbuilt       4532 mAh Battery with Fast Charging
# 905   8 GB RAM, 128 GB inbuilt   4500 mAh Battery with 67W Fast Charging
# 916   4 GB RAM, 128 GB inbuilt   5000 mAh Battery with 18W Fast Charging
# 950    4 GB RAM, 64 GB inbuilt                          5000 mAh Battery
# 954    2 GB RAM, 32 GB inbuilt   4000 mAh Battery with 15W Fast Charging
# 961    4 GB RAM, 64 GB inbuilt   5180 mAh Battery with 10W Fast Charging
# 974    2 GB RAM, 32 GB inbuilt                          3020 mAh Battery
#
#                                                display  \
# 96   6.56 inches, 720 x 1612 px Display with Water ...
# 109  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# 147  6.5 inches, 1080 x 2400 px, 120 Hz Display wit...
# 153  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# 156  6.43 inches, 1080 x 2400 px Display with Punch...
# 233  6.56 inches, 720 x 1612 px, 90 Hz Display with...
# 268  6.67 inches, 1080 x 2400 px, 120 Hz Display wi...
# 302  6.7 inches, 720 x 1600 px Display with Water D...
# 303  6.55 inches, 1080 x 2400 px, 90 Hz Display wit...
# 317                6.81 inches, 1080 x 2388 px Display
# 318  6.78 inches, 1440 x 3200 px, 144 Hz Display wi...
# 359  6.67 inches, 1220 x 2712 px, 120 Hz Display wi...
# 361                 5.4 inches, 1080 x 2340 px Display
# 372                 5.7 inches, 1080 x 2280 px Display
# 387  6.5 inches, 1080 x 2400 px, 90 Hz Display with...
# 433  6.5 inches, 720 x 1600 px, 90 Hz Display with ...
# 442  6.67 inches, 1080 x 2400 px, 120 Hz Display wi...
# 475  6.56 inches, 720 x 1600 px Display with Water ...
# 497  6.52 inches, 720 x 1600 px Display with Water ...
# 525  6.44 inches, 1080 x 2400 px Display with Water...
# 542  6.5 inches, 1080 x 2400 px, 90 Hz Display with...
# 559  6.5 inches, 720 x 1600 px, 90 Hz Display with ...
# 560         6.8 inches, 1116 x 2480 px, 120 Hz Display
# 563  6.67 inches, 1080 x 2400 px Display with Punch...
# 570  6.58 inches, 1080 x 2400 px, 120 Hz Display wi...
# 595  6.5 inches, 1242 x 2688 px Display with Large ...
# 597         6.5 inches, 1080 x 2400 px, 120 Hz Display
# 613  6.44 inches, 1080 x 2400 px, 90 Hz Display wit...
# 625  6.8 inches, 1080 x 2460 px, 120 Hz Display wit...
# 629  6.67 inches, 1080 x 2400 px, 120 Hz Display wi...
# 639  6.53 inches, 720 x 1600 px Display with Water ...
# 646  6.6 inches, 720 x 1612 px, 90 Hz Display with ...
# 662  6.8 inches, 1080 x 2460 px Display with Water ...
# 665  6.7 inches, 1080 x 2400 px Display with Punch ...
# 681  6.5 inches, 720 x 1600 px, 90 Hz Display with ...
# 687  6.4 inches, 1080 x 2340 px Display with Water ...
# 699  6.67 inches, 1080 x 2408 px, 120 Hz Display wi...
# 704  6.76 inches, 1440 x 3200 px, 120 Hz Display wi...
# 726  6.67 inches, 1080 x 2400 px, 144 Hz Display wi...
# 731  6.4 inches, 1080 x 2340 px Display with Water ...
# 733  6.18 inches, 1080 x 2246 px Display with Large...
# 737  6.67 inches, 1080 x 2400 px, 120 Hz Display wi...
# 765  6.51 inches, 1600 x 720 px Display with Punch ...
# 792  6.73 inches, 1080 x 2408 px, 120 Hz Display wi...
# 817  6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 824  6.71 inches, 1080 x 2400 px Display with Punch...
# 825  6.5 inches, 720 x 1600 px Display with Water D...
# 827  6.53 inches, 720 x 1600 px Display with Water ...
# 850  6.43 inches, 1080 x 2400 px, 90 Hz Display wit...
# 851  6.82 inches, 720 x 1600 px, 90 Hz Display with...
# 861  6.52 inches, 1080 x 2400 px, 90 Hz Display wit...
# 880  6.5 inches, 720 x 1600 px, 90 Hz Display with ...
# 881  6.52 inches, 720 x 1600 px, 90 Hz Display with...
# 891  6.2 inches, 720 x 1520 px Display with Water D...
# 894  6.71 inches, 1284 x 2778 px, 120 Hz Display wi...
# 905  6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 916  6.58 inches, 1080 x 2412 px, 120 Hz Display wi...
# 950  6.5 inches, 720 x 1544 px Display with Water D...
# 954  6.4 inches, 720 x 1560 px Display with Punch Hole
# 961  6.1 inches, 720 x 1560 px Display with Punch Hole
# 974                     5 inches, 854 x 480 px Display
#
#                                                 camera  \
# 96          50 MP + 2 MP Dual Rear & 5 MP Front Camera
# 109  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 147               64 MP Quad Rear & 32 MP Front Camera
# 153       108 MP + 2 MP Dual Rear & 16 MP Front Camera
# 156  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 233         50 MP + 2 MP Dual Rear & 8 MP Front Camera
# 268  50 MP + 50 MP + 50 MP Triple Rear & 32 MP Fron...
# 302         50 MP + 2 MP Dual Rear & 5 MP Front Camera
# 303  64 MP + 8 MP + 5 MP Triple Rear & 20 MP Front ...
# 317  48 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 318  50 MP + 13 MP + 8 MP Triple Rear & 16 MP Front...
# 359  200 MP + 8 MP + 2 MP Triple Rear & 20 MP Front...
# 361       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 372  16 MP + 12.2 MP Dual Rear & 8 MP + TOF 3D Dual...
# 387  48 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 433         50 MP + 2 MP Dual Rear & 8 MP Front Camera
# 442  200 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
# 475                 8 MP Dual Rear & 5 MP Front Camera
# 497  13 MP + 2 MP + 2 MP Triple Rear & 5 MP Front C...
# 525  64 MP + 8 MP + 2 MP Triple Rear & 44 MP Front ...
# 542  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 559               48 MP Quad Rear & 13 MP Front Camera
# 560  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 563               64 MP Quad Rear & 32 MP Front Camera
# 570  50 MP + 5 MP + 2 MP Triple Rear & 8 MP Front C...
# 595  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 597        50 MP + 2 MP Dual Rear & 16 MP Front Camera
# 613  64 MP + 8 MP + 2 MP Triple Rear & 44 MP Front ...
# 625  64 MP + 50 MP + 2 MP Triple Rear & 32 MP Front...
# 629  108 MP + 8 MP + 5 MP Triple Rear & 16 MP Front...
# 639         13 MP + 2 MP Dual Rear & 5 MP Front Camera
# 646  50 MP + Depth Sensor Dual Rear & 8 MP Front Ca...
# 662  48 MP + 8 MP + 5 MP Triple Rear & 16 MP Front ...
# 665  12 MP + 12 MP + 12 MP Triple Rear & 32 MP Fron...
# 681  50 MP + 2 MP + 2 MP Triple Rear & 8 MP Front C...
# 687  48 MP + 8 MP + 5 MP Triple Rear & 20 MP Front ...
# 699  64 MP + 8 MP + 2 MP Triple Rear & 32 MP Front ...
# 704  64 MP + 50 MP + 13 MP Triple Rear & 13 MP Fron...
# 726  108 MP + 13 MP + 5 MP Triple Rear & 20 MP Fron...
# 731               64 MP Quad Rear & 16 MP Front Camera
# 733        12 MP + 5 MP Dual Rear & 20 MP Front Camera
# 737  50 MP + 13 MP + 2 MP Triple Rear & 32 MP Front...
# 765  13 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 792        64 MP + 2 MP Dual Rear & 16 MP Front Camera
# 817  50 MP + 13 MP + 2 MP Triple Rear & 32 MP Front...
# 824               64 MP Quad Rear & 32 MP Front Camera
# 825  13 MP + 2 MP + 2 MP Triple Rear & 8 MP Front C...
# 827                     13 MP Rear & 5 MP Front Camera
# 850       50 MP + 13 MP Dual Rear & 16 MP Front Camera
# 851         16 MP + 2 MP Dual Rear & 8 MP Front Camera
# 861  64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 880                48 MP Quad Rear & 8 MP Front Camera
# 881  13 MP + 2 MP + 2 MP Triple Rear & 8 MP Front C...
# 891         13 MP + 2 MP Dual Rear & 8 MP Front Camera
# 894       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 905  50 MP + 20 MP + 2 MP Triple Rear & 32 MP + 32 ...
# 916  50 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 950        13 MP + 2 MP Dual Rear & 13 MP Front Camera
# 954  13 MP + 5 MP + 2 MP Triple Rear & 8 MP Front C...
# 961                13 MP Dual Rear & 8 MP Front Camera
# 974                                   2 MP Rear Camera
#
#                                    card                   os
# 96     Memory Card Supported, upto 1 TB          Android v12
# 109                         Android v12          Android v12
# 147                Memory Card (Hybrid)          Android v12
# 153    Memory Card Supported, upto 1 TB          Android v12
# 156    Memory Card Supported, upto 1 TB          Android v12
# 233    Memory Card Supported, upto 1 TB          Android v12
# 268                         Android v13          Android v13
# 302  Memory Card Supported, upto 512 GB          Android v11
# 303                Memory Card (Hybrid)          Android v11
# 317                         Android v11          Android v11
# 318                         Android v13          Android v13
# 359                         Android v12          Android v12
# 361           Memory Card Not Supported              iOS v14
# 372           Memory Card Not Supported          Android v10
# 387    Memory Card Supported, upto 1 TB          Android v11
# 433    Memory Card Supported, upto 1 TB          Android v12
# 442           Memory Card Not Supported          Android v12
# 475    Memory Card Supported, upto 1 TB          Android v12
# 497    Memory Card Supported, upto 1 TB          Android v11
# 525    Memory Card Supported, upto 1 TB          Android v11
# 542    Memory Card Supported, upto 1 TB          Android v11
# 559     Memory Card (Hybrid), upto 1 TB          Android v11
# 560                         Android v13          Android v13
# 563  Memory Card Supported, upto 512 GB        Android v10.0
# 570                Memory Card (Hybrid)          Android v12
# 595           Memory Card Not Supported              iOS v13
# 597     Memory Card (Hybrid), upto 1 TB          Android v13
# 613                Memory Card (Hybrid)          Android v11
# 625                         Android v12          Android v12
# 629                         Android v11          Android v11
# 639  Memory Card Supported, upto 512 GB          Android v10
# 646  Memory Card Supported, upto 256 GB          Android v12
# 662                Memory Card (Hybrid)          Android v10
# 665     Memory Card (Hybrid), upto 1 TB        Android v10.0
# 681  Memory Card Supported, upto 512 GB          Android v11
# 687  Memory Card Supported, upto 512 GB          Android v11
# 699     Memory Card (Hybrid), upto 1 TB          Android v13
# 704           Memory Card Not Supported     Hongmeng OS v4.0
# 726                         Android v10          Android v10
# 731  Memory Card Supported, upto 256 GB   Android v9.0 (Pie)
# 733   Memory Card (Hybrid), upto 256 GB  Android v8.1 (Oreo)
# 737                         Android v13          Android v13
# 765  Memory Card Supported, upto 256 GB          Android v10
# 792    Memory Card Supported, upto 1 TB          Android v13
# 817                         Android v11          Android v11
# 824    Memory Card Supported, upto 1 TB          Android v11
# 825                         Android v10          Android v10
# 827  Memory Card Supported, upto 512 GB          Android v10
# 850    Memory Card Supported, upto 1 TB          Android v12
# 851  Memory Card Supported, upto 512 GB          Android v12
# 861  Memory Card Supported, upto 512 GB          Android v12
# 880    Memory Card Supported, upto 1 TB          Android v11
# 881  Memory Card Supported, upto 256 GB          Android v10
# 891  Memory Card Supported, upto 256 GB  Android v8.1 (Oreo)
# 894           Memory Card Not Supported              iOS v16
# 905                         Android v12          Android v12
# 916     Memory Card (Hybrid), upto 1 TB          Android v12
# 950  Memory Card Supported, upto 256 GB          Android v10
# 954  Memory Card Supported, upto 512 GB          Android v10
# 961               Memory Card Supported          Android v12
# 974                         Android v11          Android v11

# %%
df1.drop([155,271],inplace=True)

# %%
tems_df = df1[df1['index'].isin(camera_rows)]

# %%
tems_df = tems_df[~tems_df['camera'].str.contains('MP')]

# %%
df1.loc[tems_df.index,'camera'] = tems_df['card'].values

# %%
df1['card']
# Out:
# 0                Memory Card Not Supported
# 1          Memory Card (Hybrid), upto 1 TB
# 2         Memory Card Supported, upto 1 TB
# 3          Memory Card (Hybrid), upto 1 TB
# 4                Memory Card Not Supported
# 5         Memory Card Supported, upto 1 TB
# 6                Memory Card Not Supported
# 7                Memory Card Not Supported
# 8                              Android v12
# 9                              Android v12
# 10        Memory Card Supported, upto 1 TB
# 11                   Memory Card Supported
# 12                             Android v12
# 13         Memory Card (Hybrid), upto 1 TB
# 14               Memory Card Not Supported
# 15               Memory Card Not Supported
# 16                   Memory Card Supported
# 17                             Android v13
# 18                             Android v12
# 19        Memory Card Supported, upto 1 TB
# 20                             Android v13
# 21                             Android v12
# 22         Memory Card (Hybrid), upto 1 TB
# 23         Memory Card (Hybrid), upto 1 TB
# 24                             Android v13
# 25                    Memory Card (Hybrid)
# 26         Memory Card (Hybrid), upto 1 TB
# 27               Memory Card Not Supported
# 28         Memory Card (Hybrid), upto 1 TB
# 29                             Android v13
# 30        Memory Card Supported, upto 1 TB
# 31               Memory Card Not Supported
# 32                   Memory Card Supported
# 33               Memory Card Not Supported
# 34         Memory Card (Hybrid), upto 1 TB
# 35               Memory Card Not Supported
# 36        Memory Card Supported, upto 1 TB
# 37                             Android v12
# 38      Memory Card Supported, upto 512 GB
# 39                             Android v13
# 40        Memory Card Supported, upto 1 TB
# 41         Memory Card (Hybrid), upto 1 TB
# 42         Memory Card (Hybrid), upto 1 TB
# 43               Memory Card Not Supported
# 44        Memory Card Supported, upto 1 TB
# 45        Memory Card Supported, upto 1 TB
# 46      Memory Card Supported, upto 512 GB
# 47        Memory Card Supported, upto 1 TB
# 48                   Memory Card Supported
# 49         Memory Card (Hybrid), upto 1 TB
# 50        Memory Card Supported, upto 1 TB
# 51                             Android v13
# 52      Memory Card Supported, upto 512 GB
# 53        Memory Card Supported, upto 1 TB
# 54        Memory Card Supported, upto 1 TB
# 55        Memory Card Supported, upto 1 TB
# 56               Memory Card Not Supported
# 57      Memory Card Supported, upto 512 GB
# 58                             Android v13
# 59         Memory Card (Hybrid), upto 1 TB
# 60                             Android v12
# 61                             Android v13
# 62        Memory Card Supported, upto 1 TB
# 63        Memory Card Supported, upto 1 TB
# 64         Memory Card (Hybrid), upto 1 TB
# 65                             Android v13
# 66                             Android v12
# 67               Memory Card Not Supported
# 68        Memory Card Supported, upto 1 TB
# 69               Memory Card Not Supported
# 70        Memory Card Supported, upto 1 TB
# 71                   Memory Card Supported
# 72         Memory Card (Hybrid), upto 1 TB
# 73                             Android v12
# 74        Memory Card Supported, upto 1 TB
# 75                   Memory Card Supported
# 76               Memory Card Not Supported
# 77        Memory Card Supported, upto 1 TB
# 78         Memory Card (Hybrid), upto 1 TB
# 79      Memory Card Supported, upto 512 GB
# 80                    Memory Card (Hybrid)
# 81        Memory Card Supported, upto 1 TB
# 82        Memory Card Supported, upto 1 TB
# 83         Memory Card (Hybrid), upto 1 TB
# 84        Memory Card Supported, upto 1 TB
# 85                             Android v12
# 86        Memory Card Supported, upto 1 TB
# 87        Memory Card Supported, upto 1 TB
# 88      Memory Card Supported, upto 512 GB
# 89         Memory Card (Hybrid), upto 1 TB
# 90        Memory Card Supported, upto 1 TB
# 91                             Android v12
# 92         Memory Card (Hybrid), upto 1 TB
# 93                             Android v13
# 94        Memory Card Supported, upto 1 TB
# 95        Memory Card Supported, upto 1 TB
# 96        Memory Card Supported, upto 1 TB
# 97                             Android v13
# 98               Memory Card Not Supported
# 99         Memory Card (Hybrid), upto 1 TB
# 100              Memory Card Not Supported
# 101     Memory Card Supported, upto 512 GB
# 102                            Android v12
# 103       Memory Card Supported, upto 1 TB
# 104     Memory Card Supported, upto 256 GB
# 105              Memory Card Not Supported
# 106                            Android v13
# 107                            Android v12
# 108        Memory Card (Hybrid), upto 1 TB
# 109                            Android v12
# 110                            Android v12
# 111              Memory Card Not Supported
# 112                            Android v12
# 113       Memory Card Supported, upto 1 TB
# 114     Memory Card Supported, upto 512 GB
# 115                            Android v12
# 116        Memory Card (Hybrid), upto 1 TB
# 117              Memory Card Not Supported
# 118              Memory Card Not Supported
# 119                            Android v13
# 120                            Android v12
# 121                            Android v12
# 122              Memory Card Not Supported
# 123       Memory Card Supported, upto 2 TB
# 124       Memory Card Supported, upto 1 TB
# 125              Memory Card Not Supported
# 126       Memory Card Supported, upto 1 TB
# 127        Memory Card (Hybrid), upto 1 TB
# 128        Memory Card (Hybrid), upto 1 TB
# 129              Memory Card Not Supported
# 130     Memory Card Supported, upto 512 GB
# 131     Memory Card Supported, upto 512 GB
# 132       Memory Card Supported, upto 1 TB
# 133                            Android v12
# 134        Memory Card (Hybrid), upto 1 TB
# 135        Memory Card (Hybrid), upto 1 TB
# 136              Memory Card Not Supported
# 137       Memory Card Supported, upto 1 TB
# 138       Memory Card Supported, upto 1 TB
# 139                            Android v12
# 140        Memory Card (Hybrid), upto 1 TB
# 141                            Android v13
# 142        Memory Card (Hybrid), upto 1 TB
# 143     Memory Card Supported, upto 128 GB
# 144                  Memory Card Supported
# 145       Memory Card Supported, upto 1 TB
# 146                            Android v11
# 147                   Memory Card (Hybrid)
# 148     Memory Card Supported, upto 512 GB
# 149              Memory Card Not Supported
# 150        Memory Card (Hybrid), upto 1 TB
# 151                   Memory Card (Hybrid)
# 152              Memory Card Not Supported
# 153       Memory Card Supported, upto 1 TB
# 154     Memory Card Supported, upto 256 GB
# 156       Memory Card Supported, upto 1 TB
# 157     Memory Card Supported, upto 256 GB
# 158              Memory Card Not Supported
# 159     Memory Card Supported, upto 256 GB
# 160       Memory Card Supported, upto 1 TB
# 161              Memory Card Not Supported
# 162                            Android v13
# 163              Memory Card Not Supported
# 164       Memory Card Supported, upto 1 TB
# 165     Memory Card Supported, upto 512 GB
# 166       Memory Card Supported, upto 1 TB
# 167                            Android v12
# 168       Memory Card Supported, upto 1 TB
# 169                            Android v11
# 170     Memory Card Supported, upto 512 GB
# 171      Memory Card (Hybrid), upto 256 GB
# 172                  Memory Card Supported
# 173              Memory Card Not Supported
# 174        Memory Card (Hybrid), upto 1 TB
# 175     Memory Card Supported, upto 512 GB
# 176     Memory Card Supported, upto 256 GB
# 177                   Memory Card (Hybrid)
# 178        Memory Card (Hybrid), upto 1 TB
# 179       Memory Card Supported, upto 1 TB
# 180                  Memory Card Supported
# 181     Memory Card Supported, upto 256 GB
# 182                            Android v13
# 183       Memory Card Supported, upto 1 TB
# 184       Memory Card Supported, upto 1 TB
# 185                            Android v11
# 186       Memory Card Supported, upto 1 TB
# 187      Memory Card (Hybrid), upto 128 GB
# 188                            Android v11
# 189     Memory Card Supported, upto 128 GB
# 190                  Memory Card Supported
# 191        Memory Card (Hybrid), upto 1 TB
# 192                  Memory Card Supported
# 193              Memory Card Not Supported
# 194       Memory Card Supported, upto 1 TB
# 195                            Android v12
# 196        Memory Card (Hybrid), upto 1 TB
# 197        Memory Card (Hybrid), upto 1 TB
# 198       Memory Card Supported, upto 1 TB
# 199                  Memory Card Supported
# 200       Memory Card Supported, upto 1 TB
# 201                            Android v12
# 202                            Android v12
# 203                   Memory Card (Hybrid)
# 204     Memory Card Supported, upto 512 GB
# 205                            Android v12
# 206       Memory Card Supported, upto 1 TB
# 207     Memory Card Supported, upto 512 GB
# 208                            Android v12
# 209              Memory Card Not Supported
# 210                            Android v12
# 211       Memory Card Supported, upto 1 TB
# 212     Memory Card Supported, upto 256 GB
# 213       Memory Card Supported, upto 1 TB
# 214                            Android v12
# 215                            Android v13
# 216     Memory Card Supported, upto 256 GB
# 217              Memory Card Not Supported
# 218       Memory Card Supported, upto 1 TB
# 219                            Android v13
# 220              Memory Card Not Supported
# 221       Memory Card Supported, upto 1 TB
# 222                            Android v12
# 223     Memory Card Supported, upto 512 GB
# 224       Memory Card Supported, upto 1 TB
# 225     Memory Card Supported, upto 512 GB
# 226       Memory Card Supported, upto 1 TB
# 227                            Android v12
# 228                            Android v12
# 229                            Android v12
# 230                            Android v13
# 231                  Memory Card Supported
# 232                  Memory Card Supported
# 233       Memory Card Supported, upto 1 TB
# 234        Memory Card (Hybrid), upto 1 TB
# 235              Memory Card Not Supported
# 236                  Memory Card Supported
# 237       Memory Card Supported, upto 1 TB
# 238        Memory Card (Hybrid), upto 1 TB
# 239     Memory Card Supported, upto 512 GB
# 240                  Memory Card Supported
# 241        Memory Card (Hybrid), upto 1 TB
# 242        Memory Card (Hybrid), upto 1 TB
# 243                            Android v13
# 244        Memory Card (Hybrid), upto 1 TB
# 245     Memory Card Supported, upto 512 GB
# 246              Memory Card Not Supported
# 247                   Memory Card (Hybrid)
# 248                            Android v13
# 249        Memory Card (Hybrid), upto 1 TB
# 250                            Android v12
# 251       Memory Card Supported, upto 2 TB
# 252        Memory Card (Hybrid), upto 1 TB
# 253                   Memory Card (Hybrid)
# 254       Memory Card Supported, upto 1 TB
# 255              Memory Card Not Supported
# 256                            Android v12
# 257                            Android v11
# 258     Memory Card Supported, upto 512 GB
# 259     Memory Card Supported, upto 512 GB
# 260     Memory Card Supported, upto 512 GB
# 261     Memory Card Supported, upto 512 GB
# 262              Memory Card Not Supported
# 263       Memory Card Supported, upto 1 TB
# 264       Memory Card Supported, upto 2 TB
# 265                  Memory Card Supported
# 266                            Android v13
# 267        Memory Card (Hybrid), upto 1 TB
# 268                            Android v13
# 269       Memory Card Supported, upto 1 TB
# 270                            Android v12
# 272     Memory Card Supported, upto 512 GB
# 273        Memory Card (Hybrid), upto 1 TB
# 274                            Android v12
# 275              Memory Card Not Supported
# 276     Memory Card Supported, upto 256 GB
# 277       Memory Card Supported, upto 1 TB
# 278              Memory Card Not Supported
# 279                   Memory Card (Hybrid)
# 280              Memory Card Not Supported
# 281       Memory Card Supported, upto 1 TB
# 282              Memory Card Not Supported
# 283       Memory Card Supported, upto 1 TB
# 284                            Android v12
# 285              Memory Card Not Supported
# 286       Memory Card Supported, upto 2 TB
# 287       Memory Card Supported, upto 1 TB
# 288              Memory Card Not Supported
# 289       Memory Card Supported, upto 1 TB
# 290        Memory Card (Hybrid), upto 1 TB
# 291     Memory Card Supported, upto 512 GB
# 292                  Memory Card Supported
# 293       Memory Card Supported, upto 1 TB
# 294                            Android v12
# 295     Memory Card Supported, upto 512 GB
# 296                            Android v13
# 297     Memory Card Supported, upto 512 GB
# 298                  Memory Card Supported
# 299                            Android v12
# 300       Memory Card Supported, upto 1 TB
# 301      Memory Card (Hybrid), upto 512 GB
# 302     Memory Card Supported, upto 512 GB
# 303                   Memory Card (Hybrid)
# 304              Memory Card Not Supported
# 305              Memory Card Not Supported
# 306                            Android v12
# 307       Memory Card Supported, upto 1 TB
# 308       Memory Card Supported, upto 1 TB
# 309                            Android v11
# 310       Memory Card Supported, upto 1 TB
# 311                            Android v12
# 312              Memory Card Not Supported
# 313      Memory Card Supported, upto 32 GB
# 314              Memory Card Not Supported
# 315       Memory Card Supported, upto 1 TB
# 316              Memory Card Not Supported
# 317                            Android v11
# 318                            Android v13
# 319              Memory Card Not Supported
# 320              Memory Card Not Supported
# 321              Memory Card Not Supported
# 322        Memory Card (Hybrid), upto 1 TB
# 323     Memory Card Supported, upto 256 GB
# 324                            Android v12
# 325     Memory Card Supported, upto 512 GB
# 326                            Android v10
# 327     Memory Card Supported, upto 256 GB
# 328                  Memory Card Supported
# 329     Memory Card Supported, upto 256 GB
# 330              Memory Card Not Supported
# 331        Memory Card (Hybrid), upto 1 TB
# 332       Memory Card Supported, upto 1 TB
# 333                            Android v12
# 334     Memory Card Supported, upto 512 GB
# 335       Memory Card Supported, upto 1 TB
# 336        Memory Card (Hybrid), upto 1 TB
# 337              Memory Card Not Supported
# 338     Memory Card Supported, upto 512 GB
# 339     Memory Card Supported, upto 512 GB
# 340                            Android v12
# 341       Memory Card Supported, upto 1 TB
# 342       Memory Card Supported, upto 1 TB
# 343                  Memory Card Supported
# 344              Memory Card Not Supported
# 345                            Android v13
# 346              Memory Card Not Supported
# 347        Memory Card (Hybrid), upto 1 TB
# 348       Memory Card Supported, upto 1 TB
# 349     Memory Card Supported, upto 512 GB
# 350     Memory Card Supported, upto 512 GB
# 351     Memory Card Supported, upto 256 GB
# 352                            Android v13
# 353       Memory Card Supported, upto 1 TB
# 354       Memory Card Supported, upto 1 TB
# 355                  Memory Card Supported
# 356     Memory Card Supported, upto 512 GB
# 357                            Android v12
# 358     Memory Card Supported, upto 256 GB
# 359                            Android v12
# 360                            Android v12
# 361              Memory Card Not Supported
# 362              Memory Card Not Supported
# 363              Memory Card Not Supported
# 364                            Android v12
# 365     Memory Card Supported, upto 256 GB
# 366              Memory Card Not Supported
# 367        Memory Card (Hybrid), upto 1 TB
# 368        Memory Card (Hybrid), upto 1 TB
# 369                            Android v11
# 370      Memory Card (Hybrid), upto 512 GB
# 371        Memory Card (Hybrid), upto 1 TB
# 372              Memory Card Not Supported
# 373      Memory Card (Hybrid), upto 512 GB
# 374              Memory Card Not Supported
# 375     Memory Card Supported, upto 256 GB
# 377                            Android v10
# 378       Memory Card Supported, upto 1 TB
# 379                  Memory Card Supported
# 380                            Android v11
# 381     Memory Card Supported, upto 256 GB
# 382        Memory Card (Hybrid), upto 1 TB
# 383        Memory Card (Hybrid), upto 1 TB
# 384              Memory Card Not Supported
# 385       Memory Card Supported, upto 1 TB
# 386       Memory Card Supported, upto 1 TB
# 387       Memory Card Supported, upto 1 TB
# 388     Memory Card Supported, upto 256 GB
# 389              Memory Card Not Supported
# 390       Memory Card Supported, upto 1 TB
# 391                  Memory Card Supported
# 392     Memory Card Supported, upto 256 GB
# 393     Memory Card Supported, upto 512 GB
# 394                  Memory Card Supported
# 395     Memory Card Supported, upto 512 GB
# 396                     Android v9.0 (Pie)
# 397                            Android v13
# 398              Memory Card Not Supported
# 399     Memory Card Supported, upto 512 GB
# 400        Memory Card (Hybrid), upto 1 TB
# 401       Memory Card Supported, upto 1 TB
# 402        Memory Card (Hybrid), upto 1 TB
# 403              Memory Card Not Supported
# 404              Memory Card Not Supported
# 405        Memory Card (Hybrid), upto 1 TB
# 406              Memory Card Not Supported
# 407                  Memory Card Supported
# 408       Memory Card Supported, upto 1 TB
# 409       Memory Card Supported, upto 1 TB
# 410                  Memory Card Supported
# 411                            Android v11
# 412              Memory Card Not Supported
# 413              Memory Card Not Supported
# 414     Memory Card Supported, upto 512 GB
# 415              Memory Card Not Supported
# 416              Memory Card Not Supported
# 417              Memory Card Not Supported
# 418                            Android v12
# 419                            Android v12
# 420                            Android v12
# 421                          Android v12.1
# 422              Memory Card Not Supported
# 423     Memory Card Supported, upto 256 GB
# 424                            Android v11
# 425                  Memory Card Supported
# 426     Memory Card Supported, upto 512 GB
# 427              Memory Card Not Supported
# 428       Memory Card Supported, upto 1 TB
# 429     Memory Card Supported, upto 512 GB
# 430                            Android v12
# 431                  Memory Card Supported
# 432        Memory Card (Hybrid), upto 1 TB
# 433       Memory Card Supported, upto 1 TB
# 434     Memory Card Supported, upto 512 GB
# 435              Memory Card Not Supported
# 436       Memory Card Supported, upto 1 TB
# 437                   Memory Card (Hybrid)
# 438     Memory Card Supported, upto 512 GB
# 439       Memory Card Supported, upto 1 TB
# 440      Memory Card (Hybrid), upto 512 GB
# 441              Memory Card Not Supported
# 442              Memory Card Not Supported
# 443     Memory Card Supported, upto 512 GB
# 444              Memory Card Not Supported
# 445       Memory Card Supported, upto 1 TB
# 446     Memory Card Supported, upto 512 GB
# 447              Memory Card Not Supported
# 448       Memory Card Supported, upto 1 TB
# 449                            Android v11
# 450       Memory Card Supported, upto 1 TB
# 451     Memory Card Supported, upto 512 GB
# 452                            Android v12
# 453      Memory Card (Hybrid), upto 512 GB
# 454                            Android v12
# 455                  Memory Card Supported
# 456     Memory Card Supported, upto 512 GB
# 457       Memory Card Supported, upto 1 TB
# 458              Memory Card Not Supported
# 459                            Android v13
# 460                            Android v13
# 461       Memory Card Supported, upto 1 TB
# 462     Memory Card Supported, upto 512 GB
# 463     Memory Card Supported, upto 256 GB
# 464        Memory Card (Hybrid), upto 1 TB
# 465                  Memory Card Supported
# 466                   Memory Card (Hybrid)
# 467     Memory Card Supported, upto 256 GB
# 468     Memory Card Supported, upto 512 GB
# 469       Memory Card Supported, upto 1 TB
# 470       Memory Card Supported, upto 1 TB
# 471      Memory Card (Hybrid), upto 256 GB
# 472     Memory Card Supported, upto 128 GB
# 473       Memory Card (Hybrid), upto 64 GB
# 474        Memory Card (Hybrid), upto 1 TB
# 475       Memory Card Supported, upto 1 TB
# 476                  Memory Card Supported
# 477              Memory Card Not Supported
# 478      Memory Card (Hybrid), upto 256 GB
# 479       Memory Card Supported, upto 1 TB
# 480        Memory Card (Hybrid), upto 1 TB
# 481                  Memory Card Supported
# 482                   Memory Card (Hybrid)
# 483     Memory Card Supported, upto 256 GB
# 484                   Memory Card (Hybrid)
# 485       Memory Card Supported, upto 1 TB
# 486                  Memory Card Supported
# 487                  Memory Card Supported
# 488                            Android v12
# 489                  Memory Card Supported
# 490                            Android v12
# 491       Memory Card Supported, upto 1 TB
# 492              Memory Card Not Supported
# 493       Memory Card Supported, upto 1 TB
# 494       Memory Card Supported, upto 1 TB
# 495                            Android v11
# 496     Memory Card Supported, upto 512 GB
# 497       Memory Card Supported, upto 1 TB
# 498        Memory Card (Hybrid), upto 1 TB
# 499              Memory Card Not Supported
# 500              Memory Card Not Supported
# 501              Memory Card Not Supported
# 502     Memory Card Supported, upto 512 GB
# 503                            Android v12
# 504     Memory Card Supported, upto 256 GB
# 505       Memory Card Supported, upto 1 TB
# 506       Memory Card Supported, upto 1 TB
# 507       Memory Card Supported, upto 1 TB
# 508                   Memory Card (Hybrid)
# 509        Memory Card (Hybrid), upto 1 TB
# 510                            Android v11
# 511                            Android v13
# 512              Memory Card Not Supported
# 513       Memory Card Supported, upto 1 TB
# 514                            Android v12
# 515              Memory Card Not Supported
# 516        Memory Card (Hybrid), upto 1 TB
# 517                  Memory Card Supported
# 518              Memory Card Not Supported
# 519       Memory Card Supported, upto 1 TB
# 520                            Android v11
# 521                            Android v12
# 522              Memory Card Not Supported
# 523                  Memory Card Supported
# 524       Memory Card Supported, upto 1 TB
# 525       Memory Card Supported, upto 1 TB
# 526     Memory Card Supported, upto 512 GB
# 527                            Android v12
# 528                            Android v12
# 529     Memory Card Supported, upto 256 GB
# 530     Memory Card Supported, upto 256 GB
# 531     Memory Card Supported, upto 512 GB
# 532     Memory Card Supported, upto 512 GB
# 533                            Android v12
# 534                            Android v12
# 535       Memory Card Supported, upto 1 TB
# 536                  Memory Card Supported
# 537                            Android v12
# 538                            Android v12
# 539                  Memory Card Supported
# 540    Memory Card Supported, upto 1000 GB
# 541       Memory Card Supported, upto 1 TB
# 542       Memory Card Supported, upto 1 TB
# 543                  Memory Card Supported
# 544              Memory Card Not Supported
# 545     Memory Card Supported, upto 512 GB
# 546                            Android v11
# 547     Memory Card Supported, upto 256 GB
# 548        Memory Card (Hybrid), upto 1 TB
# 549                            Android v12
# 550       Memory Card Supported, upto 1 TB
# 551                            Android v12
# 552     Memory Card Supported, upto 256 GB
# 553                            Android v13
# 554        Memory Card (Hybrid), upto 1 TB
# 555       Memory Card Supported, upto 1 TB
# 556     Memory Card Supported, upto 256 GB
# 557                            Android v11
# 558                            Android v11
# 559        Memory Card (Hybrid), upto 1 TB
# 560                            Android v13
# 561              Memory Card Not Supported
# 562              Memory Card Not Supported
# 563     Memory Card Supported, upto 512 GB
# 564       Memory Card Supported, upto 1 TB
# 565                  Memory Card Supported
# 566       Memory Card Supported, upto 1 TB
# 567                  Memory Card Supported
# 568       Memory Card Supported, upto 1 TB
# 569                            Android v13
# 570                   Memory Card (Hybrid)
# 571                  Memory Card Supported
# 572                            Android v12
# 573                            Android v12
# 574              Memory Card Not Supported
# 575     Memory Card Supported, upto 512 GB
# 576       Memory Card Supported, upto 1 TB
# 577     Memory Card Supported, upto 256 GB
# 578     Memory Card Supported, upto 512 GB
# 579                  Memory Card Supported
# 580                            Android v12
# 581        Memory Card (Hybrid), upto 1 TB
# 583                            Android v12
# 584     Memory Card Supported, upto 256 GB
# 585     Memory Card Supported, upto 512 GB
# 586                  Memory Card Supported
# 587                  Memory Card Supported
# 588     Memory Card Supported, upto 512 GB
# 589     Memory Card Supported, upto 256 GB
# 590       Memory Card Supported, upto 1 TB
# 591                   Memory Card (Hybrid)
# 592     Memory Card Supported, upto 256 GB
# 593              Memory Card Not Supported
# 594        Memory Card (Hybrid), upto 1 TB
# 595              Memory Card Not Supported
# 596                                iOS v10
# 597        Memory Card (Hybrid), upto 1 TB
# 598       Memory Card Supported, upto 1 TB
# 599        Memory Card (Hybrid), upto 1 TB
# 600              Memory Card Not Supported
# 601                  Memory Card Supported
# 602                            Android v12
# 603        Memory Card (Hybrid), upto 1 TB
# 604        Memory Card (Hybrid), upto 1 TB
# 605        Memory Card (Hybrid), upto 1 TB
# 606     Memory Card Supported, upto 512 GB
# 607        Memory Card (Hybrid), upto 1 TB
# 608     Memory Card Supported, upto 256 GB
# 609     Memory Card Supported, upto 256 GB
# 610        Memory Card (Hybrid), upto 1 TB
# 611     Memory Card Supported, upto 256 GB
# 612                  Memory Card Supported
# 613                   Memory Card (Hybrid)
# 614      Memory Card Supported, upto 32 GB
# 615              Memory Card Not Supported
# 616                   Memory Card (Hybrid)
# 617                          Android v10.0
# 618                            Android v10
# 619                  Memory Card Supported
# 620                            Android v12
# 621                            Android v12
# 622       Memory Card Supported, upto 1 TB
# 623              Memory Card Not Supported
# 624                            Android v12
# 625                            Android v12
# 626                  Memory Card Supported
# 627                            Android v12
# 628              Memory Card Not Supported
# 629                            Android v11
# 630                            Android v11
# 631       Memory Card Supported, upto 1 TB
# 632       Memory Card Supported, upto 1 TB
# 633      Memory Card (Hybrid), upto 256 GB
# 634     Memory Card Supported, upto 256 GB
# 635              Memory Card Not Supported
# 636                            Android v11
# 637       Memory Card Supported, upto 1 TB
# 638                  Memory Card Supported
# 639     Memory Card Supported, upto 512 GB
# 640                                iOS v13
# 641                            Android v11
# 642                            Android v13
# 643              Memory Card Not Supported
# 644                  Memory Card Supported
# 645                   Memory Card (Hybrid)
# 646     Memory Card Supported, upto 256 GB
# 647       Memory Card Supported, upto 1 TB
# 648     Memory Card Supported, upto 128 GB
# 649                  Memory Card Supported
# 650              Memory Card Not Supported
# 651                            Android v12
# 652                  Memory Card Supported
# 653     Memory Card Supported, upto 512 GB
# 654     Memory Card Supported, upto 256 GB
# 655                  Memory Card Supported
# 656     Memory Card Supported, upto 512 GB
# 657                  Memory Card Supported
# 658                            Android v11
# 659     Memory Card Supported, upto 512 GB
# 660     Memory Card Supported, upto 512 GB
# 661                            Android v10
# 662                   Memory Card (Hybrid)
# 663        Memory Card (Hybrid), upto 1 TB
# 664              Memory Card Not Supported
# 665        Memory Card (Hybrid), upto 1 TB
# 666      Memory Card (Hybrid), upto 512 GB
# 667                            Android v13
# 668       Memory Card Supported, upto 1 TB
# 669       Memory Card Supported, upto 1 TB
# 670       Memory Card Supported, upto 1 TB
# 671     Memory Card Supported, upto 128 GB
# 672     Memory Card Supported, upto 512 GB
# 673        Memory Card (Hybrid), upto 1 TB
# 674       Memory Card Supported, upto 1 TB
# 675       Memory Card Supported, upto 1 TB
# 676     Memory Card Supported, upto 256 GB
# 677                   Memory Card (Hybrid)
# 678     Memory Card Supported, upto 512 GB
# 679                   Memory Card (Hybrid)
# 680                            Android v12
# 681     Memory Card Supported, upto 512 GB
# 682              Memory Card Not Supported
# 683              Memory Card Not Supported
# 684              Memory Card Not Supported
# 685       Memory Card Supported, upto 1 TB
# 686     Memory Card Supported, upto 256 GB
# 687     Memory Card Supported, upto 512 GB
# 688     Memory Card Supported, upto 256 GB
# 689              Memory Card Not Supported
# 690     Memory Card Supported, upto 512 GB
# 691     Memory Card Supported, upto 256 GB
# 692     Memory Card Supported, upto 512 GB
# 693     Memory Card Supported, upto 256 GB
# 694        Memory Card (Hybrid), upto 1 TB
# 695     Memory Card Supported, upto 512 GB
# 696        Memory Card (Hybrid), upto 1 TB
# 697     Memory Card Supported, upto 256 GB
# 698      Memory Card (Hybrid), upto 256 GB
# 699        Memory Card (Hybrid), upto 1 TB
# 700                   Memory Card (Hybrid)
# 701              Memory Card Not Supported
# 702                            Android v12
# 703                            Android v12
# 704              Memory Card Not Supported
# 705       Memory Card Supported, upto 1 TB
# 706              Memory Card Not Supported
# 707       Memory Card Supported, upto 1 TB
# 708              Memory Card Not Supported
# 709       Memory Card Supported, upto 2 TB
# 710     Memory Card Supported, upto 256 GB
# 711                  Memory Card Supported
# 712                            Android v11
# 713     Memory Card Supported, upto 512 GB
# 714                         HarmonyOS v2.0
# 715                  Memory Card Supported
# 716      Memory Card (Hybrid), upto 256 GB
# 717                            Android v12
# 718     Memory Card Supported, upto 256 GB
# 719                  Memory Card Supported
# 720                            Android v11
# 721                  Memory Card Supported
# 722                            Android v11
# 723     Memory Card Supported, upto 512 GB
# 724      Memory Card Supported, upto 32 GB
# 725                            Android v10
# 726                            Android v10
# 727     Memory Card Supported, upto 512 GB
# 728        Memory Card (Hybrid), upto 1 TB
# 729     Memory Card Supported, upto 256 GB
# 730     Memory Card Supported, upto 256 GB
# 731     Memory Card Supported, upto 256 GB
# 732     Memory Card Supported, upto 256 GB
# 733      Memory Card (Hybrid), upto 256 GB
# 734     Memory Card Supported, upto 512 GB
# 735      Memory Card (Hybrid), upto 128 GB
# 736                            Android v13
# 737                            Android v13
# 738                            Android v12
# 739              Memory Card Not Supported
# 740       Memory Card Supported, upto 1 TB
# 741              Memory Card Not Supported
# 742                            Android v13
# 743                            Android v12
# 744                   Memory Card (Hybrid)
# 745                            Android v12
# 746                            Android v12
# 747                            Android v12
# 748       Memory Card Supported, upto 1 TB
# 749                            Android v11
# 750       Memory Card Supported, upto 1 TB
# 751                            Android v12
# 752       Memory Card Supported, upto 1 TB
# 753        Memory Card (Hybrid), upto 1 TB
# 755     Memory Card Supported, upto 256 GB
# 756       Memory Card Supported, upto 1 TB
# 757     Memory Card Supported, upto 512 GB
# 758              Memory Card Not Supported
# 759                  Memory Card Supported
# 760              Memory Card Not Supported
# 761       Memory Card Supported, upto 1 TB
# 762                            Android v12
# 763     Memory Card Supported, upto 256 GB
# 764       Memory Card Supported, upto 1 TB
# 765     Memory Card Supported, upto 256 GB
# 766                  Memory Card Supported
# 767              Memory Card Not Supported
# 768       Memory Card Supported, upto 1 TB
# 769     Memory Card Supported, upto 256 GB
# 770     Memory Card Supported, upto 256 GB
# 771      Memory Card Supported, upto 32 GB
# 772     Memory Card Supported, upto 512 GB
# 773                            Android v10
# 774     Memory Card Supported, upto 512 GB
# 775        Memory Card (Hybrid), upto 1 TB
# 776     Memory Card Supported, upto 256 GB
# 777      Memory Card (Hybrid), upto 256 GB
# 778     Memory Card Supported, upto 256 GB
# 779     Memory Card Supported, upto 256 GB
# 780     Memory Card Supported, upto 256 GB
# 781     Memory Card Supported, upto 256 GB
# 782      Memory Card (Hybrid), upto 512 GB
# 783                            Android v13
# 784              Memory Card Not Supported
# 785       Memory Card Supported, upto 1 TB
# 786       Memory Card Supported, upto 1 TB
# 787                            Android v13
# 788                  Memory Card Supported
# 789                            Android v12
# 790              Memory Card Not Supported
# 791              Memory Card Not Supported
# 792       Memory Card Supported, upto 1 TB
# 793     Memory Card Supported, upto 512 GB
# 794                  Memory Card Supported
# 795                  Memory Card Supported
# 796                            Android v12
# 797       Memory Card Supported, upto 1 TB
# 798                            Android v12
# 799                  Memory Card Supported
# 800     Memory Card Supported, upto 512 GB
# 801              Memory Card Not Supported
# 802       Memory Card Supported, upto 1 TB
# 803              Memory Card Not Supported
# 804       Memory Card Supported, upto 1 TB
# 805                  Memory Card Supported
# 806     Memory Card Supported, upto 512 GB
# 807        Memory Card (Hybrid), upto 1 TB
# 808              Memory Card Not Supported
# 809        Memory Card (Hybrid), upto 1 TB
# 810       Memory Card Supported, upto 1 TB
# 811                            Android v11
# 812       Memory Card Supported, upto 1 TB
# 813                  Memory Card Supported
# 814     Memory Card Supported, upto 512 GB
# 815              Memory Card Not Supported
# 816     Memory Card Supported, upto 256 GB
# 817                            Android v11
# 818                            Android v12
# 819              Memory Card Not Supported
# 820      Memory Card (Hybrid), upto 512 GB
# 821                  Memory Card Supported
# 822                            Android v11
# 823                            Android v10
# 824       Memory Card Supported, upto 1 TB
# 825                            Android v10
# 826              Memory Card Not Supported
# 827     Memory Card Supported, upto 512 GB
# 828     Memory Card Supported, upto 256 GB
# 829                  Memory Card Supported
# 830                            Android v11
# 831     Memory Card Supported, upto 256 GB
# 832                   Memory Card (Hybrid)
# 833     Memory Card Supported, upto 256 GB
# 834      Memory Card (Hybrid), upto 256 GB
# 835     Memory Card Supported, upto 256 GB
# 836     Memory Card Supported, upto 256 GB
# 837     Memory Card Supported, upto 512 GB
# 838     Memory Card Supported, upto 512 GB
# 839      Memory Card (Hybrid), upto 512 GB
# 840                     Android v9.0 (Pie)
# 841     Memory Card Supported, upto 512 GB
# 842      Memory Card (Hybrid), upto 512 GB
# 843      Memory Card (Hybrid), upto 256 GB
# 844      Memory Card (Hybrid), upto 128 GB
# 845        Memory Card (Hybrid), upto 2 TB
# 846                   Memory Card (Hybrid)
# 847        Memory Card (Hybrid), upto 1 TB
# 848                  Memory Card Supported
# 849     Memory Card Supported, upto 512 GB
# 850       Memory Card Supported, upto 1 TB
# 851     Memory Card Supported, upto 512 GB
# 852       Memory Card Supported, upto 1 TB
# 853                              HarmonyOS
# 854                  Memory Card Supported
# 855              Memory Card Not Supported
# 856     Memory Card Supported, upto 256 GB
# 857                            Android v12
# 858       Memory Card Supported, upto 1 TB
# 859                            Android v12
# 860                            Android v12
# 861     Memory Card Supported, upto 512 GB
# 862                  Memory Card Supported
# 863              Memory Card Not Supported
# 864                            Android v11
# 865                            Android v11
# 866                  Memory Card Supported
# 867                            Android v11
# 868                  Memory Card Supported
# 869     Memory Card Supported, upto 256 GB
# 870     Memory Card Supported, upto 256 GB
# 871       Memory Card Supported, upto 1 TB
# 872      Memory Card (Hybrid), upto 256 GB
# 873              Memory Card Not Supported
# 874     Memory Card Supported, upto 256 GB
# 875      Memory Card (Hybrid), upto 256 GB
# 876                            Android v10
# 877                            Android v10
# 878                            Android v11
# 879     Memory Card Supported, upto 256 GB
# 880       Memory Card Supported, upto 1 TB
# 881     Memory Card Supported, upto 256 GB
# 882              Memory Card Not Supported
# 883              Memory Card Not Supported
# 884     Memory Card Supported, upto 256 GB
# 885     Memory Card Supported, upto 512 GB
# 886     Memory Card Supported, upto 256 GB
# 887              Memory Card Not Supported
# 888        Memory Card (Hybrid), upto 1 TB
# 889              Memory Card Not Supported
# 890     Memory Card Supported, upto 512 GB
# 891     Memory Card Supported, upto 256 GB
# 892                  Memory Card Supported
# 893       Memory Card (Hybrid), upto 64 GB
# 894              Memory Card Not Supported
# 895                  Memory Card Supported
# 896     Memory Card Supported, upto 256 GB
# 897                            Android v13
# 898                            Android v12
# 899                  Memory Card Supported
# 900     Memory Card Supported, upto 512 GB
# 901                  Memory Card Supported
# 902     Memory Card Supported, upto 256 GB
# 903                   Memory Card (Hybrid)
# 904                   Memory Card (Hybrid)
# 905                            Android v12
# 906                   Memory Card (Hybrid)
# 907              Memory Card Not Supported
# 908                            Android v12
# 909                            Android v12
# 910                            Android v12
# 911                            Android v12
# 912       Memory Card Supported, upto 1 TB
# 913       Memory Card Supported, upto 1 TB
# 914     Memory Card Supported, upto 512 GB
# 915              Memory Card Not Supported
# 916        Memory Card (Hybrid), upto 1 TB
# 917        Memory Card (Hybrid), upto 1 TB
# 918              Memory Card Not Supported
# 919              Memory Card Not Supported
# 920     Memory Card Supported, upto 256 GB
# 921              Memory Card Not Supported
# 922                  Memory Card Supported
# 923        Memory Card (Hybrid), upto 1 TB
# 924       Memory Card Supported, upto 1 TB
# 925              Memory Card Not Supported
# 926                            Android v11
# 927     Memory Card Supported, upto 256 GB
# 928                  Memory Card Supported
# 929                  Memory Card Supported
# 930       Memory Card Supported, upto 1 TB
# 931                            Android v11
# 932              Memory Card Not Supported
# 933     Memory Card Supported, upto 256 GB
# 934     Memory Card Supported, upto 256 GB
# 935                            Android v11
# 936                  Memory Card Supported
# 937       Memory Card Supported, upto 1 TB
# 938                            Android v11
# 939                            Android v11
# 940     Memory Card Supported, upto 512 GB
# 941     Memory Card Supported, upto 512 GB
# 942     Memory Card Supported, upto 512 GB
# 943     Memory Card Supported, upto 512 GB
# 944                  Memory Card Supported
# 945     Memory Card Supported, upto 256 GB
# 946     Memory Card Supported, upto 256 GB
# 947     Memory Card Supported, upto 128 GB
# 948     Memory Card Supported, upto 256 GB
# 949              Memory Card Not Supported
# 950     Memory Card Supported, upto 256 GB
# 951              Memory Card Not Supported
# 952        Memory Card (Hybrid), upto 1 TB
# 953      Memory Card (Hybrid), upto 256 GB
# 954     Memory Card Supported, upto 512 GB
# 955     Memory Card Supported, upto 256 GB
# 956              Memory Card Not Supported
# 957     Memory Card Supported, upto 512 GB
# 958     Memory Card Supported, upto 512 GB
# 959                  Memory Card Supported
# 960     Memory Card Supported, upto 512 GB
# 961                  Memory Card Supported
# 962                  Memory Card Supported
# 963       Memory Card Supported, upto 1 TB
# 964       Memory Card Supported, upto 1 TB
# 965      Memory Card (Hybrid), upto 512 GB
# 966              Memory Card Not Supported
# 967       Memory Card (Hybrid), upto 64 GB
# 968                  Memory Card Supported
# 969                            Android v13
# 970                            Android v13
# 971                            Android v13
# 972       Memory Card Supported, upto 1 TB
# 973                            Android v12
# 974                            Android v11
# 975                            Android v13
# 976              Memory Card Not Supported
# 977                            Android v12
# 978       Memory Card Supported, upto 1 TB
# 979              Memory Card Not Supported
# 980       Memory Card Supported, upto 1 TB
# 981       Memory Card Supported, upto 1 TB
# Name: card, dtype: object

# %%
pd.set_option('display.max_rows', None)

# %%
tempo_df = df1[df1['card'].str.contains('MP')]

# %%
df1.loc[tempo_df.index,'card'] = 'Memory Card Not Supported'

# %%
df1['card'].value_counts()
# Out:
# Memory Card Supported, upto 1 TB       170
# Memory Card Not Supported              148
# Android v12                            105
# Memory Card Supported, upto 512 GB     104
# Memory Card (Hybrid), upto 1 TB         91
# Memory Card Supported                   89
# Memory Card Supported, upto 256 GB      87
# Android v13                             46
# Android v11                             41
# Memory Card (Hybrid)                    30
# Memory Card (Hybrid), upto 256 GB       13
# Memory Card (Hybrid), upto 512 GB       11
# Android v10                             11
# Memory Card Supported, upto 128 GB       6
# Memory Card Supported, upto 2 TB         5
# Memory Card Supported, upto 32 GB        4
# Memory Card (Hybrid), upto 64 GB         3
# Memory Card (Hybrid), upto 128 GB        3
# Android v9.0 (Pie)                       2
# Android v12.1                            1
# Memory Card Supported, upto 1000 GB      1
# iOS v10                                  1
# Android v10.0                            1
# iOS v13                                  1
# HarmonyOS v2.0                           1
# Memory Card (Hybrid), upto 2 TB          1
# HarmonyOS                                1
# Name: card, dtype: int64

# %%
temp_df = df1[~df1['card'].str.contains('Memory Card')]

# %%
df1.loc[temp_df.index,'os'] = temp_df['card'].values

# %%
df1['card'].value_counts()
# Out:
# Memory Card Supported, upto 1 TB       170
# Memory Card Not Supported              148
# Android v12                            105
# Memory Card Supported, upto 512 GB     104
# Memory Card (Hybrid), upto 1 TB         91
# Memory Card Supported                   89
# Memory Card Supported, upto 256 GB      87
# Android v13                             46
# Android v11                             41
# Memory Card (Hybrid)                    30
# Memory Card (Hybrid), upto 256 GB       13
# Memory Card (Hybrid), upto 512 GB       11
# Android v10                             11
# Memory Card Supported, upto 128 GB       6
# Memory Card Supported, upto 2 TB         5
# Memory Card Supported, upto 32 GB        4
# Memory Card (Hybrid), upto 64 GB         3
# Memory Card (Hybrid), upto 128 GB        3
# Android v9.0 (Pie)                       2
# Android v12.1                            1
# Memory Card Supported, upto 1000 GB      1
# iOS v10                                  1
# Android v10.0                            1
# iOS v13                                  1
# HarmonyOS v2.0                           1
# Memory Card (Hybrid), upto 2 TB          1
# HarmonyOS                                1
# Name: card, dtype: int64

# %%
df1.head()
# Out:
#    level_0  index brand_name                      model  price  rating  \
# 0        0      4    oneplus              OnePlus 11 5G  54999    89.0
# 1        1      5    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2        2      6    samsung      Samsung Galaxy A14 5G  16499    75.0
# 3        3      7   motorola       Motorola Moto G62 5G  14999    81.0
# 4        4      8     realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  has_ir_blaster  has_5g  has_nfc  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False    True     True
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 4     Dimensity 1080, Octa Core, 2.6 GHz Processor   6 GB RAM, 128 GB inbuilt
#
#                                     battery  \
# 0  5000 mAh Battery with 100W Fast Charging
# 1   5000 mAh Battery with 33W Fast Charging
# 2   5000 mAh Battery with 15W Fast Charging
# 3       5000 mAh Battery with Fast Charging
# 4   5000 mAh Battery with 67W Fast Charging
#
#                                              display  \
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 2  6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 3  6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 4  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
#
#                                               camera  \
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 2  50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 3  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4  108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
#
#                                card           os
# 0         Memory Card Not Supported  Android v13
# 1   Memory Card (Hybrid), upto 1 TB  Android v12
# 2  Memory Card Supported, upto 1 TB  Android v13
# 3   Memory Card (Hybrid), upto 1 TB  Android v12
# 4         Memory Card Not Supported  Android v13

# %%
df1.shape
# Out:
# (977, 17)

# %%
brand_names = df1['model'].str.split(' ').str.get(0)

# %%
df1.insert(1,'brand_name',brand_names)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[97], line 1
# ----> 1 df1.insert(1,'brand_name',brand_names)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/frame.py:4817, in DataFrame.insert(self, loc, column, value, allow_duplicates)
#    4811     raise ValueError(
#    4812         "Cannot specify 'allow_duplicates=True' when "
#    4813         "'self.flags.allows_duplicate_labels' is False."
#    4814     )
#    4815 if not allow_duplicates and column in self.columns:
#    4816     # Should this be a different kind of error??
# -> 4817     raise ValueError(f"cannot insert {column}, already exists")
#    4818 if not isinstance(loc, int):
#    4819     raise TypeError("loc must be int")
#
# ValueError: cannot insert brand_name, already exists

# %%
df1['brand_name'] = df1['brand_name'].str.lower()

# %%
df1.head()
# Out:
#    index brand_name                      model  price  rating  \
# 0      2    oneplus              OnePlus 11 5G  54999    89.0
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 
       Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 968                         Dual Sim, 3G, 4G, Wi-Fi, NFC
# 969    Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC,...
# 970        Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC
# 971    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 972                       Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 973              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 974                              Dual Sim, 3G, 4G, Wi-Fi
# 975              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 976              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 977                   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 978                   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 979    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 980              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 981                   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# Name: sim, dtype: object

# %%
has_5g = df1['sim'].str.contains('5G')
has_nfc = df1['sim'].str.contains('NFC')
has_ir_blaster = df1['sim'].str.contains('IR Blaster')

# %%
df1.head()
# Out:
#    level_0  index brand_name                      model  price  rating  \
# 0        0      4    oneplus              OnePlus 11 5G  54999    89.0
# 1        1      5    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2        2      6    samsung      Samsung Galaxy A14 5G  16499    75.0
# 3        3      7   motorola       Motorola Moto G62 5G  14999    81.0
# 4        4      8     realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  has_ir_blaster  has_5g  has_nfc  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False    True     True
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 4     Dimensity 1080, Octa Core, 2.6 GHz Processor   6 GB RAM, 128 GB inbuilt
#
#                                     battery  \
# 0  5000 mAh Battery with 100W Fast Charging
# 1   5000 mAh Battery with 33W Fast Charging
# 2   5000 mAh Battery with 15W Fast Charging
# 3       5000 mAh Battery with Fast Charging
# 4   5000 mAh Battery with 67W Fast Charging
#
#                                              display  \
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 2  6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 3  6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 4  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
#
#                                               camera  \
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 2  50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 3  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4  108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
#
#                                card           os
# 0         Memory Card Not Supported  Android v13
# 1   Memory Card (Hybrid), upto 1 TB  Android v12
# 2  Memory Card Supported, upto 1 TB  Android v13
# 3   Memory Card (Hybrid), upto 1 TB  Android v12
# 4         Memory Card Not Supported  Android v13

# %%
df1.insert(6,'has_5g',has_5g)
df1.insert(7,'has_nfc',has_nfc)
df1.insert(6,'has_ir_blaster',has_ir_blaster)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[101], line 1
# ----> 1 df1.insert(6,'has_5g',has_5g)
#       2 df1.insert(7,'has_nfc',has_nfc)
#       3 df1.insert(6,'has_ir_blaster',has_ir_blaster)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/frame.py:4817, in DataFrame.insert(self, loc, column, value, allow_duplicates)
#    4811     raise ValueError(
#    4812         "Cannot specify 'allow_duplicates=True' when "
#    4813         "'self.flags.allows_duplicate_labels' is False."
#    4814     )
#    4815 if not allow_duplicates and column in self.columns:
#    4816     # Should this be a different kind of error??
# -> 4817     raise ValueError(f"cannot insert {column}, already exists")
#    4818 if not isinstance(loc, int):
#    4819     raise TypeError("loc must be int")
#
# ValueError: cannot insert has_5g, already exists

# %%
processor_name
processor_brand
processor_core
processor_speed
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[103], line 1
# ----> 1 processor_name
#       2 processor_brand
#       3 processor_core
#
# NameError: name 'processor_name' is not defined

# %%
processor_name = df1['processor'].str.split(',').str.get(0)

# %%
num_corse = df1['processor'].str.split(',').str.get(1)

# %%
processor_speed = df1['processor'].str.split(',').str.get(2)

# %%
#df1.insert(10,'processor_name',processor_name)
#df1.insert(11,'num_corse',num_corse)
df1.insert(12,'processor_speeds',processor_speed)

# %%
df1 = df1.drop(columns='processor_speeds',axis=1)

# %%
df1.head()
# Out:
#    level_0  index brand_name                      model  price  rating  \
# 0        0      4    oneplus              OnePlus 11 5G  54999    89.0
# 1        1      5    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2        2      6    samsung      Samsung Galaxy A14 5G  16499    75.0
# 3        3      7   motorola       Motorola Moto G62 5G  14999    81.0
# 4        4      8     realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  has_ir_blaster  has_5g  has_nfc  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False    True     True
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
#
#       processor_name   num_corse    processor_speeds  \
# 0  Snapdragon 8 Gen2   Octa Core   3.2 GHz Processor
# 1     Snapdragon 695   Octa Core   2.2 GHz Processor
# 2        Exynos 1330   Octa Core   2.4 GHz Processor
# 3    Snapdragon  695   Octa Core   2.2 GHz Processor
# 4     Dimensity 1080   Octa Core   2.6 GHz Processor
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 4     Dimensity 1080, Octa Core, 2.6 GHz Processor   6 GB RAM, 128 GB inbuilt
#
#                                     battery  \
# 0  5000 mAh Battery with 100W Fast Charging
# 1   5000 mAh Battery with 33W Fast Charging
# 2   5000 mAh Battery with 15W Fast Charging
# 3       5000 mAh Battery with Fast Charging
# 4   5000 mAh Battery with 67W Fast Charging
#
#                                              display  \
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 2  6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 3  6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 4  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
#
#                                               camera  \
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 2  50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 3  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4  108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
#
#                                card           os
# 0         Memory Card Not Supported  Android v13
# 1   Memory Card (Hybrid), upto 1 TB  Android v12
# 2  Memory Card Supported, upto 1 TB  Android v13
# 3   Memory Card (Hybrid), upto 1 TB  Android v12
# 4         Memory Card Not Supported  Android v13

# %%
df1['processor_name'] = df1['processor_name'].str.strip()

# %%
temp_df = df1[df1['processor_name'].str.contains('Core')][['processor_name', 'num_corse','processor_speeds']].shift(1,axis=1)

# %%
df1.loc[temp_df.index,['processor_name', 'num_corse','processor_speeds']] = temp_df.values

# %%
df1.loc[856,'processor_name'] = 'Mediatek MT6739'

# %%
processor_brand = df1['processor_name'].str.split(' ').str.get(0).str.lower()

# %%
df1.insert(11,'processor_brand',processor_brand)

# %%
df1['num_corse'] = df1['num_corse'].str.strip()

# %%
df1['num_corse'] = df1['num_corse'].str.replace('Octa Core Processor','Octa Core').str.replace('Hexa Core Processor','Hexa Core')

# %%
df1['processor_speeds'] = df1['processor_speeds'].str.strip().str.split(' ').str.get(0).str.replace('\u2009',' ').str.split(' ').str.get(0).astype(float)

# %%
df1.head()
# Out:
#    level_0  index brand_name                      model  price  rating  \
# 0        0      4    oneplus              OnePlus 11 5G  54999    89.0
# 1        1      5    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2        2      6    samsung      Samsung Galaxy A14 5G  16499    75.0
# 3        3      7   motorola       Motorola Moto G62 5G  14999    81.0
# 4        4      8     realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  has_ir_blaster  has_5g  has_nfc  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False    True     True
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
#
#    ... processor_brand  num_corse processor_speeds  \
# 0  ...      snapdragon  Octa Core              3.2
# 1  ...      snapdragon  Octa Core              2.2
# 2  ...          exynos  Octa Core              2.4
# 3  ...      snapdragon  Octa Core              2.2
# 4  ...       dimensity  Octa Core              2.6
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 4     Dimensity 1080, Octa Core, 2.6 GHz Processor   6 GB RAM, 128 GB inbuilt
#
#                                     battery  \
# 0  5000 mAh Battery with 100W Fast Charging
# 1   5000 mAh Battery with 33W Fast Charging
# 2   5000 mAh Battery with 15W Fast Charging
# 3       5000 mAh Battery with Fast Charging
# 4   5000 mAh Battery with 67W Fast Charging
#
#                                              display  \
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 2  6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 3  6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 4  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
#
#                                               camera  \
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 2  50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 3  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4  108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
#
#                                card           os
# 0         Memory Card Not Supported  Android v13
# 1   Memory Card (Hybrid), upto 1 TB  Android v12
# 2  Memory Card Supported, upto 1 TB  Android v13
# 3   Memory Card (Hybrid), upto 1 TB  Android v12
# 4         Memory Card Not Supported  Android v13
#
# [5 rows x 21 columns]

# %%
ram_capacity = df1['ram'].str.strip().str.split(',').str.get(0).str.findall(r'\b(\d+)\b').str.get(0)

# %%
df1.insert(16,'ram_capasity',ram_capacity)

# %%
internal_memory = df1['ram'].str.strip().str.split(',').str.get(1).str.findall(r'\b(\d+)\b').str.get(0)

# %%
df1.insert(17,'internal_memoryy',internal_memory)

# %%
df1.head()
# Out:
#    level_0  index brand_name                      model  price  rating  \
# 0        0      4    oneplus              OnePlus 11 5G  54999    89.0
# 1        1      5    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2        2      6    samsung      Samsung Galaxy A14 5G  16499    75.0
# 3        3      7   motorola       Motorola Moto G62 5G  14999    81.0
# 4        4      8     realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  has_ir_blaster  has_5g  has_nfc  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False    True     True
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
#
#    ... processor_speeds                                        processor  \
# 0  ...              3.2  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor
# 1  ...              2.2     Snapdragon 695, Octa Core, 2.2 GHz Processor
# 2  ...              2.4        Exynos 1330, Octa Core, 2.4 GHz Processor
# 3  ...              2.2    Snapdragon  695, Octa Core, 2.2 GHz Processor
# 4  ...              2.6     Dimensity 1080, Octa Core, 2.6 GHz Processor
#
#                          ram  ram_capasity internal_memoryy  \
# 0  12 GB RAM, 256 GB inbuilt            12              256
# 1   6 GB RAM, 128 GB inbuilt             6              128
# 2    4 GB RAM, 64 GB inbuilt             4               64
# 3   6 GB RAM, 128 GB inbuilt             6              128
# 4   6 GB RAM, 128 GB inbuilt             6              128
#
#                                     battery  \
# 0  5000 mAh Battery with 100W Fast Charging
# 1   5000 mAh Battery with 33W Fast Charging
# 2   5000 mAh Battery with 15W Fast Charging
# 3       5000 mAh Battery with Fast Charging
# 4   5000 mAh Battery with 67W Fast Charging
#
#                                              display  \
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 2  6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 3  6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 4  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
#
#                                               camera  \
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 2  50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 3  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4  108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
#
#                                card           os
# 0         Memory Card Not Supported  Android v13
# 1   Memory Card (Hybrid), upto 1 TB  Android v12
# 2  Memory Card Supported, upto 1 TB  Android v13
# 3   Memory Card (Hybrid), upto 1 TB  Android v12
# 4         Memory Card Not Supported  Android v13
#
# [5 rows x 23 columns]

# %%
df1['ram_capasity']=df1['ram_capasity'].astype(float)

# %%
df1[df1['ram_capasity'] > 18]
# Out:
#      level_0  index brand_name                             model   price  \
# 435      439    443      apple            Apple iPhone SE 3 2022   43900
# 478      483    487     huawei  Huawei Mate 50 RS Porsche Design  239999
# 481      486    490      nokia                     Nokia 8000 4G    6899
# 614      627    631      nokia                      Nokia 225 4G    3589
# 739      762    766      apple                 Apple iPhone SE 4   49990
#
#      rating                                              sim  has_ir_blaster  \
# 435     NaN          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False
# 478    81.0  Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster            True
# 481     NaN                          Dual Sim, 3G, 4G, Wi-Fi           False
# 614     NaN                          Dual Sim, 3G, 4G, VoLTE           False
# 739    60.0          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False
#
#      has_5g  has_nfc      processor_name processor_brand  num_corse  \
# 435    True     True         Bionic  A15          bionic  Hexa Core
# 478   False     True  Snapdragon 8+ Gen1      snapdragon  Octa Core
# 481   False    False     Snapdragon  210      snapdragon  Quad Core
# 614   False    False         Unisoc T117          unisoc        NaN
# 739    True     True         Bionic  A15          bionic  Hexa Core
#
#      processor_speeds                                         processor  \
# 435              3.22        Bionic  A15, Hexa Core, 3.22 GHz Processor
# 478              3.20  Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor
# 481              1.10     Snapdragon  210, Quad Core, 1.1 GHz Processor
# 614               NaN                                       Unisoc T117
# 739              3.22        Bionic  A15, Hexa Core, 3.22 GHz Processor
#
#                            ram  battery_capacity  fast_charging  ram_capasity  \
# 435              64 GB inbuilt               NaN           -1.0          64.0
# 478             512 GB inbuilt            4700.0           66.0         512.0
# 481   512 MB RAM, 4 GB inbuilt            1500.0           -1.0         512.0
# 614  64 MB RAM, 128 MB inbuilt            1150.0           -1.0          64.0
# 739              64 GB inbuilt               NaN           -1.0          64.0
#
#      internal_memoryy                                  battery  screen_size  \
# 435               NaN                                     None         4.70
# 478               NaN  4700 mAh Battery with 66W Fast Charging         6.74
# 481               4.0                         1500 mAh Battery         2.80
# 614             128.0                         1150 mAh Battery         2.40
# 739               NaN                                     None         6.10
#
#        resolution  refresh_rate                                      display  \
# 435   750 x 1334             60            4.7 inches, 750 x 1334 px Display
# 478  1212 x 2616            120  6.74 inches, 1212 x 2616 px, 120 Hz Display
# 481    240 x 320             60             2.8 inches, 240 x 320 px Display
# 614    240 x 320             60             2.4 inches, 240 x 320 px Display
# 739   750 x 1580             60            6.1 inches, 750 x 1580 px Display
#
#     num_rear_cameras num_front_cameras  \
# 435                1                 1
# 478                3                 1
# 481                1           Missing
# 614                1           Missing
# 739                1                 1
#
#                                                 camera  \
# 435                     12 MP Rear & 7 MP Front Camera
# 478  50 MP + 48 MP + 13 MP Triple Rear & 13 MP Fron...
# 481                                   2 MP Rear Camera
# 614                                 0.3 MP Rear Camera
# 739                  12 MP Rear & 10.8 MP Front Camera
#
#                                   card                 os  ram_capacity  \
# 435          Memory Card Not Supported                ios           NaN
# 478  Memory Card (Hybrid), upto 256 GB   Hongmeng OS v3.0           NaN
# 481              Memory Card Supported          Bluetooth           NaN
# 614  Memory Card Supported, upto 32 GB  RTOS (Series 30+)           NaN
# 739          Memory Card Not Supported                ios           NaN
#
#     internal_memory primary_camera_rear primary_camera_front extended_memory
# 435             NaN                  12                    7               0
# 478             NaN                  50                   13          256 GB
# 481             NaN                   2                  NaN   Not Specified
# 614             NaN                 0.3                  NaN           32 GB
# 739             NaN                  12                 10.8               0

# %%
df1.loc[[439,762], ['ram_capasity']] = [4.0,4.0]

# %%
df1.loc[[483], ['ram_capacity','internal_memory']] = [12.0,'512']

# %%
df1.drop([486,627],inplace=True)

# %%
df1['internal_memoryy'] = df1['internal_memoryy'].astype(float)

# %%
df1['internal_memoryy']
# Out:
# 0       256.0
# 1       128.0
# 2        64.0
# 3       128.0
# 4       128.0
# 5       128.0
# 6       128.0
# 7       256.0
# 8       128.0
# 9       128.0
# 10      128.0
# 11      128.0
# 12      128.0
# 13      128.0
# 14      256.0
# 15      128.0
# 16       32.0
# 17      256.0
# 18      128.0
# 19       64.0
# 20      128.0
# 21      128.0
# 22       64.0
# 23      128.0
# 24      256.0
# 25      128.0
# 26      128.0
# 27      128.0
# 28      128.0
# 29      128.0
# 30      128.0
# 31      128.0
# 32      256.0
# 33       64.0
# 34      128.0
# 35      128.0
# 36      256.0
# 37      256.0
# 38      128.0
# 39      256.0
# 812     128.0
# 813      32.0
# 814     128.0
# 815     512.0
# 816      64.0
# 817     128.0
# 818     128.0
# 819      16.0
# 820     128.0
# 821     128.0
# 822     128.0
# 823     512.0
# 824     128.0
# 825     128.0
# 826     256.0
# 827     128.0
# 828      64.0
# 829      16.0
# 830     128.0
# 831     128.0
# 832     128.0
# 833      32.0
# 834     128.0
# 835     128.0
# 836      64.0
# 837      64.0
# 838      64.0
# 839      64.0
# 840      64.0
# 841      64.0
# 842     256.0
# 843      64.0
# 844      64.0
# 845     256.0
# 846    1024.0
# 847     128.0
# 848     256.0
# 849     128.0
# 850     128.0
# 851     128.0
# 852      64.0
# 853     128.0
# 854     128.0
# 855     128.0
# 856     128.0
# 857     128.0
# 858     128.0
# 859     128.0
# 860     256.0
# 861      64.0
# 862     256.0
# 863     128.0
# 864     128.0
# 865     256.0
# 866      64.0
# 867     128.0
# 868      64.0
# 869      32.0
# 870      64.0
# 871     128.0
# 872      64.0
# 873     128.0
# 874     128.0
# 875     128.0
# 876       8.0
# 877     128.0
# 878     128.0
# 879      64.0
# 880      64.0
# 881      64.0
# 882     256.0
# 883     256.0
# 884      32.0
# 885     128.0
# 886      32.0
# 887     128.0
# 888     128.0
# 889     256.0
# 890      64.0
# 891      16.0
# 892      32.0
# 893      32.0
# 894     128.0
# 895     128.0
# 896      64.0
# 897     128.0
# 898     128.0
# 899      64.0
# 900      32.0
# 901      64.0
# 902      64.0
# 903     128.0
# 904      64.0
# 905     128.0
# 906      32.0
# 907       1.0
# 908     128.0
# 909     128.0
# 910     256.0
# 911     128.0
# 912    1024.0
# 913    1024.0
# 914     128.0
# 915     128.0
# 916     128.0
# 917     128.0
# 918     512.0
# 919     128.0
# 920      64.0
# 921     128.0
# 922     128.0
# 923     128.0
# 924     128.0
# 925       1.0
# 926     128.0
# 927      64.0
# 928     128.0
# 929      32.0
# 930     128.0
# 931     128.0
# 932     128.0
# 933     128.0
# 934      64.0
# 935     128.0
# 936      32.0
# 937     128.0
# 938     128.0
# 939     128.0
# 940      64.0
# 941     128.0
# 942     128.0
# 943     128.0
# 944     128.0
# 945     128.0
# 946      64.0
# 947      32.0
# 948      32.0
# 949     256.0
# 950      64.0
# 951     128.0
# 952     256.0
# 953     512.0
# 954    1024.0
# 955      16.0
# 956     512.0
# 957     128.0
# 958      64.0
# 959      16.0
# 960      64.0
# 961      64.0
# 962     128.0
# 963     128.0
# 964     128.0
# 965      32.0
# 966     128.0
# 967    1024.0
# 968     128.0
# 969     256.0
# 970     128.0
# 971     256.0
# 972      64.0
# 973     256.0
# 974      32.0
# 975     256.0
# 976     256.0
# 977     128.0
# 978     128.0
# 979     256.0
# 980     128.0
# 981    1024.0
# Name: internal_memoryy, dtype: float64

# %%
df1.loc[temp_df.index,'internal_memoryy'] = 1024

# %%
df1['internal_memoryy'].value_counts()
# Out:
# 128.0     515
# 64.0      182
# 256.0     155
# 32.0       62
# 1024.0     20
# 512.0      20
# 16.0       11
# 1.0         5
# 4.0         1
# 8.0         1
# Name: internal_memoryy, dtype: int64

# %%
battery_capacity
fast_charging

# %%
battery_capacity = df1['battery'].str.strip().str.split('with').str.get(0).str.strip().str.findall(r'\b(\d+)\b').str.get(0).astype(float)

# %%
df1.insert(16,'battery_capacity',battery_capacity)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[184], line 1
# ----> 1 df1.insert(16,'battery_capacity',battery_capacity)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/frame.py:4817, in DataFrame.insert(self, loc, column, value, allow_duplicates)
#    4811     raise ValueError(
#    4812         "Cannot specify 'allow_duplicates=True' when "
#    4813         "'self.flags.allows_duplicate_labels' is False."
#    4814     )
#    4815 if not allow_duplicates and column in self.columns:
#    4816     # Should this be a different kind of error??
# -> 4817     raise ValueError(f"cannot insert {column}, already exists")
#    4818 if not isinstance(loc, int):
#    4819     raise TypeError("loc must be int")
#
# ValueError: cannot insert battery_capacity, already exists

# %%
df1['battery_capacity']
# Out:
# 0       5000.0
# 1       5000.0
# 2       5000.0
# 3       5000.0
# 4       5000.0
# 5       5000.0
# 6       3279.0
# 7       4980.0
# 8       4500.0
# 9       4500.0
# 10      5000.0
# 11      5000.0
# 12      5000.0
# 13      5000.0
# 14      5000.0
# 15      3240.0
# 16      5000.0
# 17      4700.0
# 18      5000.0
# 19      5000.0
# 20      5000.0
# 21      4830.0
# 22      5000.0
# 23      5000.0
# 24      4800.0
# 25      4500.0
# 26      5000.0
# 27      4323.0
# 28      4500.0
# 29      4500.0
# 30      5000.0
# 31      5000.0
# 32      4700.0
# 33      3110.0
# 34      5000.0
# 35      4500.0
# 36      5000.0
# 37      5000.0
# 38      5200.0
# 39      4500.0
# 40      5000.0
# 41      5000.0
# 42      5000.0
# 43      5000.0
# 44      5000.0
# 45      6000.0
# 46      5000.0
# 47      5000.0
# 48      5000.0
# 49      5000.0
# 50      5000.0
# 51      5000.0
# 52      5000.0
# 53      5000.0
# 54      5000.0
# 55      5000.0
# 56      4325.0
# 57      5000.0
# 58      4700.0
# 59      5000.0
# 60      5000.0
# 61      4600.0
# 62      5000.0
# 63      5000.0
# 64      5000.0
# 65      4600.0
# 66      5000.0
# 67      4980.0
# 68      5000.0
# 69      5000.0
# 70      5000.0
# 71      4200.0
# 72      5000.0
# 73      4800.0
# 74      5000.0
# 75      3500.0
# 76      3095.0
# 77      4800.0
# 78      5000.0
# 79      5000.0
# 80      5000.0
# 81      5000.0
# 82      5000.0
# 83      5000.0
# 84      5000.0
# 85      4020.0
# 86      5000.0
# 87      5000.0
# 88      5000.0
# 89      5000.0
# 90      5000.0
# 91      5000.0
# 92      5000.0
# 93      4700.0
# 94      5000.0
# 95      5000.0
# 96      5000.0
# 97      5000.0
# 98      4600.0
# 99      5000.0
# 100     3200.0
# 101     5200.0
# 102     4400.0
# 103     5000.0
# 104     4310.0
# 105     4820.0
# 106     5000.0
# 107     3700.0
# 108     5000.0
# 109     5000.0
# 110     5160.0
# 111        NaN
# 112     5080.0
# 113     5000.0
# 114     5000.0
# 115     4500.0
# 116     5000.0
# 117     4700.0
# 118     5000.0
# 119     3900.0
# 120     4800.0
# 121     4500.0
# 122     4410.0
# %%
fast_charging = df1['battery'].str.strip().str.split('with').str.get(1).str.strip().str.findall(r'\d{2,3}')

# %%
df1.insert(17,'fast_charging',fast_charging)

# %%
def fast_charge_extractor(item):
    if type(item) == list:
        if len(item) == 1:
            return item[0]
        else:
            return 0
    else:
        return -1

# %%
df1['fast_charging'] = df1['fast_charging'].apply(fast_charge_extractor).astype(float)

# %%
df1.head()
# Out:
#    level_0  index brand_name                      model  price  rating  \
# 0        0      4    oneplus              OnePlus 11 5G  54999    89.0
# 1        1      5    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2        2      6    samsung      Samsung Galaxy A14 5G  16499    75.0
# 3        3      7   motorola       Motorola Moto G62 5G  14999    81.0
# 4        4      8     realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  has_ir_blaster  has_5g  has_nfc  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False    True     True
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
#
#       processor_name processor_brand  num_corse  processor_speeds  \
# 0  Snapdragon 8 Gen2      snapdragon  Octa Core               3.2
# 1     Snapdragon 695      snapdragon  Octa Core               2.2
# 2        Exynos 1330          exynos  Octa Core               2.4
# 3    Snapdragon  695      snapdragon  Octa Core               2.2
# 4     Dimensity 1080       dimensity  Octa Core               2.6
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 4     Dimensity 1080, Octa Core, 2.6 GHz Processor   6 GB RAM, 128 GB inbuilt
#
#    battery_capacity  fast_charging  ram_capasity  internal_memoryy  \
# 0            5000.0           -1.0          12.0             256.0
# 1            5000.0           -1.0           6.0             128.0
# 2            5000.0           -1.0           4.0              64.0
# 3            5000.0           -1.0           6.0             128.0
# 4            5000.0           -1.0           6.0             128.0
#
#                                     battery  screen_size    resolution  \
# 0  5000 mAh Battery with 100W Fast Charging         6.70  1440 x 3216
# 1   5000 mAh Battery with 33W Fast Charging         6.59  1080 x 2412
# 2   5000 mAh Battery with 15W Fast Charging         6.60  1080 x 2408
# 3       5000 mAh Battery with Fast Charging         6.55  1080 x 2400
# 4   5000 mAh Battery with 67W Fast Charging         6.70  1080 x 2412
#
#    refresh_rate                                            display  \
# 0           120  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...
# 1           120  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 2            90  6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 3           120  6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 4           120  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
#
#   num_rear_cameras num_front_cameras  \
# 0                3                 1
# 1                3                 1
# 2                3                 1
# 3                3                 1
# 4                3                 1
#
#                                               camera  \
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 2  50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 3  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4  108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
#
#                                card       os  ram_capacity internal_memory  \
# 0         Memory Card Not Supported  android           NaN             NaN
# 1   Memory Card (Hybrid), upto 1 TB  android           NaN             NaN
# 2  Memory Card Supported, upto 1 TB  android           NaN             NaN
# 3   Memory Card (Hybrid), upto 1 TB  android           NaN             NaN
# 4         Memory Card Not Supported  android           NaN             NaN
#
#   primary_camera_rear primary_camera_front extended_memory
# 0                  50                   16               0
# 1                  64                   16            1 TB
# 2                  50                   13            1 TB
# 3                  50                   16            1 TB
# 4                 108                   16               0

# %%
screen_size = df1['display'].str.strip().str.split(',').str.get(0).str.strip().str.split(' ').str.get(0).astype(float)

# %%
df1.insert(21,'screen_size',screen_size)

# %%
resolution = df1['display'].str.strip().str.split(',').str.get(1).str.strip().str.split('px').str.get(0)

# %%
df1.insert(22,'resolution',resolution)

# %%
refresh_rate = df1['display'].str.strip().str.split(',').str.get(2).str.strip().str.findall(r'\d{2,3}').str.get(0).apply(lambda x:60 if pd.isna(x) else x).astype(int)

# %%
df1.insert(23,'refresh_rate',refresh_rate)

# %%
df1.head()
# Out:
#    index brand_name                      model  price  rating  \
# 0      2    oneplus              OnePlus 11 5G  54999    89.0
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4    samsung      Samsung Galaxy A14 5G  16499    75.0
# 3      5   motorola       Motorola Moto G62 5G  14999    81.0
# 4      6     realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  has_ir_blaster  has_5g  has_nfc  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False    True     True
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
#
#                                          processor  ... internal_memoryy  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  ...            256.0
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor  ...            128.0
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor  ...             64.0
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor  ...            128.0
# 4     Dimensity 1080, Octa Core, 2.6 GHz Processor  ...            128.0
#
#                                              display screen_size  \
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...        6.70
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...        6.59
# 2  6.6 inches, 1080 x 2408 px, 90 Hz Display with...        6.60
# 3  6.55 inches, 1080 x 2400 px, 120 Hz Display wi...        6.55
# 4  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...        6.70
#
#      resolution refresh_rate  \
# 0  1440 x 3216           120
# 1  1080 x 2412           120
# 2  1080 x 2408            90
# 3  1080 x 2400           120
# 4  1080 x 2412           120
#
#                                               camera  \
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 2  50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 3  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4  108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
#
#                                card           os  ram_capacity  \
# 0         Memory Card Not Supported  Android v13           NaN
# 1   Memory Card (Hybrid), upto 1 TB  Android v12           NaN
# 2  Memory Card Supported, upto 1 TB  Android v13           NaN
# 3   Memory Card (Hybrid), upto 1 TB  Android v12           NaN
# 4         Memory Card Not Supported  Android v13           NaN
#
#    internal_memory
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#
# [5 rows x 29 columns]

# %%
df1['camera'].value_counts()
# Out:
# 50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front Camera                   39
# 64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front Camera                   38
# 50 MP + 2 MP + 2 MP Triple Rear & 16 MP Front Camera                   34
# 13 MP + 2 MP Dual Rear & 5 MP Front Camera                             23
# 13 MP Rear & 5 MP Front Camera                                         20
# 12 MP + 12 MP Dual Rear & 12 MP Front Camera                           20
# 50 MP + 2 MP + 2 MP Triple Rear & 8 MP Front Camera                    20
# 50 MP + 2 MP Dual Rear & 8 MP Front Camera                             19
# 8 MP Rear & 5 MP Front Camera                                          18
# 64 MP Quad Rear & 32 MP Front Camera                                   18
# 13 MP + 2 MP Dual Rear & 8 MP Front Camera                             18
# 108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front Camera                  17
# 64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front Camera                   16
# 48 MP + 2 MP + 2 MP Triple Rear & 16 MP Front Camera                   14
# 48 MP Quad Rear & 13 MP Front Camera                                   14
# 50 MP + 2 MP Dual Rear & 5 MP Front Camera                             14
# 50 MP Quad Rear & 8 MP Front Camera                                    13
# 108 MP Quad Rear & 32 MP Front Camera                                  12
# 48 MP Quad Rear & 16 MP Front Camera                                   12
# 50 MP + 8 MP + 2 MP Triple Rear & 32 MP Front Camera                   11
# 13 MP + 2 MP + 2 MP Triple Rear & 5 MP Front Camera                    10
# 64 MP + 8 MP + 2 MP Triple Rear & 32 MP Front Camera                   10
# 108 MP Quad Rear & 16 MP Front Camera                                  10
# 12 MP + 12 MP + 12 MP Triple Rear & 12 MP Front Camera                 10
# 64 MP Quad Rear & 16 MP Front Camera                                   10
# 13 MP Dual Rear & 8 MP Front Camera                                     9
# 13 MP + 2 MP + 2 MP Triple Rear & 8 MP Front Camera                     9
# 50 MP + 8 MP Dual Rear & 16 MP Front Camera                             9
 MP + 2 MP + Depth Sensor Triple Rear & 8 MP Front Camera             1
# Name: camera, dtype: int64

# %%
def camera_extractor(text):

  if 'Quad' in text:
    return '4'
  elif 'Triple' in text:
    return '3'
  elif 'Dual' in text:
    return '2'
  elif 'Missing' in text:
    return 'Missing'
  else:
    return '1'

# %%
num_rear_cameras = df1['camera'].str.strip().str.split('&').str.get(0).apply(camera_extractor)

# %%
df1.insert(25,'num_rear_cameras',num_rear_cameras)

# %%
num_front_cameras = df1['camera'].str.strip().str.split('&').str.get(1).str.strip().fillna('Missing').apply(camera_extractor)

# %%
df1.insert(26,'num_front_cameras',num_front_cameras)

# %%
df1[df1['num_front_cameras'] == 'Missing']
# Out:
#      level_0  index brand_name                model   price  rating  \
# 69        69     73       oppo     Oppo Find N Fold   99990     NaN
# 458      462    466     xiaomi  Xiaomi Mi Mix Alpha  199990     NaN
# 481      486    490      nokia        Nokia 8000 4G    6899     NaN
# 614      627    631      nokia         Nokia 225 4G    3589     NaN
# 956      993    997     huawei        Huawei Mate X  169000     NaN
# 974     1012   1016       itel            itel A23s    4787     NaN
#
#                                                    sim  has_ir_blaster  \
# 69             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False
# 458                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False
# 481                            Dual Sim, 3G, 4G, Wi-Fi           False
# 614                            Dual Sim, 3G, 4G, VoLTE           False
# 956  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...            True
# 974                            Dual Sim, 3G, 4G, Wi-Fi           False
#
#      has_5g  has_nfc  ...    resolution refresh_rate  \
# 69     True     True  ...  1792 x 1920           120
# 458    True    False  ...  2088 x 2250            60
# 481   False    False  ...    240 x 320            60
# 614   False    False  ...    240 x 320            60
# 956    True     True  ...  2200 x 2480            60
# 974   False    False  ...    854 x 480            60
#
#                                                display  num_rear_cameras  \
# 69   7.1 inches, 1792 x 1920 px, 120 Hz Display wit...                 2
# 458                7.92 inches, 2088 x 2250 px Display                 3
# 481                   2.8 inches, 240 x 320 px Display                 1
# 614                   2.4 inches, 240 x 320 px Display                 1
# 956                   8 inches, 2200 x 2480 px Display                 4
# 974                     5 inches, 854 x 480 px Display                 1
#
#     num_front_cameras                                     camera  \
# 69            Missing             Foldable Display, Dual Display
# 458           Missing  108 MP + 20 MP + 12 MP Triple Rear Camera
# 481           Missing                           2 MP Rear Camera
# 614           Missing                         0.3 MP Rear Camera
# 956           Missing                     48 MP Quad Rear Camera
# 974           Missing                           2 MP Rear Camera
#
#                                   card                                 os  \
# 69           Memory Card Not Supported                        Android v12
# 458          Memory Card Not Supported                        Android v10
# 481              Memory Card Supported                          Bluetooth
# 614  Memory Card Supported, upto 32 GB                  RTOS (Series 30+)
# 956          Memory Card Not Supported  Memory Card (Hybrid), upto 256 GB
# 974                        Android v11                        Android v11
#
#      ram_capacity  internal_memory
# 69            NaN              NaN
# 458           NaN              NaN
# 481           NaN              NaN
# 614           NaN              NaN
# 956           NaN              NaN
# 974           NaN              NaN
#
# [6 rows x 32 columns]

# %%
pd.set_option('display.max_columns',None)

# %%
df1.head()
# Out:
#    level_0  index brand_name                      model  price  rating  \
# 0        0      4    oneplus              OnePlus 11 5G  54999    89.0
# 1        1      5    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2        2      6    samsung      Samsung Galaxy A14 5G  16499    75.0
# 3        3      7   motorola       Motorola Moto G62 5G  14999    81.0
# 4        4      8     realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  has_ir_blaster  has_5g  has_nfc  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False    True     True
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False    True    False
#
#       processor_name processor_brand  num_corse  processor_speeds  \
# 0  Snapdragon 8 Gen2      snapdragon  Octa Core               3.2
# 1     Snapdragon 695      snapdragon  Octa Core               2.2
# 2        Exynos 1330          exynos  Octa Core               2.4
# 3    Snapdragon  695      snapdragon  Octa Core               2.2
# 4     Dimensity 1080       dimensity  Octa Core               2.6
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 4     Dimensity 1080, Octa Core, 2.6 GHz Processor   6 GB RAM, 128 GB inbuilt
#
#    battery_capacity  fast_charging  ram_capasity  internal_memoryy  \
# 0            5000.0          100.0          12.0             256.0
# 1            5000.0           33.0           6.0             128.0
# 2            5000.0           15.0           4.0              64.0
# 3            5000.0            0.0           6.0             128.0
# 4            5000.0           67.0           6.0             128.0
#
#                                     battery  screen_size    resolution  \
# 0  5000 mAh Battery with 100W Fast Charging         6.70  1440 x 3216
# 1   5000 mAh Battery with 33W Fast Charging         6.59  1080 x 2412
# 2   5000 mAh Battery with 15W Fast Charging         6.60  1080 x 2408
# 3       5000 mAh Battery with Fast Charging         6.55  1080 x 2400
# 4   5000 mAh Battery with 67W Fast Charging         6.70  1080 x 2412
#
#    refresh_rate                                            display  \
# 0           120  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...
# 1           120  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 2            90  6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 3           120  6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 4           120  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
#
#   num_rear_cameras num_front_cameras  \
# 0                3                 1
# 1                3                 1
# 2                3                 1
# 3                3                 1
# 4                3                 1
#
#                                               camera  \
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 2  50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 3  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4  108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
#
#                                card           os  ram_capacity internal_memory
# 0         Memory Card Not Supported  Android v13           NaN             NaN
# 1   Memory Card (Hybrid), upto 1 TB  Android v12           NaN             NaN
# 2  Memory Card Supported, upto 1 TB  Android v13           NaN             NaN
# 3   Memory Card (Hybrid), upto 1 TB  Android v12           NaN             NaN
# 4         Memory Card Not Supported  Android v13           NaN             NaN

# %%
#df1[df1['camera'] == 'Foldable Display, Dual Display']
df1.loc[69,'camera'] == '50 MP'
# Out:
# False

# %%
df1.loc[temp_df.index, 'camera'] = '50 MP'

# %%
df1['primary_camera_rear'] = df1['camera'].str.split(' ').str.get(0).str.replace('\u2009',' ').str.split(' ').str.get(0)

# %%
df1['primary_camera_front'] = df1['camera'].str.split('&').str.get(1).str.strip().str.split(' ').str.get(0).str.replace('\u2009',' ').str.split(' ').str.get(0)

# %%
df1[df1['card'] == 'Memory Card (Hybrid)']
# Out:
#      level_0  index brand_name                                      model  \
# 25        25     29    samsung                   Samsung Galaxy S20 FE 5G
# 80        80     84   motorola                       Motorola Moto G72 4G
# 147      147    151    samsung                      Samsung Galaxy M34 5G
# 151      151    155   motorola                          Motorola Moto G52
# 177      178    182       vivo                                Vivo Y75 5G
# 203      204    208   motorola        Motorola Moto G52 (6GB RAM + 128GB)
# 247      248    252   motorola                          Motorola Moto G73
# 253      254    258     xiaomi                Xiaomi Redmi Note 11 Pro 5G
# 279      281    285       vivo                               Vivo V23e 5G
# 303      305    309     xiaomi                    Xiaomi Mi 11 Lite NE 5G
# 437      441    445       poco                                Poco X3 Pro
# 466      470    474     xiaomi  Xiaomi Mi 11 Lite NE 5G (8GB RAM + 128GB)
# 482      487    491       sony                           Sony Xperia 5 II
# 484      489    493       sony        Sony Xperia 1 IV (12GB RAM + 512GB)
# 508      513    517     realme                               Realme Q5 5G
# 570      580    584      nokia                                  Nokia G60
# 591      602    606       vivo                                   Vivo V21
# 613      626    630       vivo                                Vivo V21 5G
# 616      629    633       sony                           Sony Xperia 1 II
# 645      662    666       vivo                                  Vivo V25e
# 662      680    684         lg                               LG Velvet 5G
# 677      696    700      honor                              Honor Play 30
# 679      698    702       sony                        Sony Xperia 5 IV 5G
# 700      720    724       vivo                                  Vivo V21s
# 744      767    771   motorola                       Motorola Moto G52 5G
# 832      860    864       sony                          Sony Xperia 10 II
# 846      875    879     huawei                            Huawei Nova Y61
# 903      939    943        zte                               ZTE Axon 30S
# 904      940    944      honor                                   Honor X6
# 906      942    946        tcl                                  TCL Ion X
#
#      price  rating                                                sim  \
# 25   31239    88.0            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 80   15999    83.0                Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC
# 147  16999    84.0            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 151  11999    75.0                Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC
# 177  21990    82.0                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 203  12999    79.0                Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC
# 247  25999    85.0            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 253  17990    81.0     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 279  21994    84.0                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 303  21890    83.0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 437  19650    82.0         Dual Sim, 3G, 4G, VoLTE, Wi-Fi, IR Blaster
# 466  22999    86.0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 482  69990    86.0            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 484  92980     NaN            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 508  14990    78.0                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 570  28498    81.0            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 591  24999    83.0                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 613  23994    85.0                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 616  69999    89.0            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 645  19990    84.0                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 662  54999    85.0            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 677   9999    68.0                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 679  82199    89.0            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 700  29999    86.0            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 744  16999    76.0            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 832  27999    75.0                Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC
# 846  21990    63.0                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 903  19999    82.0            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 904  13999    71.0                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 906   8990    60.0                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi
#
#      has_ir_blaster  has_5g  has_nfc     processor_name processor_brand  \
# 25            False    True     True     Snapdragon 865      snapdragon
# 80            False   False     True         Helio  G99           helio
# 147           False    True     True        Exynos 1200          exynos
# 151           False   False     True     Snapdragon 680      snapdragon
# 177           False    True    False  Dimensity  700 5G       dimensity
# 203           False   False     True     Snapdragon 680      snapdragon
# 247           False    True     True      Dimensity 930       dimensity
# 253            True    True    False     Snapdragon 695      snapdragon
# 279           False    True    False  Dimensity  810 5G       dimensity
# 303            True    True     True   Snapdragon  778G      snapdragon
# 437            True   False    False     Snapdragon 860      snapdragon
# 466            True    True     True   Snapdragon  778G      snapdragon
# 482           False    True     True     Snapdragon 865      snapdragon
# 484           False    True     True  Snapdragon 8 Gen1      snapdragon
# 508           False    True    False     Snapdragon 695      snapdragon
# 570           False    True     True    Snapdragon  695      snapdragon
# 591           False   False    False     Dimensity 800U       dimensity
# 613           False    True    False     Dimensity 800U       dimensity
# 616           False    True     True    Snapdragon  865      snapdragon
# 645           False   False    False          Helio G99           helio
# 662           False    True     True   Snapdragon  765G      snapdragon
# 677           False    True    False    Snapdragon 480+      snapdragon
# 679           False    True     True  Snapdragon 8 Gen1      snapdragon
# 700           False    True     True     Dimensity 800U       dimensity
# 744           False    True     True     Snapdragon 695      snapdragon
# 832           False   False     True    Snapdragon  665      snapdragon
# 846           False   False    False               None            None
# 903           False    True     True     Snapdragon 870      snapdragon
# 904           False   False    False          Helio G25           helio
# 906           False   False    False          Helio G25           helio
#
#      num_corse  processor_speeds  \
# 25   Octa Core              2.84
# 80   Octa Core              2.20
# 147  Octa Core              2.40
# 151  Octa Core              2.40
# 177  Octa Core              2.20
# 203  Octa Core              2.40
# 247  Octa Core              2.20
# 253  Octa Core              2.20
# 279  Octa Core              2.40
# 303  Octa Core              2.40
# 437  Octa Core              2.96
# 466  Octa Core              2.40
# 482  Octa Core              2.84
# 484  Octa Core              3.00
# 508  Octa Core              2.20
# 570  Octa Core              2.20
# 591  Octa Core              2.40
# 613  Octa Core              2.40
# 616  Octa Core              2.84
# 645  Octa Core              2.20
# 662  Octa Core              2.40
# 677  Octa Core              2.20
# 679  Octa Core              3.00
# 700  Octa Core              2.40
# 744  Octa Core              2.20
# 832  Octa Core              2.00
# 846  Octa Core               NaN
# 903  Octa Core              3.20
# 904  Octa Core              2.00
# 906  Octa Core              2.00
#
#                                            processor  \
# 25     Snapdragon 865, Octa Core, 2.84 GHz Processor
# 80          Helio  G99, Octa Core, 2.2 GHz Processor
# 147        Exynos 1200, Octa Core, 2.4 GHz Processor
# 151     Snapdragon 680, Octa Core, 2.4 GHz Processor
# 177  Dimensity  700 5G, Octa Core, 2.2 GHz Processor
# 203     Snapdragon 680, Octa Core, 2.4 GHz Processor
# 247      Dimensity 930, Octa Core, 2.2 GHz Processor
# 253     Snapdragon 695, Octa Core, 2.2 GHz Processor
# 279  Dimensity  810 5G, Octa Core, 2.4 GHz Processor
# 303  Snapdragon  778G , Octa Core, 2.4 GHz Processor
# 437    Snapdragon 860, Octa Core, 2.96 GHz Processor
# 466  Snapdragon  778G , Octa Core, 2.4 GHz Processor
# 482   Snapdragon 865 , Octa Core, 2.84 GHz Processor
# 484    Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 508     Snapdragon 695, Octa Core, 2.2 GHz Processor
# 570    Snapdragon  695, Octa Core, 2.2 GHz Processor
# 591     Dimensity 800U, Octa Core, 2.4 GHz Processor
# 613     Dimensity 800U, Octa Core, 2.4 GHz Processor
# 616  Snapdragon  865 , Octa Core, 2.84 GHz Processor
# 645          Helio G99, Octa Core, 2.2 GHz Processor
# 662   Snapdragon  765G, Octa Core, 2.4 GHz Processor
# 677    Snapdragon 480+, Octa Core, 2.2 GHz Processor
# 679    Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 700    Dimensity 800U , Octa Core, 2.4 GHz Processor
# 744     Snapdragon 695, Octa Core, 2.2 GHz Processor
# 832      Snapdragon  665, Octa Core, 2 GHz Processor
# 846                              Octa Core Processor
# 903    Snapdragon 870 , Octa Core, 3.2 GHz Processor
# 904            Helio G25, Octa Core, 2 GHz Processor
# 906            Helio G25, Octa Core, 2 GHz Processor
#
#                            ram  battery_capacity  fast_charging  ram_capasity  \
# 25    8 GB RAM, 128 GB inbuilt            4500.0            0.0           8.0
# 80    6 GB RAM, 128 GB inbuilt            5000.0           33.0           6.0
# 147   6 GB RAM, 128 GB inbuilt            6000.0           25.0           6.0
# 151    4 GB RAM, 64 GB inbuilt            5000.0           33.0           4.0
# 177   8 GB RAM, 128 GB inbuilt            5000.0           18.0           8.0
# 203   6 GB RAM, 128 GB inbuilt            5000.0           33.0           6.0
# 247   8 GB RAM, 256 GB inbuilt            5000.0           30.0           8.0
# 253    6 GB RAM, 64 GB inbuilt            5000.0           67.0           6.0
# 279   8 GB RAM, 128 GB inbuilt            4050.0           44.0           8.0
# 303   6 GB RAM, 128 GB inbuilt            4250.0           33.0           6.0
# 437   6 GB RAM, 128 GB inbuilt            5160.0           33.0           6.0
# 466   8 GB RAM, 128 GB inbuilt            4250.0           33.0           8.0
# 482   8 GB RAM, 128 GB inbuilt            4000.0           21.0           8.0
# 484  12 GB RAM, 512 GB inbuilt            5000.0           30.0          12.0
# 508   6 GB RAM, 128 GB inbuilt            5000.0           60.0           6.0
# 570   6 GB RAM, 128 GB inbuilt            4500.0           20.0           6.0
# 591   8 GB RAM, 128 GB inbuilt            4000.0           33.0           8.0
# 613   8 GB RAM, 128 GB inbuilt            4000.0           33.0           8.0
# 616   8 GB RAM, 256 GB inbuilt            4000.0           21.0           8.0
# 645   8 GB RAM, 256 GB inbuilt            4500.0           44.0           8.0
# 662   6 GB RAM, 128 GB inbuilt            4300.0           25.0           6.0
# 677   4 GB RAM, 128 GB inbuilt            5000.0           -1.0           4.0
# 679   8 GB RAM, 256 GB inbuilt            5000.0           30.0           8.0
# 700   8 GB RAM, 128 GB inbuilt            4000.0           33.0           8.0
# 744    4 GB RAM, 64 GB inbuilt            5000.0           33.0           4.0
# 832   4 GB RAM, 128 GB inbuilt            3600.0           18.0           4.0
# 846    4 GB RAM, 64 GB inbuilt            5000.0           22.0           4.0
# 903   6 GB RAM, 128 GB inbuilt            4200.0           55.0           6.0
# 904    4 GB RAM, 64 GB inbuilt            5000.0           10.0           4.0
# 906    3 GB RAM, 32 GB inbuilt            3000.0           10.0           3.0
#
#      internal_memoryy                                    battery  screen_size  \
# 25              128.0        4500 mAh Battery with Fast Charging         6.50
# 80              128.0    5000 mAh Battery with 33W Fast Charging         6.55
# 147             128.0    6000 mAh Battery with 25W Fast Charging         6.50
# 151              64.0    5000 mAh Battery with 33W Fast Charging         6.60
# 177             128.0    5000 mAh Battery with 18W Fast Charging         6.58
# 203             128.0    5000 mAh Battery with 33W Fast Charging         6.60
# 247             256.0    5000 mAh Battery with 30W Fast Charging         6.50
# 253              64.0    5000 mAh Battery with 67W Fast Charging         6.67
# 279             128.0    4050 mAh Battery with 44W Fast Charging         6.44
# 303             128.0    4250 mAh Battery with 33W Fast Charging         6.55
# 437             128.0    5160 mAh Battery with 33W Fast Charging         6.67
# 466             128.0    4250 mAh Battery with 33W Fast Charging         6.55
# 482             128.0    4000 mAh Battery with 21W Fast Charging         6.10
# 484             512.0    5000 mAh Battery with 30W Fast Charging         6.50
# 508             128.0    5000 mAh Battery with 60W Fast Charging         6.60
# 570             128.0    4500 mAh Battery with 20W Fast Charging         6.58
# 591             128.0    4000 mAh Battery with 33W Fast Charging         6.44
# 613             128.0    4000 mAh Battery with 33W Fast Charging         6.44
# 616             256.0    4000 mAh Battery with 21W Fast Charging         6.50
# 645             256.0    4500 mAh Battery with 44W Fast Charging         6.44
# 662             128.0    4300 mAh Battery with 25W Fast Charging         6.80
# 677             128.0                           5000 mAh Battery         6.50
# 679             256.0    5000 mAh Battery with 30W Fast Charging         6.10
# 700             128.0    4000 mAh Battery with 33W Fast Charging         6.44
# 744              64.0    5000 mAh Battery with 33W Fast Charging         6.60
# 832             128.0    3600 mAh Battery with 18W Fast Charging         6.00
# 846            1024.0  5000 mAh Battery with 22.5W Fast Charging         6.52
# 903             128.0    4200 mAh Battery with 55W Fast Charging         6.90
# 904              64.0    5000 mAh Battery with 10W Fast Charging         6.50
# 906              32.0    3000 mAh Battery with 10W Fast Charging         6.00
#
#        resolution  refresh_rate  \
# 25   1080 x 2400            120
# 80   1080 x 2400            120
# 147  1080 x 2400            120
# 151  2460 x 1080             90
# 177  1080 x 2408             60
# 203  2460 x 1080             90
# 247  1080 x 2400            120
# 253  1080 x 2400            120
# 279  1080 x 2400             60
# 303  1080 x 2400             90
# 437  1080 x 2400            120
# 466  1080 x 2400             90
# 482  1080 x 2520            120
# 484  1644 x 3840            120
# 508  1080 x 2412            120
# 570  1080 x 2400            120
# 591  1080 x 2400             90
# 613  1080 x 2400             90
# 616  1644 x 3840             60
# 645  1080 x 2400             90
# 662  1080 x 2460             60
# 677   720 x 1600             60
# 679  1080 x 2520            120
# 700  1080 x 2400             90
# 744  2460 x 1080             90
# 832  1080 x 2520             90
# 846   720 x 1600             60
# 903  1080 x 2460            120
# 904   720 x 1600             60
# 906   720 x 1440             60
#
#                                                display num_rear_cameras  \
# 25   6.5 inches, 1080 x 2400 px, 120 Hz Display wit...                3
# 80   6.55 inches, 1080 x 2400 px, 120 Hz Display wi...                3
# 147  6.5 inches, 1080 x 2400 px, 120 Hz Display wit...                4
# 151  6.6 inches, 2460 x 1080 px, 90 Hz Display with...                3
# 177  6.58 inches, 1080 x 2408 px Display with Water...                3
# 203  6.6 inches, 2460 x 1080 px, 90 Hz Display with...                3
# 247  6.5 inches, 1080 x 2400 px, 120 Hz Display wit...                2
# 253  6.67 inches, 1080 x 2400 px, 120 Hz Display wi...                3
# 279  6.44 inches, 1080 x 2400 px Display with Water...                3
# 303  6.55 inches, 1080 x 2400 px, 90 Hz Display wit...                3
# 437  6.67 inches, 1080 x 2400 px, 120 Hz Display wi...                4
# 466  6.55 inches, 1080 x 2400 px, 90 Hz Display wit...                3
# 482         6.1 inches, 1080 x 2520 px, 120 Hz Display                3
# 484         6.5 inches, 1644 x 3840 px, 120 Hz Display                4
# 508  6.6 inches, 1080 x 2412 px, 120 Hz Display wit...                3
# 570  6.58 inches, 1080 x 2400 px, 120 Hz Display wi...                3
# 591  6.44 inches, 1080 x 2400 px, 90 Hz Display wit...                3
# 613  6.44 inches, 1080 x 2400 px, 90 Hz Display wit...                3
# 616                 6.5 inches, 1644 x 3840 px Display                4
# 645  6.44 inches, 1080 x 2400 px, 90 Hz Display wit...                3
# 662  6.8 inches, 1080 x 2460 px Display with Water ...                3
# 677  6.5 inches, 720 x 1600 px Display with Water D...                1
# 679         6.1 inches, 1080 x 2520 px, 120 Hz Display                3
# 700  6.44 inches, 1080 x 2400 px, 90 Hz Display wit...                3
# 744  6.6 inches, 2460 x 1080 px, 90 Hz Display with...                3
# 832            6 inches, 1080 x 2520 px, 90 Hz Display                3
# 846  6.52 inches, 720 x 1600 px Display with Water ...                3
# 903         6.9 inches, 1080 x 2460 px, 120 Hz Display                4
# 904  6.5 inches, 720 x 1600 px Display with Water D...                3
# 906                    6 inches, 720 x 1440 px Display                1
#
#     num_front_cameras                                             camera  \
# 25                  1  12 MP + 12 MP + 8 MP Triple Rear & 32 MP Front...
# 80                  1  108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
# 147                 1               64 MP Quad Rear & 32 MP Front Camera
# 151                 1  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 177                 1  50 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 203                 1  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 247                 1        50 MP + 8 MP Dual Rear & 16 MP Front Camera
# 253                 1  108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
# 279                 1  50 MP + 8 MP + 2 MP Triple Rear & 44 MP Front ...
# 303                 1  64 MP + 8 MP + 5 MP Triple Rear & 20 MP Front ...
# 437                 1               48 MP Quad Rear & 20 MP Front Camera
# 466                 1  64 MP + 8 MP + 5 MP Triple Rear & 20 MP Front ...
# 482                 1  12 MP + 12 MP + 12 MP Triple Rear & 8 MP Front...
# 484                 1               12 MP Quad Rear & 12 MP Front Camera
# 508                 1  50 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 570                 1  50 MP + 5 MP + 2 MP Triple Rear & 8 MP Front C...
# 591                 1  64 MP + 8 MP + 2 MP Triple Rear & 44 MP Front ...
# 613                 1  64 MP + 8 MP + 2 MP Triple Rear & 44 MP Front ...
# 616                 1                12 MP Quad Rear & 8 MP Front Camera
# 645                 1  64 MP + 2 MP + 2 MP Triple Rear & 32 MP Front ...
# 662                 1  48 MP + 8 MP + 5 MP Triple Rear & 16 MP Front ...
# 677                 1                     13 MP Rear & 5 MP Front Camera
# 679                 1  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 700                 1  64 MP + 8 MP + 2 MP Triple Rear & 44 MP Front ...
# 744                 1  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 832                 1  12 MP + 8 MP + 8 MP Triple Rear & 8 MP Front C...
# 846                 1                                              50 MP
# 903                 1               50 MP Quad Rear & 16 MP Front Camera
# 904                 1  50 MP + 2 MP + 2 MP Triple Rear & 5 MP Front C...
# 906                 1                     13 MP Rear & 5 MP Front Camera
#
#                      card             os  ram_capacity internal_memory  \
# 25   Memory Card (Hybrid)    Android v10           NaN             NaN
# 80   Memory Card (Hybrid)    Android v12           NaN             NaN
# 147  Memory Card (Hybrid)    Android v12           NaN             NaN
# 151  Memory Card (Hybrid)    Android v12           NaN             NaN
# 177  Memory Card (Hybrid)    Android v12           NaN             NaN
# 203  Memory Card (Hybrid)    Android v12           NaN             NaN
# 247  Memory Card (Hybrid)    Android v13           NaN             NaN
# 253  Memory Card (Hybrid)    Android v11           NaN             NaN
# 279  Memory Card (Hybrid)    Android v12           NaN             NaN
# 303  Memory Card (Hybrid)    Android v11           NaN             NaN
# 437  Memory Card (Hybrid)    Android v11           NaN             NaN
# 466  Memory Card (Hybrid)    Android v11           NaN             NaN
# 482  Memory Card (Hybrid)    Android v10           NaN             NaN
# 484  Memory Card (Hybrid)    Android v12           NaN             NaN
# 508  Memory Card (Hybrid)    Android v12           NaN             NaN
# 570  Memory Card (Hybrid)    Android v12           NaN             NaN
# 591  Memory Card (Hybrid)    Android v11           NaN             NaN
# 613  Memory Card (Hybrid)    Android v11           NaN             NaN
# 616  Memory Card (Hybrid)    Android v10           NaN             NaN
# 645  Memory Card (Hybrid)    Android v12           NaN             NaN
# 662  Memory Card (Hybrid)    Android v10           NaN             NaN
# 677  Memory Card (Hybrid)    Android v11           NaN             NaN
# 679  Memory Card (Hybrid)    Android v12           NaN             NaN
# 700  Memory Card (Hybrid)    Android v12           NaN             NaN
# 744  Memory Card (Hybrid)    Android v12           NaN             NaN
# 832  Memory Card (Hybrid)  Android v10.0           NaN             NaN
# 846  Memory Card (Hybrid)       EMUI v12           NaN             NaN
# 903  Memory Card (Hybrid)    Android v12           NaN             NaN
# 904  Memory Card (Hybrid)    Android v12           NaN             NaN
# 906  Memory Card (Hybrid)        Android           NaN             NaN
#
#     primary_camera_rear primary_camera_front
# 25                   12                   32
# 80                  108                   16
# 147                  64                   32
# 151                  50                   16
# 177                  50                   16
# 203                  50                   16
# 247                  50                   16
# 253                 108                   16
# 279                  50                   44
# 303                  64                   20
# 437                  48                   20
# 466                  64                   20
# 482                  12                    8
# 484                  12                   12
# 508                  50                   16
# 570                  50                    8
# 591                  64                   44
# 613                  64                   44
# 616                  12                    8
# 645                  64                   32
# 662                  48                   16
# 677                  13                    5
# 679                  12                   12
# 700                  64                   44
# 744                  50                   16
# 832                  12                    8
# 846                  50                  NaN
# 903                  50                   16
# 904                  50                    5
# 906                  13                    5

# %%
df1.loc[temp_df.index, 'card'] = 'Not Specified'

# %%
df1['extended_memory'] = df1['card'].apply(lambda x:'0' if 'Not' in x else x.split('upto')).str.get(-1).str.strip().str.replace('Memory Card Supported','Not Specified')

# %%
df1[df1['os'].str.contains('Memory Card')]
# Out:
#      level_0  index brand_name                       model   price  rating  \
# 158      159    163       oppo             Oppo Find N2 5G   94990     NaN
# 304      306    310    samsung     Samsung Galaxy Z Flip 3   69999    84.0
# 320      322    326     royole            Royole FlexPai 2  109999    87.0
# 363      365    369       oppo            OPPO Find N Flip   89990    88.0
# 389      392    396       oppo           OPPO Find N2 Flip   70990    88.0
# 499      504    508    samsung  Samsung Galaxy Z Flip 4 5G   89999    88.0
# 562      570    574         lg                  LG Wing 5G   54999    89.0
# 600      613    617    oukitel                Oukitel WP21   22990    82.0
# 664      682    686         lg                LG V60 ThinQ   79990     NaN
# 701      721    725       asus  Asus ROG Phone 6D Ultimate  107990     NaN
# 706      726    730     huawei            Huawei Mate Xs 2  162990    89.0
# 819      844    848        cat                CAT S22 Flip   14999     NaN
# 863      894    898     royole         Royole FlexPai 3 5G  149999    87.0
# 956      993    997     huawei               Huawei Mate X  169000     NaN
#
#                                                    sim  has_ir_blaster  \
# 158            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False
# 304          Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False
# 320                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False
# 363          Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False
# 389          Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False
# 499            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False
# 562            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False
# 600                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi           False
# 664            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False
# 701            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC           False
# 706    Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster            True
# 819                   Single Sim, 3G, 4G, VoLTE, Wi-Fi           False
# 863                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi           False
# 956  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...            True
#
#      has_5g  has_nfc       processor_name processor_brand  num_corse  \
# 158    True     True   Snapdragon 8+ Gen1      snapdragon  Octa Core
# 304    True     True       Snapdragon 888      snapdragon  Octa Core
# 320    True    False       Snapdragon 865      snapdragon  Octa Core
# 363    True     True       Dimensity 9000       dimensity  Octa Core
# 389    True     True  Dimensity 9000 Plus       dimensity  Octa Core
# 499    True     True  Snapdragon  8+ Gen1      snapdragon  Octa Core
# 562    True     True     Snapdragon  765G      snapdragon  Octa Core
# 600   False    False            Helio G99           helio  Octa Core
# 664    True     True      Snapdragon  865      snapdragon  Octa Core
# 701    True     True  Dimensity 9000 Plus       dimensity  Octa Core
# 706   False     True       Snapdragon 888      snapdragon  Octa Core
# 819   False    False         Qualcomm 215        qualcomm  Quad Core
# 863    True    False       Snapdragon 888      snapdragon  Octa Core
# 956    True     True           Kirin  990           kirin  Octa Core
#
#      processor_speeds                                          processor  \
# 158              3.20   Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor
# 304              2.84      Snapdragon 888, Octa Core, 2.84 GHz Processor
# 320              2.84      Snapdragon 865, Octa Core, 2.84 GHz Processor
# 363              3.05      Dimensity 9000, Octa Core, 3.05 GHz Processor
# 389              3.20  Dimensity 9000 Plus, Octa Core, 3.2 GHz Processor
# 499              3.20  Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 562              2.40    Snapdragon  765G , Octa Core, 2.4 GHz Processor
# 600              2.20            Helio G99, Octa Core, 2.2 GHz Processor
# 664              2.84     Snapdragon  865, Octa Core, 2.84 GHz Processor
# 701              3.20  Dimensity 9000 Plus, Octa Core, 3.2 GHz Processor
# 706              2.84      Snapdragon 888, Octa Core, 2.84 GHz Processor
# 819              1.30         Qualcomm 215, Quad Core, 1.3 GHz Processor
# 863              2.84      Snapdragon 888, Octa Core, 2.84 GHz Processor
# 956              2.86          Kirin  990, Octa Core, 2.86 GHz Processor
#
#                            ram  battery_capacity  fast_charging  ram_capasity  \
# 158  12 GB RAM, 256 GB inbuilt            4520.0           67.0          12.0
# 304   8 GB RAM, 128 GB inbuilt            3300.0           15.0           8.0
# 320   8 GB RAM, 128 GB inbuilt            4450.0           -1.0           8.0
# 363   8 GB RAM, 128 GB inbuilt            4300.0           44.0           8.0
# 389   8 GB RAM, 256 GB inbuilt            4300.0           44.0           8.0
# 499   8 GB RAM, 128 GB inbuilt            3700.0           25.0           8.0
# 562   8 GB RAM, 128 GB inbuilt            4000.0            0.0           8.0
# 600  12 GB RAM, 256 GB inbuilt            9800.0           66.0          12.0
# 664   8 GB RAM, 128 GB inbuilt            5000.0            0.0           8.0
# 701  16 GB RAM, 512 GB inbuilt            6000.0           65.0          16.0
# 706   8 GB RAM, 512 GB inbuilt            4600.0           66.0           8.0
# 819    2 GB RAM, 16 GB inbuilt            2000.0           -1.0           2.0
# 863   8 GB RAM, 128 GB inbuilt            3360.0           -1.0           8.0
# 956   8 GB RAM, 512 GB inbuilt            4500.0           55.0           8.0
#
#      internal_memoryy                                  battery  screen_size  \
# 158             256.0  4520 mAh Battery with 67W Fast Charging         7.10
# 304             128.0  3300 mAh Battery with 15W Fast Charging         6.70
# 320             128.0                         4450 mAh Battery         7.80
# 363             128.0  4300 mAh Battery with 44W Fast Charging         6.80
# 389             256.0  4300 mAh Battery with 44W Fast Charging         6.80
# 499             128.0  3700 mAh Battery with 25W Fast Charging         6.70
# 562             128.0      4000 mAh Battery with Fast Charging         6.80
# 600             256.0  9800 mAh Battery with 66W Fast Charging         6.78
# 664             128.0      5000 mAh Battery with Fast Charging         6.80
# 701             512.0  6000 mAh Battery with 65W Fast Charging         6.78
# 706             512.0  4600 mAh Battery with 66W Fast Charging         7.80
# 819              16.0                         2000 mAh Battery         4.00
# 863             128.0                         3360 mAh Battery         7.20
# 956             512.0  4500 mAh Battery with 55W Fast Charging         8.00
#
#        resolution  refresh_rate  \
# 158  1792 x 1920            120
# 304  1080 x 2640            120
# 320  1440 x 1920             60
# 363  1200 x 2400            120
# 389  1080 x 2520            120
# 499  1080 x 2640            120
# 562  1080 x 2460             60
# 600  1080 x 2400            120
# 664  1080 x 2460             60
# 701  1080 x 2448            165
# 706  2200 x 2480            120
# 819    480 x 640             60
# 863  1440 x 1920             60
# 956  2200 x 2480             60
#
#                                                display num_rear_cameras  \
# 158  7.1 inches, 1792 x 1920 px, 120 Hz Display wit...                3
# 304  6.7 inches, 1080 x 2640 px, 120 Hz Display wit...                2
# 320                 7.8 inches, 1440 x 1920 px Display                3
# 363  6.8 inches, 1200 x 2400 px, 120 Hz Display wit...                2
# 389  6.8 inches, 1080 x 2520 px, 120 Hz Display wit...                2
# 499  6.7 inches, 1080 x 2640 px, 120 Hz Display wit...                2
# 562                 6.8 inches, 1080 x 2460 px Display                3
# 600        6.78 inches, 1080 x 2400 px, 120 Hz Display                3
# 664  6.8 inches, 1080 x 2460 px Display with Punch ...                3
# 701        6.78 inches, 1080 x 2448 px, 165 Hz Display                3
# 706  7.8 inches, 2200 x 2480 px, 120 Hz Display wit...                3
# 819                     4 inches, 480 x 640 px Display                1
# 863                 7.2 inches, 1440 x 1920 px Display                3
# 956                   8 inches, 2200 x 2480 px Display                4
#
#     num_front_cameras                                             camera  \
# 158                 2  50 MP + 48 MP + 32 MP Triple Rear & 32 MP + 32...
# 304                 1       12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 320                 1  64 MP + 16 MP + 8 MP Triple Rear & 32 MP Front...
# 363                 1        50 MP + 8 MP Dual Rear & 32 MP Front Camera
# 389                 1        50 MP + 8 MP Dual Rear & 32 MP Front Camera
# 499                 1       12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 562                 1  64 MP + 13 MP + 12 MP Triple Rear & 32 MP Fron...
# 600                 1  64 MP + 20 MP + 2 MP Triple Rear & Main Front ...
# 664                 1  64 MP + 13 MP + 0.3 MP Triple Rear & 10 MP Fro...
# 701                 1  50 MP + 13 MP + 5 MP Triple Rear & 12 MP Front...
# 706                 1  50 MP + 13 MP + 8 MP Triple Rear & 10.7 MP Fro...
# 819                 1                      5 MP Rear & 2 MP Front Camera
# 863                 1  64 MP + 16 MP + 8 MP Triple Rear & 32 MP Front...
# 956           Missing                             48 MP Quad Rear Camera
#
#                           card                                  os  \
# 158  Memory Card Not Supported           Memory Card Not Supported
# 304  Memory Card Not Supported           Memory Card Not Supported
# 320  Memory Card Not Supported  Memory Card Supported, upto 256 GB
# 363  Memory Card Not Supported           Memory Card Not Supported
# 389  Memory Card Not Supported           Memory Card Not Supported
# 499  Memory Card Not Supported           Memory Card Not Supported
# 562  Memory Card Not Supported     Memory Card (Hybrid), upto 2 TB
# 600  Memory Card Not Supported                Memory Card (Hybrid)
# 664  Memory Card Not Supported     Memory Card (Hybrid), upto 2 TB
# 701  Memory Card Not Supported           Memory Card Not Supported
# 706  Memory Card Not Supported   Memory Card (Hybrid), upto 256 GB
# 819  Memory Card Not Supported  Memory Card Supported, upto 128 GB
# 863  Memory Card Not Supported  Memory Card Supported, upto 256 GB
# 956  Memory Card Not Supported   Memory Card (Hybrid), upto 256 GB
#
#      ram_capacity internal_memory primary_camera_rear primary_camera_front  \
# 158           NaN             NaN                  50                   32
# 304           NaN             NaN                  12                   10
# 320           NaN             NaN                  64                   32
# 363           NaN             NaN                  50                   32
# 389           NaN             NaN                  50                   32
# 499           NaN             NaN                  12                   10
# 562           NaN             NaN                  64                   32
# 600           NaN             NaN                  64                 Main
# 664           NaN             NaN                  64                   10
# 701           NaN             NaN                  50                   12
# 706           NaN             NaN                  50                 10.7
# 819           NaN             NaN                   5                    2
# 863           NaN             NaN                  64                   32
# 956           NaN             NaN                  48                  NaN
#
#     extended_memory
# 158               0
# 304               0
# 320               0
# 363               0
# 389               0
# 499               0
# 562               0
# 600               0
# 664               0
# 701               0
# 706               0
# 819               0
# 863               0
# 956               0

# %%
df1.loc[temp_df.index, 'os'] = 'Not Specified'

# %%
df1['os'].value_counts()
# Out:
# Android v12                           379
# Android v11                           272
# Android v13                            89
# Android v10                            67
# Android v9.0 (Pie)                     28
# Android v10.0                          22
# Not Specified                          20
# iOS v16                                15
# iOS v15                                12
# Android v8.1 (Oreo)                     9
# iOS v14                                 6
# Memory Card Not Supported               6
# iOS v13                                 4
# Android v8.0 (Oreo)                     4
# iOS v15.0                               3
# Android v6.0 (Marshmallow)              2
# HarmonyOS v2.0                          2
# Memory Card (Hybrid), upto 256 GB       2
# Android v11.0                           2
# Harmony v2.0                            2
# iOS v14.0                               2
# Memory Card (Hybrid), upto 2 TB         2
# Android v5.1.1 (Lollipop)               2
# Memory Card Supported, upto 256 GB      2
# Android v12.1                           2
# Hongmeng OS v3.0                        1
# Hongmeng OS v4.0                        1
# Android                                 1
# Android v7.1 (Nougat)                   1
# EMUI v12                                1
# HarmonyOS                               1
# HarmonyOS v2                            1
# Memory Card Supported, upto 128 GB      1
# iOS v13.0                               1
# iOS v12.3                               1
# Bluetooth                               1
# iOS v17                                 1
# RTOS (Series 30+)                       1
# Memory Card (Hybrid)                    1
# iOS v10                                 1
# Pragati OS (Powered by Android)         1
# Android v4.4.2 (KitKat)                 1
# Android v5.1 (Lollipop)                 1
# Android v9 (Pie)                        1
# Name: os, dtype: int64

# %%
def os_extractor(text):

  if 'Android' in text:
    return 'android'
  elif 'iOS' in text:
    return 'ios'
  elif 'Not Specified':
    return text
  elif 'Harmony' in text or 'Hongmeng' in text or 'EMUI' in text:
    return 'other'

# %%
df1['os'] = df1['os'].apply(os_extractor)

# %%
export_df = df1.drop(columns=['index','sim','processor','ram','battery','display','camera','card'])

# %%
export_df.to_csv('smartphone_cleaned_v2.csv',index=False)

# %%
df2 = pd.read_csv('smartphone_cleaned_v2.csv')
